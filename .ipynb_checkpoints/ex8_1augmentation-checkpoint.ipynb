# %% [markdown]
# ## 実験8
#
# MASK1個&水増し倍率2倍からMASK10個&水増し倍率11倍までの正答率の推移を確認していく
#
# 全部5分割交差検証で

# %%
import os, subprocess

if 'COLAB_GPU' in os.environ:
    # Google Colabの場合
    from google.colab import drive
    drive.mount('/content/drive')
    base_path = "/content/drive/MyDrive/code/"

    #!pip install transformers sentencepiece datasets
    #上記はローカル環境でシンタックスエラーになる。代わりに以下のように実行。
    subprocess.run(["pip", "install", "torch","transformers", "fugashi", "unidic-lite"])
else:
    # ローカル環境の場合
    base_path = os.path.expanduser("../../")

# %%
import os
import shutil
import random
import math
from collections import Counter
import numpy as np
import pandas as pd
import torch
import fugashi
import unidic_lite
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import transformers

# %% [markdown]
# ここでいろいろ設定することにする

# %%
#1つのデータでMASKに置き換える単語の数は？
n_masks = 8
#MASKのための重要度算出は？("tfidf" or "bm25")
mask_method = "bm25"
#直後の相談者発話を入力データに含むか？
is_after_dialogue = True
#クライエント発話にもMASKを適用するか？
mask_client_dialogue = True
#データ拡張の倍率
multiplier_augmentation = 8
#実験番号
ex_n = [8, 8]

# %%
dataset_path = base_path + "datasets/dataset_original.csv"
data_path = base_path + "datasets/ver-20200312/"
#tfidf_path = "../tfidf/original_tfidf.txt"
model_name = "cl-tohoku/bert-base-japanese-v3"
gpt_path = base_path + "datasets/augmention_by_chatGPT.csv"

tokenizer = transformers.BertJapaneseTokenizer.from_pretrained(model_name)
gpt_df = pd.read_csv(gpt_path, encoding="utf-8")
data = {}
df = pd.DataFrame()
filelist = os.listdir(data_path)
for filename in filelist:
    if filename.split(".")[-1] != "csv":
        continue
    tmp_df = pd.read_csv(data_path + filename, encoding="cp932")
    tmp_dict = tmp_df.to_dict(orient="records")
    for line in gpt_df.iloc:
        before = line["before"]
        output = line["output"]
        after = line["after"] if type(line["after"]) != float else ""
        miticode = line["MITI-code"]
        source = line["source"]
        before_dict = {"NO":"Cl", "dialogue":before, "MITI_code":0, "target":""}
        output_dict = {"NO":"Co", "dialogue":output, "MITI_code":miticode, "target":""}
        after_dict = {"NO":"Cl", "dialogue":after, "MITI_code":0, "target":""}
        #print(filename, source)
        if source == filename:
            tmp_dict.append(before_dict)
            tmp_dict.append(output_dict)
            tmp_dict.append(after_dict)
    new_df = pd.DataFrame(tmp_dict)
    new_df.insert(4, "source",filename)
    df = pd.concat([df, new_df], axis=0)

# %%
df
# Out:
#        NO                                           dialogue  MITI_code  \
# 0    Co1   現状についてお話しいただきありがとうございました。そんな中、こちらのカウンセリングを受けて、...          3
# 1    Cl1                             そうですね。転職活動へのやる気を高めたいです。          7
# 2    Co2               やる気を高めて転職活動を行い、来年度からは新しい職場で働きたいわけですね。          2
# 3    Cl2                     そうです。さすがに今の職場で来年度も働くイメージは持てません。          7
# 4     Co3                             早急に脱出したいという思いが強いわけですね。          2
# ..    ...                                                ...        ...
# 25  Cl13                                              そうですね。          0
# 26  Co14   もしかしたら、きちんと飲んでみると、効果も変わってくるんじゃないかと思うんですね。こちらで、...          4
# 27  Cl14                                       今日はちょっと難しいです。          8
# 28  Co15                     そうですか。それでは、またお時間あるときにお立ち寄りください。          0
# 29  Cl15                                              はい。ぜひ。          7
#
#           target     source
# 0   転職に向けた行動を起こす  case1.csv
# 1            NaN  case1.csv
# 2            NaN  case1.csv
# 3            NaN  case1.csv
# 4            NaN  case1.csv
# ..           ...        ...
# 25           NaN  case9.csv
# 26           NaN  case9.csv
# 27           NaN  case9.csv
# 28           NaN  case9.csv
# 29           NaN  case9.csv
#
# [481 rows x 5 columns]

# %%
data_sep = []
for i, series in enumerate(df.iloc):
    if i == 0 or i == len(df)-1:
        continue
    if "Cl" not in df.iloc[i-1]["NO"]:
        continue
    elif "Co" not in df.iloc[i]["NO"]:
        continue
    source = series["source"]
    miti_code = series["MITI_code"]
    dialogue_before = df.iloc[i-1]["dialogue"] if "Cl" in df.iloc[i-1]["NO"] else ""
    dialogue = series["dialogue"]
    dialogue_after = df.iloc[i+1]["dialogue"] if "Cl" in df.iloc[i+1]["NO"] else ""
    if is_after_dialogue:
        sentence = dialogue_before + "[SEP]" + dialogue + "[SEP]" + dialogue_after
    else:
        sentence = dialogue_before + "[SEP]" + dialogue
    data_sep.append({"sentence":sentence, "miti_code":miti_code, "source":source})
df_sep = pd.DataFrame(data_sep)

# %%
for series in df_sep.iloc:
    print(series["sentence"])
# Out:
# そうですね。転職活動へのやる気を高めたいです。[SEP]やる気を高めて転職活動を行い、来年度からは新しい職場で働きたいわけですね。[SEP]そうです。さすがに今の職場で来年度も働くイメージは持てません。
# そうです。さすがに今の職場で来年度も働くイメージは持てません。[SEP]早急に脱出したいという思いが強いわけですね。[SEP]はい。
# はい。[SEP]それでもなかなかやる気が出てこないというのは、何度か失敗していたり、今の仕事が忙しかったりということがあるわけですね。[SEP]そうです。どうせこんな書類書いたって無駄だろうと思ってしまいます。
# そうです。どうせこんな書類書いたって無駄だろうと思ってしまいます。[SEP]ただ、ご自身としては、そうも言っていられない状況だと。[SEP]そうですね。何とかして、脱出しなくてはいけないと思います。
# そうですね。何とかして、脱出しなくてはいけないと思います。[SEP]来年度から別の職場で働くために出来る限りのことをしたいという思いはあるわけですね。[SEP]そうですね。現実的に、時間が無いということが大きいかもしれませんね。
# そうですね。現実的に、時間が無いということが大きいかもしれませんね。[SEP]まずは、なんとか時間を確保する必要があると。[SEP]そうですね。やる気がないわけではないんだと思います。何とかして、転職先を見つけたいです。
# そうですね。やる気がないわけではないんだと思います。何とかして、転職先を見つけたいです。[SEP]はい[SEP]ただ、時間的に厳しい中で、なかなかうまくいかず、落ち込んでいました。
# ただ、時間的に厳しい中で、なかなかうまくいかず、落ち込んでいました。[SEP]忙しい中で、せっかく書いた書類がなかなか一次審査を通らないと、嫌になってしまうことはありますよね。ただ、実際は、今後も転職活動は続けていきたいということですね。[SEP]そうですね。一応会社の規定では、3か月前までに退職願を出さなくてはいけないことになっているのですが、当面はそれを目指して、それが難しくても、今後も転職活動を続けていく気ではいます。
# そうですね。一応会社の規定では、3か月前までに退職願を出さなくてはいけないことになっているのですが、当面はそれを目指して、それが難しくても、今後も転職活動を続けていく気ではいます。[SEP]そのために今日できることとしては、今後の見通しについてお伺いしていくことですかね。他に何か、やる気を高めるために出来そうなことはありますか？[SEP]そうですね。あとは、時間ですかね。どうしても、なかなかうまく時間が使えていない感じがするので、その辺りについてご相談させていただければと思います。
# そうですね。あとは、時間ですかね。どうしても、なかなかうまく時間が使えていない感じがするので、その辺りについてご相談させていただければと思います。[SEP]時間の使い方について相談できると、今後、今のお仕事をしながら少なくとも今以上には、転職活動を効率的に進めることができるだろうということですね。[SEP]はい。
# はい。[SEP]そうすると、改めて、今日も面談が終わった後には、どんな風になっていると良さそうですか？[SEP]そうですね。やる気というよりも、淡々と、計画的に、応募書類を出し続けるということですかね。気分的なことよりも、現職との両立がキーになりそうです。
# そうですね。やる気というよりも、淡々と、計画的に、応募書類を出し続けるということですかね。気分的なことよりも、現職との両立がキーになりそうです。[SEP]やる気というよりも、いかに現在のお仕事と両立させながら、応募を継続していくかが重要だろうということですね。[SEP]はい
# はい[SEP]それが、今と違ってどのようになっていると、良さそうですか？[SEP]そうですね。今は、応募書類の締め切りに追われている感じなので、もう少し余裕をもって準備をしたいです。
# そうですね。今は、応募書類の締め切りに追われている感じなので、もう少し余裕をもって準備をしたいです。[SEP]いいじゃないですか！早めに準備すると気分的にも余裕が持てそうですね。[SEP]そうなんです。今はいつもぎりぎりで、夜20時までに大きな郵便局まで書類を出しに行くこともあるので、それが無いだけでも、だいぶ効率的になると思います。
# そうなんです。今はいつもぎりぎりで、夜20時までに大きな郵便局まで書類を出しに行くこともあるので、それが無いだけでも、だいぶ効率的になると思います。[SEP]余裕をもって準備をして、早めに、近所の郵便局に出しに行けるといいということですね。[SEP]はい。あとは…どうしても、日々の業務に追われていると、転職活動を先送りにしがちなので、それを何とかする必要がありますかね。
# はい。あとは…どうしても、日々の業務に追われていると、転職活動を先送りにしがちなので、それを何とかする必要がありますかね。[SEP]日々の業務と転職活動とのバランスをとると。[SEP]そうですね。例えば、毎日1時間は転職に向けた書類を準備する時間に充てるとか。
# そうですね。例えば、毎日1時間は転職に向けた書類を準備する時間に充てるとか。[SEP]良さそうですね！毎日1時間ぐらい取れれば、ある程度転職に向けた準備を余裕をもって進めて行けそうということですかね。[SEP]そうですね。平日で1時間取れれば十分だと思います。むしろ、1時間取れるかどうか…
# そうですね。平日で1時間取れれば十分だと思います。むしろ、1時間取れるかどうか…[SEP]1時間とるのは難しいかもしれないと。[SEP]そうですね…毎日30分位が現実的かという思いと、1時間取れれば、だいぶ前進しそうだという思いがあります。
# そうですね…毎日30分位が現実的かという思いと、1時間取れれば、だいぶ前進しそうだという思いがあります。[SEP]1時間は、少し、現実的ではないかもしれない。一方で、1時間ぐらい取れた方が、転職活動は進むだろうということですね。[SEP]そうなんですよね…
# そうなんですよね…[SEP]毎日30分か、1時間かというのが、良いところですかね。[SEP]はい。
# はい。[SEP]それは、やっぱり、どっちかに決めておいた方がいいだろうということですよね。[SEP]そうですね。結局、どっちでもということだと、30分とか、場合によっては、やらなくてもいいかということになりがちだと思います。1時間なら1時間と決めた方が、その時間を確保するために、準備できると思います。また、30分と決めれば、それくらいは絶対確保しようとおもえるだろうし。
# そうですね。結局、どっちでもということだと、30分とか、場合によっては、やらなくてもいいかということになりがちだと思います。1時間なら1時間と決めた方が、その時間を確保するために、準備できると思います。また、30分と決めれば、それくらいは絶対確保しようとおもえるだろうし。[SEP]30分にするにしろ、1時間にするにしろ、それをしっかり決めることが、今後転職活動をスムーズに進めて行くためには重要ということですね。[SEP]そうですね。とりあえずは、1時間やるということで、しばらくやってみようと思います。
# そうですね。とりあえずは、1時間やるということで、しばらくやってみようと思います。[SEP]30分よりは1時間に決めた方が良さそうな感じだったんですね。[SEP]はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。
# はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。[SEP]そうですね。将来を見据えて、1つ1つの事を、しっかり考えて、計画的に進める力をお持ちなんですね。[SEP]実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]1日1時間、転職活動のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10点として、あまり重要でないというのを0点とすると、Aさんにとっては、何点くらいになりそうですか？[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。1日1時間転職活動のために時間を使うのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# はい。[SEP]それはやはり、来年度は別の職場で働きたいというのが大きな理由ですよね。[SEP]はい。
# はい。[SEP]他にも何かありそうですか？[SEP]そうですね。やっぱり、自分のために時間は使うべきだという思いがあります。今の仕事は、それが嫌いなわけではないですが、自分が今やるべきことはそれではないと思います。自分の人生やキャリアの優先順位を上げるべきだと思います。
# そうですね。やっぱり、自分のために時間は使うべきだという思いがあります。今の仕事は、それが嫌いなわけではないですが、自分が今やるべきことはそれではないと思います。自分の人生やキャリアの優先順位を上げるべきだと思います。[SEP]仕事は仕事で大事だけれど、今自分のために何が必要かということを考えると、それは、転職に向けた活動を優先することだということですね。[SEP]はい。
# はい。[SEP]それでは、1日1時間転職に向けた活動の時間を確保することに対する自信度は10点満点でいうとどれくらいでしょうか？0点が自信度ゼロ。10点は、「絶対できる」だとすると。[SEP]そうですね。1時間となると、なかなか難しそうですが…でも何とかなりますかね。まぁ、6点か7点ぐらいでしょうか。
# そうですね。1時間となると、なかなか難しそうですが…でも何とかなりますかね。まぁ、6点か7点ぐらいでしょうか。[SEP]だいぶ自信度も高そうですね。[SEP]そうですね。無理ではないと思います。
# そうですね。無理ではないと思います。[SEP]具体的には、どんな風にすることができそうですか？[SEP]曜日によって業務内容は変わってくるのですが、月、火、木は1日開発の仕事をしていて、木曜日は英会話に通っているので、その前の時間ですかね。月、火は、簡単な書類作成なら、休憩時間などに出来ると思います。水と金は、ミーティングが多くなるので、なかなか日中行うのは難しいですね。この日は退勤後かなと思います。
# 曜日によって業務内容は変わってくるのですが、月、火、木は1日開発の仕事をしていて、木曜日は英会話に通っているので、その前の時間ですかね。月、火は、簡単な書類作成なら、休憩時間などに出来ると思います。水と金は、ミーティングが多くなるので、なかなか日中行うのは難しいですね。この日は退勤後かなと思います。[SEP]だいぶ具体的に考えられていますね！それでは、先ほどは1日1時間とることの自信度は6点か7点ということでしたが、これを、もう少し上げるとすると、何があると上がってきそうですか？[SEP]そうですね…月、火の仕事中に突発的な業務が発生した時や、水、金に疲れて帰宅したときなんかが難しいと思います。この辺りの対処法を見つけることができれば、自信度は高まると思います。
# そうですね…月、火の仕事中に突発的な業務が発生した時や、水、金に疲れて帰宅したときなんかが難しいと思います。この辺りの対処法を見つけることができれば、自信度は高まると思います。[SEP]月、火に日中に出来なかった場合にどうするかということと、水、金に疲れて帰宅したときにどうするかということですね。[SEP]はい。いずれも帰宅してしまうと、なかなか作業の時間が取れないことが多いので、帰宅前にやれるといいですかね。例えば、水、金や月、火で日中に1時間取れなかったときには、帰宅途中でカフェやレストランによって1時間作業をして帰るとか。
# はい。いずれも帰宅してしまうと、なかなか作業の時間が取れないことが多いので、帰宅前にやれるといいですかね。例えば、水、金や月、火で日中に1時間取れなかったときには、帰宅途中でカフェやレストランによって1時間作業をして帰るとか。[SEP]いいですね！そのような工夫をすると、1日1時間転職のための活動をすることに対する自信度は、10点満点でどれくらいになりますか？[SEP]8，9割出来るのではないでしょうか。100％というのは難しいと思ので、これくらいなら十分かと思います。
# 8，9割出来るのではないでしょうか。100％というのは難しいと思ので、これくらいなら十分かと思います。[SEP]1日1時間時間を使うと意識して、過ごし、場合によっては、帰宅途中にカフェやレストランによることで、8，9割はこの目標を達成できそうだということですね。[SEP]はい。
# はい。[SEP]今日は初めは転職に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事と転職活動を両立させるかが大事ということから、1日1時間と時間を決めて、転職活動に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を取れば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の転職の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい[SEP]このように本日は話をしてきましたが、いかがでしたか？[SEP]本当にやる気が無くて転職のことを考えるだけで憂うつでしたが、このままではいけないと改めて思えたし、じゃあ具体的に何をしていけばいいのかということも明確になったので、今はとても前向きで、気持ちも軽くなりました。まだ時間はあるので、まずはこの方向で継続してみたいと思います。
# 本当にやる気が無くて転職のことを考えるだけで憂うつでしたが、このままではいけないと改めて思えたし、じゃあ具体的に何をしていけばいいのかということも明確になったので、今はとても前向きで、気持ちも軽くなりました。まだ時間はあるので、まずはこの方向で継続してみたいと思います。[SEP]そうですね。もう少しやってみて、またうまくいかないようであれば方針を修正するということでいいのではないかと思います。他に何か今日話し合っておいた方がいいことはありますか？[SEP]いいえ。大丈夫です。
# いいえ。大丈夫です。[SEP]わかりました。それでは、今日はこれで面談を終えたいと思います。またいつでもご連絡ください。本日はありがとうございました。[SEP]ありがとうございました。
# はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。[SEP]時間管理に関して少し困っているようですね。特に大きな問題があったわけではないけれど、朝の時間に間に合わせることが難しかったということが理解できます。日常生活での小さな挑戦にも前向きに取り組んでいることは、とても良いことだと思います。[SEP]実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。
# はい。[SEP]あなたは、月曜日と火曜日に予期せぬ業務が発生したり、水曜日と金曜日に疲れて帰宅することが、転職活動における時間確保の障壁となっていると感じていますね。このような状況に対処する方法を見つけることが、あなたの自信度を向上させる鍵になりそうです。[SEP]はい。
# はい。[SEP]あなたは、帰宅途中にカフェやレストランで作業時間を確保することを考えているようですね。このような工夫をすることで、転職活動に必要な1日1時間の時間を実質的に確保し、目標達成に向けた自信が高まると感じているのですね。[SEP]はい。
# はい。[SEP]あなたは、帰宅途中にカフェやレストランで1時間作業をすることを検討しています。これにより、転職活動のための時間を効果的に確保し、自信度を8、9割程度まで高めることができると考えているようです。[SEP]はい。
# はい。[SEP]あなたは、1日1時間の時間を転職活動に費やすことを意識しており、帰宅途中にカフェやレストランを利用することで、この目標を8、9割達成できると考えています。このような具体的な計画は、あなたの転職活動への自信を高めるのに役立つでしょう。[SEP]はい。
# はい。[SEP]あなたは、仕事の日に発生する突発的な業務や、疲れて帰宅した日に作業時間が取れないという課題に直面しています。しかし、帰宅途中にカフェやレストランで時間を作るという具体的な対策を考えていて、このアプローチにより転職活動における自信度が高まると感じているようです。[SEP]はい。
# うん[SEP]はっきりいうと，このままだったらすぐにでも彼の耳に鼓膜チュ－ブを入れなければならないんです。またP ビタミンC欠乏や虫歯，行動上の問題，ぜんそく，呼吸器感染…本当に多くのリスクを彼に負わせることになるんです。それに加え，喫煙者の子どもは，彼ら自身も喫煙者になりがちです。彼を喫煙者に育てたいのですか？[SEP]もう、私は吸っていないって・・・いえ，私，私，私やめようとしてきたけれど，でもすごく難しくてどうやっていいか分からないんです。
# もう、私は吸っていないって・・・いえ，私，私，私やめようとしてきたけれど，でもすごく難しくてどうやっていいか分からないんです。[SEP]今がやめるときです。吸い続けることはできません。彼のためだけでなくあなたのためにも言います。肺がんや肺気腫，口腔がん，心疾患などのりスクも増えるんですよ。[SEP]わかっています。わかっています。聞いたことがあるし，以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの？すごく難しい。
# わかっています。わかっています。聞いたことがあるし，以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの？すごく難しい。[SEP]そうね，今までのような苦労をしなくてもあなたが利用できるものがあります｡ニコチン代用品、パッチや，トローチ，ガム，吸入器，スプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬）にトライするのであれば，薬物治療について話をすることができます。禁煙グループへの参加もできますし，電話相談窓口もありますし…。[SEP]とにかくそれをする時間がない…
# とにかくそれをする時間がない…[SEP]やめられないという言い訳をしないこと！非常に大事なことなんですから｡[SEP]わかってます。知っているんです。何ひとつ問題のない人なんていないでしよ？本当に，それは本当に難しいことなんです。
# わかってます。知っているんです。何ひとつ問題のない人なんていないでしよ？本当に，それは本当に難しいことなんです。[SEP]では，あなたのお子さんの健康以上に大事なものはなんですか？[SEP]わかりません。
# わかりません。[SEP]あなたが私に禁煙しますといってくれることをまってます。ホントに大事なことです。[SEP]そうね，それを全部見てみます。何かできるようなことを見つけて頑張ってみます。それで私の主治医に話をしてみます。
# そうね，それを全部見てみます。何かできるようなことを見つけて頑張ってみます。それで私の主治医に話をしてみます。[SEP]OK，私はあなたが本当にこのことを真剣に考える必要があると思いますよ。申し上げたように，あなた自身とあなたのお子さんを危険にさらしているのですから。[SEP]わかりました。とにかくわかりました。
# わかりました。とにかくわかりました。[SEP]O K[SEP]わかりました。とにかくわかりました。
# わかりました。とにかくわかりました。[SEP]息子さんが何度も中耳炎を繰り返していることは、あなたにとっても息子さんにとっても大きなストレスですね。タバコの煙が子どもの耳感染のリスクファクターの一つであることを考慮すると、あなたが喫煙していることが関連している可能性があります。息子さんの周りで吸わないように気をつけているというあなたの努力は理解していますが、それでもタバコの影響は考慮に入れなければならないかもしれません。[SEP]
# わかりました。とにかくわかりました。[SEP]息子さんの健康を守るために、そしてあなた自身の健康のためにも、タバコをやめることを真剣に考える時期に来ているようです。タバコを吸うことの影響は中耳炎だけに留まらず、他の多くの健康リスクも伴います。あなたが禁煙することは、息子さんを喫煙者に育てないためにも重要です。[SEP]
# わかりました。とにかくわかりました。[SEP]あなたが禁煙しようとしていること、そしてそれが非常に難しいことを理解しています。しかし、息子さんの健康のためにも、あなた自身のためにも、禁煙は避けられない道です。肺がんや心疾患など、喫煙によるリスクは非常に高く、今がやめる時です。[SEP]
# わかりました。とにかくわかりました。[SEP]あなたが禁煙する方法についてわからないというのは理解しています。しかし、禁煙を支援する多くの方法があります。ニコチン代用品や経口禁煙薬、禁煙グループへの参加など、さまざまなオプションがあります。時間がないと感じるかもしれませんが、これはあなたと息子さんの健康のために非常に重要なことです。[SEP]
# ええ[SEP]では，もし禁煙の決心をするとして，全く自信がない「できないと思う」場合を1，できると確信している場合を10として9から10段階で今のあなたはどの辺りですか？[SEP]たぶん5くらいだと，迷っているところ。以前やったことがあるからできると思うけれど，同時にすごく難しいとも感じている，同じ状況じゃないし。
# たぶん5くらいだと，迷っているところ。以前やったことがあるからできると思うけれど，同時にすごく難しいとも感じている，同じ状況じゃないし。[SEP]では2や3ではなく，5としたのはどうしてでしょう。[SEP]私にとっても良くないと分かっているし，彼がタバコをすってもいいと思って成長してほしくない。彼にはそういうことをしてほしくない。噛むタバコとかそういったものをしてほしくない。だから、特に彼がお母さんがタバコを吸っているとわかるくらいの年になる前に，やめるべきなのは分かっている。
# 私にとっても良くないと分かっているし，彼がタバコをすってもいいと思って成長してほしくない。彼にはそういうことをしてほしくない。噛むタバコとかそういったものをしてほしくない。だから、特に彼がお母さんがタバコを吸っているとわかるくらいの年になる前に，やめるべきなのは分かっている。[SEP]はい。[SEP]でも私にできるのかわからない。
# でも私にできるのかわからない。[SEP]OK，やめたい理由がたくさんあるようですね。過去にやめることに成功していますし，今も少しうしろめたさを感じている。[SEP]ええ。
# ええ。[SEP]ここからどうするべきだと思いますか？[SEP]わかりません，私…助けがほしい，どういった助けを必要としているかわからない。
# わかりません，私…助けがほしい，どういった助けを必要としているかわからない。[SEP]わかりました，もし何か興味があれば，もちろんお話することができます。実際にいろんな方の禁煙を成功させている新たな選択肢もたくさんあります。あなたが試せる薬物療法も…[SEP]薬は好きではありません。
# 薬は好きではありません。[SEP]OK，他の方と一緒に体験することができるサポートグループや勉強会もあります。時々，ただそのサポートを受けるだけで大きな恩恵を被る。特に喫煙がストレス緩和になるような人にとってはそんな場所が役立つかもしれません。[SEP]それはよさそうですね，でも全てに参加する時間があるかどうか。
# それはよさそうですね，でも全てに参加する時間があるかどうか。[SEP]もちろん，時間もたくさん取られるかもしれませんし，あなたの生活に合わないかもしれません。あなたの生活に合うようないくつかの選択肢について話ができればと思うのですが。[SEP]とても嬉しいです
# とても嬉しいです[SEP]OK，ではもしよければ，あなたが来られるときに一度予約を取り直して，そのことについて話をしましょう。[SEP]そうしたいと思います，いいですね。
# そうしたいと思います，いいですね。[SEP]よかった。[SEP]ありがとうございました。
# ありがとうございました。[SEP]はい。[SEP]でも私にできるのかわからない。
# でも私にできるのかわからない。[SEP]タバコをやめたいというあなたの気持ち、特にお子さんの成長を思ってのことだということが伝わってきます。自分自身や大切な人のために、健康的な生活を目指すことは大変価値のあることです。そして、そのような変化に取り組むことに対する不安や疑問を感じることも、ごく自然なことです。[SEP]ええ。
# ええ。[SEP]じゃあ３分くらいで。どんなテーマで？[SEP]んー、英語の勉強をしたいんだけど。
# んー、英語の勉強をしたいんだけど。[SEP]英語の勉強をしたい。[SEP]やっぱりなんか必要かなぁって思うんで。で、やっぱ実際忙しいから、挫折の繰り返しみたいな。
# やっぱりなんか必要かなぁって思うんで。で、やっぱ実際忙しいから、挫折の繰り返しみたいな。[SEP]じゃあ、何回かチャレンジされて、挫折して、でもやっぱり気になるというか。[SEP]まあ何回か、そうね、次回の、教科書読むとか、来年の海外の学会に出たいなぁとか、実際、参加者の先生の話を聞くと、すごいよかったなぁって話が出てきたりするから。うん、そんときはガーッとあがってくるんだけど
# まあ何回か、そうね、次回の、教科書読むとか、来年の海外の学会に出たいなぁとか、実際、参加者の先生の話を聞くと、すごいよかったなぁって話が出てきたりするから。うん、そんときはガーッとあがってくるんだけ
。[SEP]そうですね。ただ、難しいですよね。
# そうですね。ただ、難しいですよね。[SEP]そうだね。でも、来られているときもあるよね。その時はどんな感じかな？[SEP]うぅん．．．たまたま起きるとか、そんなに意識していなくても起きられるんですよね。
# うぅん．．．たまたま起きるとか、そんなに意識していなくても起きられるんですよね。[SEP]来られるときは、意識せずにも起きられるのか！それはいいね！[SEP]そうなんですよ…逆に起きられない時は、寝るのが遅いのかもしれません。
# そうなんですよ…逆に起きられない時は、寝るのが遅いのかもしれません。[SEP]遅く寝ているせいで、朝定時に起きられない。[SEP]そうですね。
# そうですね。[SEP]やっぱり、寝るのが遅くなるっていうのは、色々やることがあったりするんだね。[SEP]そうですね。それだけのせいではないですが、仕事を持ち帰っていることも多いですかね。
# そうですね。それだけのせいではないですが、仕事を持ち帰っていることも多いですかね。[SEP]一つは、仕事を持ち帰えっているせいもあると。それはご苦労様。申し訳なかったね。[SEP]いえいえ。たまたま期限のある仕事だったので。
# いえいえ。たまたま期限のある仕事だったので。[SEP]一つはそれで、他には？[SEP]そうですね…まぁ、テレビ見すぎなのかな。
# そうですね…まぁ、テレビ見すぎなのかな。[SEP]テレビ、好きなんだね。[SEP]そうなんですよ。録画してあるのがあるんで…
# そうなんですよ。録画してあるのがあるんで…[SEP]それは絶対に減らせないね。[SEP]そうですね…
# そうですね…[SEP]そうすると、今、テレビと、仕事の持ち帰りとあったわけだけど、今後、遅刻を減らすためにできそうなことがあるとしたら、どんなこと？[SEP]まずは、テレビですかね。きちんと時間を決めようと思います。録画してあるのをすべて見るとなると、遅くなってしまうので。
# まずは、テレビですかね。きちんと時間を決めようと思います。録画してあるのをすべて見るとなると、遅くなってしまうので。[SEP]そっか。それはありがとうね。仕事の持ち帰りについては、どうかな？[SEP]持ち帰りは、減らした方が良いとは思うのですが、締め切りを遅らせることもできませんし…
# 持ち帰りは、減らした方が良いとは思うのですが、締め切りを遅らせることもできませんし…[SEP]そうしたら、私から提案させてもらいたいことがあるんだけどいい？[SEP]はい。
# はい。[SEP]まず、持ち帰りは極力減らして、できれば無しにすること。その上で、締め切りに間に合わなそうなことがあったら、早めに言ってもらえる？担当を増やしたりしようと思うから。[SEP]わかりました。それならできそうです。
# わかりました。それならできそうです。[SEP]それでは、仕事の持ち帰りを無くすというのと、テレビの時間を調節するということで、やってみようか。[SEP]はい。ありがとうございました。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]朝の時間に間に合わせようとする努力をされていたのですね。何か特別なことがあったわけではなく、ただ時間に追われていたということで、そのような状況にも関わらず、最善を尽くそうとされたことは称賛に値します。[SEP]そうですね。すみません。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]時間管理に関して少し困っているようですね。特に大きな問題があったわけではないけれど、朝の時間に間に合わせることが難しかったということが理解できます。日常生活での小さな挑戦にも前向きに取り組んでいることは、とても良いことだと思います。[SEP]そうですね。すみません。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]今朝は少し遅れてしまったようですね。しかし、そこから立ち直って、ここに来るまでの時間を有意義に使おうとした姿勢が素晴らしいです。[SEP]そうですね。すみません。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]今朝は時間に間に合わせるのが難しかったと聞きましたが、そういった時にどのように対応するかも大切ですね。自分自身を律する力が身についているようで、それはとても大切なことです。[SEP]そうですね。すみません。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]大丈夫ですよ。たまにはそういう日もありますからね。無理せず、自分のペースで行きましょう。[SEP]そうですね。すみません。
# そうですね。目覚ましをたくさんかけたり、夜は早めに負担に入るようにしたり...[SEP]あなたが時間管理を改善しようとする努力をしていることがわかります。目覚ましを複数設定したり、早めに休むよう努めたりと、具体的な対策を講じているのは素晴らしいですね。[SEP]そうですね。ただ、難しいですよね
# そうですね。目覚ましをたくさんかけたり、夜は早めに負担に入るようにしたり...[SEP
# うーん。そうそう、今のご飯の食べ方やったら、いけるんやろな～っと思うけど（笑）。[SEP]まだやってみる勇気はない。　[SEP]まぁ、やってみて、、、これで1回やってみて、うん、減るなら減るで。
# まぁ、やってみて、、、これで1回やってみて、うん、減るなら減るで。[SEP]ご飯がうまくなるだけでも、それでもええかなっと！[SEP]ようは、いかに自分で自制するっていうことか～。
# ようは、いかに自分で自制するっていうことか～。[SEP]ちょっとトライしてみようかなという気持ちがある。　[SEP]いかにタバコをやめれるか、やめたいなっていう思いもある。美味しいんやったら、美味しい方がいいし。昔に比べたら、食欲も落ちていることは落ちているし。
# いかにタバコをやめれるか、やめたいなっていう思いもある。美味しいんやったら、美味しい方がいいし。昔に比べたら、食欲も落ちていることは落ちているし。[SEP]もしかすると今はチャンスかも！みたいな。　[SEP]うまくいけばぁ。昔は吉野家で絶対大盛だったけど、今は並盛でも満足できるし、他の大盛やお代わりがができるお店でも大盛やおかわりは、もうええわ～ってなって食べなくなった。職場に来る野菜中心ヘルシー弁当、ご飯150くらいのやつでも満足できるし～みたいな。
# うまくいけばぁ。昔は吉野家で絶対大盛だったけど、今は並盛でも満足できるし、他の大盛やお代わりがができるお店でも大盛やおかわりは、もうええわ～ってなって食べなくなった。職場に来る野菜中心ヘルシー弁当、ご飯150くらいのやつでも満足できるし～みたいな。[SEP]そうなんですね～。今までのお話を整理すると食事の量もそこそこ減ってきているし、無理のない食べ方も分かってきて、禁煙するなら今がチャンスだと感じていて、ニコチンパッチを活用してなら禁煙できそうかな！ということ。で、折角なので頑張られてみますか？　[SEP]ですね。まずはあれ（禁煙サポートプログラム）に申込んでパッチをもらうところから始めてみようかなっと。
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]タバコをやめたいという意志があることが伺えます。しかし、タバコをやめることで体重が増加することに対する不安が大きいようですね。過去に禁煙に成功した経験から、食事の量が増えることを経験しているため、それが再び起こるかもしれないという心配があるようです。[SEP]
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]タバコをやめた時の食事の美味しさを感じることについては、一つの課題となっています。食事がより美味しく感じられるために、過食傾向になる可能性があるということですね。しかし、現在の食事量が減っていることは、タバコをやめた際の体重増加のリスクを減らすことにつながりそうです。[SEP]
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]ニコチンパッチを使用することについて、前向きに考えているようです。パッチを使用することで、禁煙に挑戦し、同時に体重管理にも気をつけることが重要になりそうです。体重の増加を恐れることなく、健康的な方法で禁煙に取り組むことができれば、長期的に見て健康に良い影響を与えることになるでしょう。[SEP]
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]禁煙に向けての第一歩として、禁煙サポートプログラムに申し込み、ニコチンパッチを試すことを決めたのは素晴らしいことです。食事量の管理にも注意しながら、禁煙に成功するための支援を得ることが重要です。この取り組みは、あなたの健康改善に大きく貢献することになるでしょう。[SEP]
# [SEP]お薬について少しお尋ねしてもよろしいですか？[SEP]あ、はい。
# あ、はい。[SEP]お薬は指示通り飲めていますか？[SEP]あ、まぁ…
# あ、まぁ…[SEP]飲めないめないこともありますかね?[SEP]まぁ、そうですね。
# まぁ、そうですね。[SEP]あるんですね。別に責めるつもりはないんですよ。きちんと飲めた方が良いのかと思いまして。[SEP]そうですね。
# そうですね。[SEP]薬を飛ばしてしまうことがあっても困ることはないんですね。[SEP]実は、あんまり効果を感じてないんですよね。
# 実は、あんまり効果を感じてないんですよね。[SEP]そうなんですね。朝晩きちんと飲んでも、飛ばしてしまってもあまり変わらない。[SEP]はい。
# はい。[SEP]なんだかもったいないですね。せっかく飲んでるのに…[SEP]はぁ…
# はぁ…[SEP]そんなに気にならないですか?[SEP]いやぁ…
# いやぁ…[SEP]せっかくなら、ちゃんと効いてくれた方が良いのかと思って…[SEP]そうですね。お金も払ってるんで。
# そうですね。お金も払ってるんで。[SEP]薬が効かなくても、症状としてはそれほど気にならないんですね。[SEP]そういうわけじゃにんですけど、あきらめてますよね。悪くならないだけいいかって。
# そういうわけじゃにんですけど、あきらめてますよね。悪くならないだけいいかって。[SEP]確かにそうですね。悪くなっていないのは良いことですね。もっと効く方法があったら、なお良いという感じですかね。[SEP]そりゃそうですね。
# そりゃそうですね。[SEP]ですよね。医師はそのことについて何と言っているんですか？[SEP]何と言っているわけでもないですけど、薬が変わることもあれば、もう少し様子を見ようとなることもありますね。
# 何と言っているわけでもないですけど、薬が変わることもあれば、もう少し様子を見ようとなることもありますね。[SEP]そうですか。きちんと医師とお話はできてるんですね。最善は尽くしているという感じですね。[SEP]そうですね。
# そうですね。[SEP]もしかしたら、きちんと飲んでみると、効果も変わってくるんじゃないかと思うんですね。こちらで、定期的に薬が飲めるようにサポートすることもできますが、今日は、あと10分ぐらいお時間どうですか？[SEP]今日はちょっと難しいです。
# 今日はちょっと難しいです。[SEP]そうですか。それでは、またお時間あるときにお立ち寄りください。[SEP]はい。ぜひ。

# %% [markdown]
# まず、sep区切りしてから5分割して、5種類のデータセットを作成する。
#
# train、valid、testがそれぞれ5種類できたら、trainだけ水増しして、3つセットでp1～p5/datasetに放り込む。

# %%
def cross_validation_split(data, num_split):
    data_shuffled = data.sample(frac=1).reset_index(drop=True)  # DataFrameをシャッフル

    split_size = len(data) // num_split  # DataFrameの長さを5で割る

    split_data = []
    for i in range(0, len(data), split_size):
        split_data.append(data_shuffled.iloc[i:i + split_size])  # ランダムに5等分してリストに追加

    return split_data[:num_split]

num_split = 5
split_df = cross_validation_split(df_sep, num_split)

# %%
for i in range(len(split_df)):
    print(len(split_df[i]))
# Out:
# 44
# 44
# 44
# 44
# 44

# %%
train_df1 = pd.concat(split_df[0:3])
valid_df1 = split_df[3]
test_df1 = split_df[4]

train_df2 = pd.concat(split_df[1:4])
valid_df2 = split_df[4]
test_df2 = split_df[0]

train_df3 = pd.concat(split_df[2:])
valid_df3 = split_df[0]
test_df3 = split_df[1]

train_df4 = pd.concat([split_df[0], split_df[3], split_df[4]], ignore_index=True)
valid_df4 = split_df[1]
test_df4 = split_df[2]

train_df5 = pd.concat([split_df[0], split_df[1], split_df[4]], ignore_index=True)
valid_df5 = split_df[2]
test_df5 = split_df[3]

train_list = [train_df1, train_df2, train_df3, train_df4, train_df5]

# %% [markdown]
# これからtrain_listに各要素にMASKを施す。
#
# その前に、全発話を含んだdfから単語リストを作成する。

# %%
i = 0
csvlist = []
for file in filelist:
    if file.split(".")[1] == "csv":
        csvlist.append(file)
print(csvlist)
def tokenize_with_subwords_and_pos(text, tokenizer):
    tagger = fugashi.Tagger()
    # fugashiを使って形態素解析
    tokens_with_pos = [(word.surface, word.feature.pos1) for word in tagger(text)]
    # WordPieceトークナイザーを使ってサブワード分割
    subword_tokens_with_pos = [[], []]
    for token, pos_info in tokens_with_pos:
        subwords = tokenizer.tokenize(token)
        # サブワードごとにトークンと品詞情報のペアを作成
        for subword in subwords:
            subword_tokens_with_pos[0].append(subword)
            subword_tokens_with_pos[1].append(pos_info)
    return subword_tokens_with_pos

def tokenize_with_subwords_and_pos_v2(text, tokenizer):
    tagger = fugashi.Tagger()
    # fugashiを使って形態素解析
    tokens_with_pos = [(word.surface, word.feature.pos1) for word in tagger(text)]
    # WordPieceトークナイザーを使ってサブワード分割
    subword_tokens_with_pos = [[], []]
    for token, pos_info in tokens_with_pos:
        #トークンをさらにサブワードに分解
        subwords = tokenizer.tokenize(token)
        is_subword = False
        #サブワードに品詞をつける
        for subword in subwords:
            if "#" in subword:
                is_subword = True
        if is_subword:
            for subword in subwords:
                subword_tokens_with_pos[0].append(subword)
                subword_tokens_with_pos[1].append(pos_info)
        else:
            subword_tokens_with_pos[0].append(token)
            subword_tokens_with_pos[1].append(pos_info)
    return subword_tokens_with_pos
# Out:
# ['case1.csv', 'case2!.csv', 'case3.csv', 'case4.csv', 'case5!.csv', 'case6!.csv', 'case7.csv', 'case8!.csv', 'case9.csv']

# %%
word_list_from_tokenizer = {}
word_list_from_fugashi = {}
for key in csvlist:
    print(key)
    tmp_df = df[df["source"] == key]
    dialogues = tmp_df["dialogue"].str.strip("\u3000").tolist()
    sum_dialogues = "".join(dialogues)
    tokenized_dialogues = tokenize_with_subwords_and_pos_v2(sum_dialogues, tokenizer)
    word_list_from_fugashi[key] = tokenized_dialogues
    tokenized_dialogues_by_tokenizer = tokenizer.tokenize(sum_dialogues)
    word_list_from_tokenizer[key] = tokenized_dialogues_by_tokenizer
# Out:
# case1.csv
# case2!.csv
# case3.csv
# case4.csv
# case5!.csv
# case6!.csv
# case7.csv
# case8!.csv
# case9.csv

# %%
conversion_dict = {
    "たって": ["たっ", "##て"],
    "良さ": ["良", "##さ"],
    "取れれ": ["取れ", "##れ"],
    "なんか": ["なん", "##か"],
    "わかん": ["わか", "##ん"],
    "エイデンヘ": ["エイ", "##デン", "##ヘ"],
    "時々":["時", "々"],
    "よさ": ["よ", "##さ"],
    "借りれ": ["借り", "##れ"],
    "借りれる": ["借り", "##れる"],
    "ガッツン": ["ガッツ", "##ン"],
    "，":[","],
    "（":["("],
    "）":[")"],
    "１":["1"],
    "２":["2"],
    "１０":["10"],
    "3１":["31"],
    "３":["3"],
    "５":["5"],
    "？":["?"],
    "ＭＩ":["MI"],
    "㎏":["kg"],
    "…": [".", ".", "."],
    "！":["!"],
    "％":["%"],
    "｡":["。"],
    "－":["-"],
    "．":["."],
    "～":["~"]
}

# %%
new_word_list = {}
for key in csvlist:
    new_word_list[key] = [[], []]
    word_and_pos_in_file = word_list_from_fugashi[key]
    tmp_word_list = []
    tmp_pos_list = []
    for i in range(len(word_and_pos_in_file[0])):
        token = word_and_pos_in_file[0][i]
        pos = word_and_pos_in_file[1][i]
        if token in conversion_dict.keys():
            tokens = conversion_dict[token]
            for token in tokens:
                tmp_word_list.append(token)
                tmp_pos_list.append(pos)
        else:
            tmp_word_list.append(token)
            tmp_pos_list.append(pos)
    new_word_list[key] = [tmp_word_list, tmp_pos_list]

# %%
i = 0
csvlist = []
for file in filelist:
    if file.split(".")[1] == "csv":
        csvlist.append(file)
print(csvlist)
def tokenize_with_subwords_and_pos(text, tokenizer):
    tagger = fugashi.Tagger()
    # fugashiを使って形態素解析
    tokens_with_pos = [(word.surface, word.feature.pos1) for word in tagger(text)]
    # WordPieceトークナイザーを使ってサブワード分割
    subword_tokens_with_pos = [[], []]
    for token, pos_info in tokens_with_pos:
        subwords = tokenizer.tokenize(token)
        # サブワードごとにトークンと品詞情報のペアを作成
        for subword in subwords:
            subword_tokens_with_pos[0].append(subword)
            subword_tokens_with_pos[1].append(pos_info)
    return subword_tokens_with_pos

def tokenize_with_subwords_and_pos_v2(text, tokenizer):
    tagger = fugashi.Tagger()
    # fugashiを使って形態素解析
    tokens_with_pos = [(word.surface, word.feature.pos1) for word in tagger(text)]
    # WordPieceトークナイザーを使ってサブワード分割
    subword_tokens_with_pos = [[], []]
    for token, pos_info in tokens_with_pos:
        #トークンをさらにサブワードに分解
        subwords = tokenizer.tokenize(token)
        is_subword = False
        #サブワードに品詞をつける
        for subword in subwords:
            if "#" in subword:
                is_subword = True
        if is_subword:
            for subword in subwords:
                subword_tokens_with_pos[0].append(subword)
                subword_tokens_with_pos[1].append(pos_info)
        else:
            subword_tokens_with_pos[0].append(token)
            subword_tokens_with_pos[1].append(pos_info)
    return subword_tokens_with_pos
# Out:
# ['case1.csv', 'case2!.csv', 'case3.csv', 'case4.csv', 'case5!.csv', 'case6!.csv', 'case7.csv', 'case8!.csv', 'case9.csv']

# %%
word_list_from_tokenizer = {}
word_list_from_fugashi = {}
for key in csvlist:
    print(key)
    tmp_df = df[df["source"] == key]
    dialogues = tmp_df["dialogue"].str.strip("\u3000").tolist()
    sum_dialogues = "".join(dialogues)
    tokenized_dialogues = tokenize_with_subwords_and_pos_v2(sum_dialogues, tokenizer)
    word_list_from_fugashi[key] = tokenized_dialogues
    tokenized_dialogues_by_tokenizer = tokenizer.tokenize(sum_dialogues)
    word_list_from_tokenizer[key] = tokenized_dialogues_by_tokenizer
# Out:
# case1.csv
# case2!.csv
# case3.csv
# case4.csv
# case5!.csv
# case6!.csv
# case7.csv
# case8!.csv
# case9.csv

# %%
new_word_list = {}
for key in csvlist:
    new_word_list[key] = [[], []]
    word_and_pos_in_file = word_list_from_fugashi[key]
    tmp_word_list = []
    tmp_pos_list = []
    for i in range(len(word_and_pos_in_file[0])):
        token = word_and_pos_in_file[0][i]
        pos = word_and_pos_in_file[1][i]
        if token in conversion_dict.keys():
            tokens = conversion_dict[token]
            for token in tokens:
                tmp_word_list.append(token)
                tmp_pos_list.append(pos)
        else:
            tmp_word_list.append(token)
            tmp_pos_list.append(pos)
    new_word_list[key] = [tmp_word_list, tmp_pos_list]

# %%
def compute_bm25(documents, query, k1=2.0, b=0.75, csvlist=['case1.csv', 'case2!.csv', 'case3.csv', 'case4.csv', 'case5!.csv', 'case6!.csv', 'case7.csv', 'case8!.csv', 'case9.csv']):
    word_counts = {}  # 単語のカウントを格納する空の辞書
    # 各文書を処理して単語をカウントし、辞書に格納する
    for i, doc in enumerate(documents, 0):
        # 辞書に単語をカウントして格納
        word_count = {}
        for word in doc:
            if word not in word_count:
                word_count[word] = 1
            else:
                word_count[word] += 1

        # 各文書の単語カウントをword_countsに追加
        word_counts[csvlist[i]] = word_count
    # DataFrameに単語カウントを格納
    df = pd.DataFrame(word_counts).fillna(0).astype(int)
    #print(df)
    # 各文書の単語数を取得
    doc_lengths = df.sum(axis=0)
    #print(doc_lengths)
    # 全文書の平均単語数を計算
    avg_doc_length = doc_lengths.mean()
    #print(avg_doc_length)
    score_for_query = {}
    for word in query:
        print("computing...",word)
        scores = []
        word_series = df.loc[word]
        # IDF (Inverse Document Frequency)
        idf = math.log((len(df.columns) - word_series[word_series != 0].count() + 0.5) / (word_series[word_series != 0].count() + 0.5))
        #print(word, ":idf,",idf)
        for document in df.columns:
            doc = df.loc[:][document]
            doc_counter = dict(doc[doc != 0])  # 0でない値のみ取得して辞書に変換
            #print(doc_counter)
            # 各文書の単語数を取得
            doc_length = doc_lengths[document]
            # 各クエリの単語に対するBM25スコアを計算
            # TF (Term Frequency)
            tf = doc_counter.get(word, 0) / doc.sum()
            #print(document,word,":tf,",tf)
            # bm25 score
            if tf == 0:
                score = -1
            else:
                score = idf * ((tf * (k1 + 1)) / (tf + k1 * (1 - b + b * doc_length / avg_doc_length)))

            scores.append(score)
        score_for_query[word] = scores
    return score_for_query

# 例
documents = [
    "私は研究をしています。",
    "明日、ゼミで研究の進捗を発表します。",
    "明日はチキン弁当弁当を食べます。",
    "今日は研究と研究と研究をします。"*2
]

query = ["研究", "弁当", "明日", "を", "。", "今日"]

bm25_score = compute_bm25([tokenizer.tokenize(doc) for doc in documents], query)
for score in bm25_score:
    print(score, bm25_score[score], sep="\t")
# Out:
# computing... 研究
# computing... 弁当
# computing... 明日
# computing... を
# computing... 。
# computing... 今日
# 研究	[-0.17327377466439275, -0.09544481742937684, -1, -0.21243683542953806]
# 弁当	[-1, -1, 0.3244319320928727, -1]
# 明日	[-1, 0.0, 0.0, -1]
# を	[-0.4493359585806545, -0.24750882592735315, -0.4493359585806545, -0.19446629991453318]
# 。	[-0.4493359585806545, -0.24750882592735315, -0.4493359585806545, -0.19446629991453318]
# 今日	[-1, -1, -1, 0.07499045911581707]

# %%
#filelist
count = 0
incorrect_list = []
for key in csvlist:
    j = 0
    tokens_from_tokenizer = word_list_from_tokenizer[key]
    tokens_from_fugashi = new_word_list[key]
    print(key)
    for i in range(len(tokens_from_tokenizer)):    
        correct_token = tokens_from_tokenizer[i]
        my_token = tokens_from_fugashi[0][j]
        my_token_pos_info = tokens_from_fugashi[1][j]
        is_correct = correct_token == my_token

        if not is_correct:
            k = j + 1 if j+1 < len(tokens_from_fugashi[0]) else j
            l = j + 2 if j+2 < len(tokens_from_fugashi[0]) else j
            m = j + 3 if j+3 < len(tokens_from_fugashi[0]) else j
            n = j + 4 if j+4 < len(tokens_from_fugashi[0]) else j
            if tokens_from_fugashi[0][k] == correct_token:
                j = k
                #print(correct_token, tokens_from_fugashi[0][k], "True",  sep="\t")
                count -= 1
            elif tokens_from_fugashi[0][l] == correct_token:
                j = l
                #print(correct_token, tokens_from_fugashi[0][l], "True", sep="\t")
            elif tokens_from_fugashi[0][m] == correct_token:
                j = m
                #print(correct_token, tokens_from_fugashi[0][m], "True", sep="\t")

            else:
                incorrect_list.append((key, j, correct_token, my_token_pos_info))
                j -= 1
                print(correct_token, my_token, is_correct, sep="\t")
                print("前のトークン:", tokens_from_fugashi[0][j])
                count += 1


        else:
            #print(correct_token , my_token, is_correct, my_token_pos_info, sep="\t")
            a = 0
        j += 1
# Out:
# case1.csv
# case2!.csv
# case3.csv
# case4.csv
# ##と	と	False
# 前のトークン: ##え
# ##と	と	False
# 前のトークン: ##え
# な	なん	False
# 前のトークン: ,
# ん	なん	False
# 前のトークン: ,
# ##,	,	False
# 前のトークン: 々
# case5!.csv
# case6!.csv
# case7.csv
# case8!.csv
# case9.csv

# %%
print(incorrect_list)

for incorrect in incorrect_list:
    key = incorrect[0]
    index = incorrect[1]
    correct = incorrect[2]
    pos = incorrect[3]
    if correct != "ん" and correct != "##,":
        new_word_list[key][0][index] = correct
    elif correct == "##,":
        new_word_list[key][0][index+1] = correct 
    else:
        new_word_list[key][0].insert(index+1, correct)
        new_word_list[key][1].insert(index+1, pos)
# Out:
# [('case4.csv', 95, '##と', '助詞'), ('case4.csv', 486, '##と', '助詞'), ('case4.csv', 497, 'な', '代名詞'), ('case4.csv', 497, 'ん', '代名詞'), ('case4.csv', 1310, '##,', '補助記号')]

# %%
for key in csvlist:
    print(key)
    print(new_word_list[key][0] == word_list_from_tokenizer[key])
# Out:
# case1.csv
# True
# case2!.csv
# True
# case3.csv
# True
# case4.csv
# True
# case5!.csv
# True
# case6!.csv
# True
# case7.csv
# True
# case8!.csv
# True
# case9.csv
# True

# %%
docs = []
for key in csvlist:
    print(key)
    docs.append(new_word_list[key][0])
# Out:
# case1.csv
# case2!.csv
# case3.csv
# case4.csv
# case5!.csv
# case6!.csv
# case7.csv
# case8!.csv
# case9.csv

# %%
words_set = set()
stop_words = []
for i, doc in enumerate(docs):
    for word in doc:
        if word not in stop_words:
            words_set.add(word)
print(len(words_set))
print(words_set)
# Out:
# 1381
 'モチ', '申し', '学会', '##晩', '恐れ', 'そう', '毎月', 'れ', '闇', '進む', '寝', '仕', '##ゃく', '水曜', '協力', '手', '##き', 'ミー', '名前', '##水', '容易', 'チ', '第', '##急', '豊富', '会社', 'もらっ', '領域', '子', '対し', '誰', 'いずれ', '壊れ', 'な', '無駄', '肢', '器', 'サイズ', '達', '年金', '新', 'なん', 'です', '菱', '比べる', 'もらえる', '##ト', '持ち', '応用', '進める', '働く', '苦労', 'いっしょ', 'すご', '頻繁', '140', 'お', '終わっ', '乗り', '設定', '美味', '端', 'だっ', 'ブラック', '考慮', 'ましょう', 'イラ', '探し', '吸い', '元々', '食べ', '90', '医師', '##菜', 'しの', '非常', '経', 'など', '影響', '実質', '明るい', 'ながら', '休憩', '高める', '思い出', '##ン', '##,', '確信', 'かわり', '##ひ', '呼吸', '憂', 'エイ', '歩', '##腹', '新しい', '##す', 'せる', '転職', 'よろ', '向か', '##夫', '##て', '##費', 'MI', '##じ', '父', '意識', '##リング', '全て', '##よう', '代わり', '実', 'とる', '難しく', 'もし', '##り', '緩和', '多い', '改善', '発生', 'うん', '通り', 'か', '分け', '傾向', '##がん', 'トータル', 'むしろ', '多かっ', '両立', 'つき', '##がけ', 'すぐ', '分析', '##朝', '自信', 'アプローチ', '強い', '郵便', 'せよう', 'なく', '##帰り', '返済', 'カバー', '##しかっ', 'ガム', 'カード', '食べる', '患っ', 'たまたま', '将来', '##クター', '##テ', '任せ', '食', '##しい', 'いる', '次', '知れ', '場合', '思え', '過', '積極', '窓口', '##ックス', '身', '無い', '屋', '##そう', '使え', '買っ', '80', 'とにかく', '読む', '療法', 'に', '##据', 'よ', '文献', 'あの', '原因', '全く', '睡眠', '一方', '言う', 'ね', '耳', '思っ', '業', 'ござい', 'よく', '物', 'なお', 'た', '立つ', '近所', 'だい', '現実', '戻る', '生活', 'いか', '遅く', '朝', '時', '生き', 'キャリア', '学ん', '##けれ', '想像', '主な', '決断', '悩み', '準備', '友達', 'しろ', '充て', '選択', '大分', '人', '##ティング', '日々', '恐ろしい', '##ぎり', '##る', '抗', '##起', 'かなり', '給料', '遅れ', '##らしい', '進ま', 'いかに', '取っ', '製品', '低下', '死', 'すべて', '##年', 'まし', '言い', 'リラ', '現在', '大きく', 'ぬ', '胎児', '関する', '店', '治療', '修正', 'おっ', '努め', 'がん', '時間', 'ファ', '##慢', 'やはり', '##なた', 'トライ', '週', '聞く', 'より', '再度', 'ズボン', '産業', '飛ばし', 'プログラム', 'でしょう', '自身', '息子', '軽く', '合う', '書き', 'みんな', '取り組ん', '悩ん', 'あきら', '早く', '木曜', '多発 ...

# %%
words_extracted_by_pos = []
for key in csvlist:
    tmp_words = []
    print(key)
    words = new_word_list[key][0]
    pos_list = new_word_list[key][1]
    for i in range(len(words)):
        word = words[i]
        pos = pos_list[i]
        if pos=="名詞" or pos == "形容詞":
            tmp_words.append(word)
    words_extracted_by_pos.append(" ".join(tmp_words))
# Out:
# case1.csv
# case2!.csv
# case3.csv
# case4.csv
# case5!.csv
# case6!.csv
# case7.csv
# case8!.csv
# case9.csv

# %%
vectorizer = TfidfVectorizer(use_idf=True, stop_words=[])
tfidf = vectorizer.fit_transform(words_extracted_by_pos)

# %%
terms = vectorizer.get_feature_names_out()
print(terms.shape)
print(terms)
# Out:
# (517,)
# ['10' '100' '13' '140' '150' '20' '200' '30' '31' '72' '80' '90' 'an' 'mi'
#  'ok' 'あと' 'いい' 'いく' 'いっしょ' 'いま' 'うま' 'うまく' 'うめ' 'かっ' 'かわり' 'か月' 'がん' 'けれ'
#  'こと' 'しい' 'しかっ' 'しく' 'しろ' 'しん' 'すご' 'すごい' 'すば' 'すべて' 'せい' 'ぜん' 'そく' 'そば'
#  'たい' 'たばこ' 'ため' 'っち' 'つもり' 'とき' 'ところ' 'ない' 'なか' 'なかっ' 'なく' 'なけれ' 'なさ'
#  'のり' 'はず' 'ひと' 'ほう' 'ほし' 'ほしい' 'ほど' 'まし' 'まま' 'みんな' 'もっ' 'もの' 'もん' 'ゃく'
#  'やつ' 'やる' 'ゆえ' 'よう' 'よかっ' 'よく' 'よろ' 'らしい' 'わけ' 'アプローチ' 'イメージ' 'イラ' 'エア'
#  'エイ' 'エージェント' 'オプション' 'オン' 'カウンセ' 'カバー' 'カフェ' 'カル' 'カード' 'ガッツ' 'ガム'
#  'キャリア' 'キー' 'クター' 'グループ' 'コン' 'サイズ' 'サポート' 'シングル' 'スイッチ' 'スク' 'ストレス'
#  'スプレー' 'スーツ' 'ズボン' 'ゼロ' 'タバコ' 'チェック' 'チャレンジ' 'チャンス' 'チュ' 'チン' 'ックス'
#  'ティング' 'テイ' 'テレビ' 'テーマ' 'デン' 'トライ' 'トロ' 'トータル' 'ニコ' 'バランス' 'パッチ' 'ビタミン'
#  'ファ' 'ブラック' 'プログラム' 'ベーション' 'ペース' 'ホン' 'マイナス' 'マザー' 'マックス' 'ミー' 'モチ' 'ヤン'
#  'ライン' 'リスク' 'リズム' 'リラ' 'リング' 'レストラン' 'レパートリー' 'ローン' 'ワイン' 'ワークショップ' 'ーチ'
#  '一人' '一応' '一方' '一時' '一緒' '不安' '両立' '中心' '予約' '人生' '今年' '今後' '今日' '仕事'
#  '付き合い' '代わり' '代用' '以上' '以前' '休憩' '会社' '会話' '低下' '体調' '体重' '体験' '余裕' '作成'
#  '作業' '使い分け' '使用' '価値' '保健' '修正' '健康' '債務' '傾向' '優先' '元々' '先生' '先輩' '入社'
#  '全て' '全部' '具体' '内容' '再度' '冷蔵' '冷静' '処方' '出し' '分析' '切り' '初め' '利用' '前進'
#  '割り' '助け' '努力' '効果' '効率' '勇気' '勉強' '勝手' '医師' '半分' '協力' '危険' '原因' '厳しい'
#  '厳しく' '参加' '友達' '反対' '取り組み' '口腔' '吉野' '同時' '名前' '向上' '周り' '呼吸' '問題' '喫煙'
#  '国内' '場合' '場所' '増加' '変化' '夏休み' '多い' '多かっ' '多く' '多発' '大きい' '大きく' '大事' '失敗'
#  '女性' '妊娠' '姿勢' '嫌い' '子ども' '子供' '学会' '定時' '定期' '実施' '実質' '実践' '実際' '客観'
#  '家庭' '家族' '家電' '審査' '対処' '対応' '対策' '専門' '将来' '小さく' '少ない' '少なく' '工夫' '希望'
#  '帰り' '帰宅' '平日' '年度' '年金' '弁当' '強い' '当面' '影響' '心配' '必要' '応募' '応用' '怖い'
#  '思い' '思い出' '恐ろしい' '恩恵' '息子' '悩み' '悪い' '悪く' '情報' '想像' '意志' '意義' '意識' '感じ'
#  '感染' '感覚' '成功' '成長' '技術' '担当' '持ち帰' '指導' '指示' '挑戦' '挫折' '振り' '提案' '支払い'
#  '支援' '改善' '教科' '整理' '文献' '新しい' '方向' '方法' '方針' '旅行' '日々' '日中' '日常' '日本'
#  '早く' '明るい' '明るく' '時代' '時期' '時間' '普通' '曜日' '書類' '最初' '最近' '月曜' '期限' '木曜'
#  '本当' '検討' '業務' '楽し' '楽しい' '楽しく' '様子' '機会' '次回' '段階' '毎年' '毎日' '毎月' '気分'
#  '気持ち' '水曜' '決心' '決断' '治療' '法律' '注意' '活動' '活用' '海外' '満点' '満足' '準備' '火曜'
#  '点数' '無い' '無かっ' '無く' '無し' '無理' '無駄' '煙草' '熱中' '父母' '物質' '特定' '状態' '状況'
#  '現在' '現実' '現状' '現職' '理由' '理解' '環境' '生活' '産業' '申し' '疑問' '疾患' '症状' '療法'
#  '発揮' '発生' '目標' '目覚' '直面' '相談' '看護' '真剣' '睡眠' '瞬間' '破産' '確保' '確信' '確認'
#  '禁煙' '称賛' '程度' '積極' '窓口' '管理' '精神' '素晴らしい' '経験' '結局' '結果' '給料' '絶対' '継続'
#  '維持' '締め' '緩和' '繰り返し' '美味' '習慣' '考慮' '職場' '胎児' '脱出' '自信' '自分' '自己' '自然'
#  '自覚' '自身' '興味' '良い' '良かっ' '良く' '若い' '苦労' '英語' '薬物' '行き' '行動' '製品' '複数'
#  '要因' '見通し' '規定' '解決' '解消' '言い' '計画' '訪問' '設定' '証拠' '説明' '課題' '調整' '調節'
#  '講習' '負担' '貢献' '資料' '赤ちゃん' '転職' '軽く' '辺り' '近所' '返済' '退職' '途中' '通り' '連絡'
#  '遅い' '遅く' '運動' '過去' '達成' '選択' '部署' '郵便' '野菜' '金曜' '録画' '長期' '開発' '間違い'
#  '関係' '関連' '限り' '障壁' '障害' '難しい' '難しく' '電化' '電話' '項目' '順位' '領域' '食事' '食材'
#  '飲み' '高い' '高く']

# %%
scores = compute_bm25(docs, words_set)
# Out:
# computing... ます
# computing... ##シー
# computing... 遅
# computing... 英
# computing... 希望
# computing... もう
# computing... ば
# computing... 習っ
# computing... 半分
# computing... こ
# computing... しれ
# computing... たくさん
# computing... 先生
# computing... 伝わっ
# computing... 突
# computing... 言っ
# computing... 増加
# computing... 実施
# computing... 児
# computing... kg
# computing... リズム
# computing... 看護
# computing... 辺り
# computing... 行き
# computing... 律
# computing... ワークショップ
# computing... しまい
# computing... 良かっ
# computing... 落ち込ん
# computing... 聞き
# computing... 支払い
# computing... 旅行
# computing... 起こる
# computing... 折
# computing... 健康
# computing... わかり
# computing... きちんと
# computing... けれど
# computing... ##ぱ
# computing... 立ち
# computing... ##たい
# computing... 勧め
# computing... 録画
# computing... 後
# computing... とり
# computing... ##鼻
# computing... とても
# computing... でき
# computing... 入る
# computing... 広がり
# computing... 注意
# computing... ##ら
# computing... 国内
# computing... ・
# computing... ##ぇ
# computing... ##チン
# computing... おけ
# computing... 留
# computing... こう
# computing... 健
# computing... 噛
# computing... 検討
# computing... 子供
# computing... 時代
# computing... ##制
# computing... 問
# computing... 話
# computing... 貯
# computing... なら
# computing... 飽
# computing... 医
# computing... もちろん
# computing... べき
# computing... 課題
# computing... 気づく
# computing... わかっ
# computing... 高まる
# computing... 繋
# computing... 間に合わ
# computing... さらさ
# computing... 出し
# computing... ぎ
# computing... ニコ
# computing... ##リ
# computing... チェック
# computing... ##まし
# computing... いっ
# computing... タバコ
# computing... そろ
# computing... もん
# computing... 反対
# computing... 出来る
# computing... 兆
# computing... ##しゃ
# computing... 体重
# computing... ##しく
# computing... 立た
# computing... 通じ
# computing... 以前
# computing... 書い
# computing... オン
# computing... ##飽
# computing... ##an
# computing... せい
# computing... て
# computing... 中
# computing... 絶対
# computing... こんな
# computing... うまく
# computing... ほう
# computing... 退職
# computing... 見る
# computing... 努力
# computing... 思う
# computing... 躍
# computing... 予
# computing... 考える
# computing... よっ
# computing... 症状
# computing... けど
# computing... 減る
# computing... 自然
# computing... 前進
# computing... よかっ
# computing... 主に
# computing... 虫
# computing... あっ
# computing... “
# computing... 飲
# computing... のり
# computing... ##める
# computing... おい
# computing... キー
# computing... 太
# computing... 電話
# computing... 恩恵
# computing... よう
# computing... ##飯
# computing... 他
# computing... 感じ
# computing... K
# computing... すみ
# computing... 起こし
# computing... 様子
# computing... 障壁
# computing... 重要
# computing... 事
# computing... T
# computing... 並
# computing... ##と
# computing... ##欲
# computing... コ
# computing... 満点
# computing... ##口
# computing... 具体
# computing... ゆえ
# computing... の
# computing... 主
# computing... 加え
# computing... 感覚
# computing... が
# computing... 忙
# computing... 達成
# computing... おり
# computing... 自己
# computing... 書
# computing... いう
# computing... 何
# computing... かける
# computing... 受け
# computing... 不
# computing... さ
# computing... 実際
# computing... 彼
# computing... 結局
# computing... ##える
# computing... 思い出し
# computing... 保健
# computing... おも
# computing... ##談
# computing... 締め
# computing... 専門
# computing... 出来
# computing... 楽しい
# computing... ##張っ
# computing... ##や
# computing... いただ
# computing... 変わる
# computing... 育て
# computing... 瞬間
# computing... ##かす
# computing... 伝え
# computing... 好き
# computing... もたらし
# computing... ぁ
# computing... 通
# computing... 担当
# computing... 決め
# computing... ##ベーション
# computing... ##出し
# computing... あまり
# computing... メ
# computing... 今後
# computing... まず
# computing... 長期
# computing... 頑
# computing... 話し
# computing... 処方
# computing... ##振り
# computing... できれ
# computing... なかっ
# computing... 複数
# computing... 英語
# computing... 減
# computing... くる
# computing... 相談
# computing... 聞こえ
# computing... 大事
# computing... 手伝
# computing... 気持ち
# computing... か月
# computing... 場所
# computing... マザー
# computing... 期限
# computing... 起こっ
# computing... やり
# computing... 見通し
# computing... やら
# computing... 活用
# computing... たく
# computing... ##息
# computing... O
# computing... 可能
# computing... くれる
# computing... 上がっ
# computing... 下げ
# computing... 規定
# computing... C
# computing... ヘル
# computing... 追わ
# computing... 始め
# computing... ちゃ
# computing... 守る
# computing... 限り
# computing... 式
# computing... なき
# computing... うま
# computing... 厳しく
# computing... 聞か
# computing... ##計
# computing... 作業
# computing... いけ
# computing... 順位
# computing... 年度
# computing... 違う
# computing... ##が
# computing... 向上
# computing... 5
# computing... 今
# computing... 目指す
# computing... 過ぎ
# computing... 数
# computing... 中心
# computing... 人生
# computing... ##ーズ
# computing... 1
# computing... かかっ
# computing... す
# computing... 工夫
# computing... 極
# computing... ##コン
# computing... ##歯
# computing... しよう
# computing... 年
# computing... もっと
# computing... 火
# computing... ##切れ
# computing... 時期
# computing... 決心
# computing... 電化
# computing... -
# computing... 別れ
# computing... 困っ
# computing... られる
# computing... 関し
# computing... いや
# computing... ##食
# computing... パッチ
# computing... 来
# computing... 有
# computing... ##ー
# computing... 以上
# computing... ##ん
# computing... それ
# computing... なっ
# computing... ##する
# computing... でし
# computing... わから
# computing... ある
# computing... 吸
# computing... ##立ち
# computing... フル
# computing... ##角
# computing... ##っかり
# computing... 割り
# computing... 」
# computing... 難
# computing... 取り
# computing... ##力
# computing... と
# computing... 良く
# computing... まっ
# computing... やめ
# computing... 持ち帰
# computing... 取れ
# computing... 効果
# computing... 使い分け
# computing... 点数
# computing... さん
# computing... Z
# computing... 効か
# computing... ##ぁ
# computing... 余裕
# computing... 直面
# computing... よる
# computing... 業務
# computing... 成長
# computing... なか
# computing... 指示
# computing... 読
# computing... ぐらい
# computing... 家
# computing... ##込ん
# computing... こちら
# computing... 使う
# computing... 月曜
# computing... ##発
# computing... 見
# computing... ##刻
# computing... 妊娠
# computing... 習慣
# computing... 方
# computing... 起き
# computing... たっ
# computing... うめ
# computing... しん
# computing... 自
# computing... 私
# computing... なさ
# computing... 助け
# computing... 高く
# computing... ##ぐ
# computing... 父母
# computing... 取れる
# computing... 出
# computing... ##む
# computing... 来る
# computing... 面
# computing... 明るく
# computing... 足り
# computing... 無かっ
# computing... ##診
# computing... モチ
# computing... 申し
# computing... 学会
# computing... ##晩
# computing... 恐れ
# computing... そう
# computing... 毎月
# computing... れ
# computing... 闇
# computing... 進む
# computing... 寝
# computing... 仕
# computing... ##ゃく
# computing... 水曜
# computing... 協力
# computing... 手
# computing... ##き
# computing... ミー
# computing... 名前
# computing... ##水
# computing... 容易
# computing... チ
# computing... 第
# computing... ##急
# computing... 豊富
# computing... 会社
# computing... もらっ
# computing... 領域
# computing... 子
# computing... 対し
# computing... 誰
# computing... いずれ
# computing... 壊れ
# computing... な
# computing... 無駄
# computing... 肢
# computing... 器
# computing... サイズ
# computing... 達
# computing... 年金
# computing... 新
# computing... なん
# computing... です
# computing... 菱
# computing... 比べる
# computing... もらえる
# computing... ##ト
# computing... 持ち
# computing... 応用
# computing... 進める
# computing... 働く
# computing... 苦労
# computing... いっしょ
# computing... すご
# computing... 頻繁
# computing... 140
# computing... お
# computing... 終わっ
# computing... 乗り
# computing... 設定
# computing... 美味
# computing... 端
# computing... だっ
# computing... ブラック
# computing... 考慮
# computing... ましょう
# computing... イラ
# computing... 探し
# computing... 吸い
# computing... 元々
# computing... 食べ
# computing... 90
# computing... 医師
# computing... ##菜
# computing... しの
# computing... 非常
# computing... 経
# computing... など
# computing... 影響
# computing... 実質
# computing... 明るい
# computing... ながら
# computing... 休憩
# computing... 高める
# computing... 思い出
# computing... ##ン
# computing... ##,
# computing... 確信
# computing... かわり
# computing... ##ひ
# computing... 呼吸
# computing... 憂
# computing... エイ
# computing... 歩
# computing... ##腹
# computing... 新しい
# computing... ##す
# computing... せる
# computing... 転職
# computing... よろ
# computing... 向か
# computing... ##夫
# computing... ##て
# computing... ##費
# computing... MI
# computing... ##じ
# computing... 父
# computing... 意識
# computing... ##リング
# computing... 全て
# computing... ##よう
# computing... 代わり
# computing... 実
# computing... とる
# computing... 難しく
# computing... もし
# computing... ##り
# computing... 緩和
# computing... 多い
# computing... 改善
# computing... 発生
# computing... うん
# computing... 通り
# computing... か
# computing... 分け
# computing... 傾向
# computing... ##がん
# computing... トータル
# computing... むしろ
# computing... 多かっ
# computing... 両立
# computing... つき
# computing... ##がけ
# computing... すぐ
# computing... 分析
# computing... ##朝
# computing... 自信
# computing... アプローチ
# computing... 強い
# computing... 郵便
# computing... せよう
# computing... なく
# computing... ##帰り
# computing... 返済
# computing... カバー
# computing... ##しかっ
# computing... ガム
# computing... カード
# computing... 食べる
# computing... 患っ
# computing... たまたま
# computing... 将来
# computing... ##クター
# computing... ##テ
# computing... 任せ
# computing... 食
# computing... ##しい
# computing... いる
# computing... 次
# computing... 知れ
# computing... 場合
# computing... 思え
# computing... 過
# computing... 積極
# computing... 窓口
# computing... ##ックス
# computing... 身
# computing... 無い
# computing... 屋
# computing... ##そう
# computing... 使え
# computing... 買っ
# computing... 80
# computing... とにかく
# computing... 読む
# computing... 療法
# computing... に
# computing... ##据
# computing... よ
# computing... 文献
# computing... あの
# computing... 原因
# computing... 全く
# computing... 睡眠
# computing... 一方
# computing... 言う
# computing... ね
# computing... 耳
# computing... 思っ
# computing... 業
# computing... ござい
# computing... よく
# computing... 物
# computing... なお
# computing... た
# computing... 立つ
# computing... 近所
# computing... だい
# computing... 現実
# computing... 戻る
# computing... 生活
# computing... いか
# computing... 遅く
# computing... 朝
# computing... 時
# computing... 生き
# computing... キャリア
# computing... 学ん
# computing... ##けれ
# computing... 想像
# computing... 主な
# computing... 決断
# computing... 悩み
# computing... 準備
# computing... 友達
# computing... しろ
# computing... 充て
# computing... 選択
# computing... 大分
# computing... 人
# computing... ##ティング
# computing... 日々
# computing... 恐ろしい
# computing... ##ぎり
# computing... ##る
# computing... 抗
# computing... ##起
# computing... かなり
# computing... 給料
# computing... 遅れ
# computing... ##らしい
# computing... 進ま
# computing... いかに
# computing... 取っ
# computing... 製品
# computing... 低下
# computing... 死
# computing... すべて
# computing... ##年
# computing... まし
# computing... 言い
# computing... リラ
# computing... 現在
# computing... 大きく
# computing... ぬ
# computing... 胎児
# computing... 関する
# computing... 店
# computing... 治療
# computing... 修正
# computing... おっ
# computing... 努め
# computing... がん
# computing... 時間
# computing... ファ
# computing... ##慢
# computing... やはり
# computing... ##なた
# computing... トライ
# computing... 週
# computing... 聞く
# computing... より
# computing... 再度
# computing... ズボン
# computing... 産業
# computing... 飛ばし
# computing... プログラム
# computing... でしょう
# computing... 自身
# computing... 息子
# computing... 軽く
# computing... 合う
# computing... 書き
# computing... みんな
# computing... 取り組ん
# computing... 悩ん
# computing... あきら
# computing... 早く
# computing... 木曜
# computing... 多発
# computing... 欠
# computing... ぜん
# computing... ##張
# computing... 気分
# computing... 使用
# computing... デン
# computing... ##ヘ
# computing... 管理
# computing... くれ
# computing... この
# computing... すば
# computing... 調整
# computing... 調節
# computing... も
# computing... 方法
# computing... 際
# computing... ペース
# computing... 実践
# computing... A
# computing... ##イラ
# computing... ##返り
# computing... OK
# computing... ##立っ
# computing... 教科
# computing... させ
# computing... 少なく
# computing... 良好
# computing... 価値
# computing... 多く
# computing... ##味
# computing... 本当
# computing... 20
# computing... 特定
# computing... ##れ
# computing... どれ
# computing... 途中
# computing... すごい
# computing... とも
# computing... 使わ
# computing... み
# computing... ##金
# computing... ##構
# computing... で
# computing... 同時
# computing... 減っ
# computing... ##し
# computing... 職場
# computing... 冷蔵
# computing... 程度
# computing... みたい
# computing... 曜日
# computing... 自覚
# computing... わ
# computing... つけ
# computing... トロ
# computing... マックス
# computing... き
# computing... できる
# computing... 食材
# computing... 禁煙
# computing... 平日
# computing... 100
# computing... サポート
# computing... 間
# computing... 質
# computing... 試
# computing... め
# computing... 作成
# computing... ##位
# computing... 対処
# computing... 再び
# computing... まで
# computing... 月
# computing... つながる
# computing... ##切り
# computing... 品
# computing... カウンセ
# computing... 君
# computing... ##テイ
# computing... ##つ
# computing... 150
# computing... そば
# computing... 取り組み
# computing... 変
# computing... 振り
# computing... 見つけ
# computing... みる
# computing... わけ
# computing... ストレス
# computing... 出さ
# computing... 伴い
# computing... 疑問
# computing... なんて
# computing... あなた
# computing... がち
# computing... 関連
# computing... 72
# computing... スク
# computing... 嬉
# computing... れる
# computing... バランス
# computing... 読み
# computing... 悪く
# computing... 願
# computing... 振
# computing... 取り組む
# computing... 通し
# computing... ##期
# computing... せ
# computing... ちゃっ
# computing... 周り
# computing... もの
# computing... ##腫
# computing... ほしい
# computing... ##つい
# computing... 状態
# computing... どう
# computing... 除い
# computing... 示し
# computing... は
# computing... なけれ
# computing... 大きな
# computing... ##合っ
# computing... 目標
# computing... 別
# computing... ##気
# computing... つながり
# computing... 大胆
# computing... 訪問
# computing... 行動
# computing... ##丈
# computing... 要因
# computing... 結果
# computing... ホン
# computing... 例えば
# computing... 冷静
# computing... 肺
# computing... ##々
# computing... 遅い
# computing... ”
# computing... 尋ね
# computing... 向け
# computing... 十分
# computing... あり
# computing... ところ
# computing... 抱え
# computing... 債務
# computing... ##か
# computing... 項目
# computing... たち
# computing... 違っ
# computing... 今年
# computing... 間違い
# computing... 味
# computing... 飲む
# computing... ##耳
# computing... 道
# computing... 障害
# computing... やる
# computing... 変わっ
# computing... 性
# computing... 厳しい
# computing... 変わら
# computing... ##ッ
# computing... 変化
# computing... ##シ
# computing... シングル
# computing... 確実
# computing... 貢献
# computing... さまざま
# computing... 関係
# computing... いえ
# computing... 向き
# computing... ない
# computing... そこ
# computing... 使っ
# computing... 小
# computing... 願い
# computing... ##ま
# computing... 会
# computing... 減らす
# computing... 姿勢
# computing... 続け
# computing... いく
# computing... 引っ
# computing... 怖い
# computing... 応募
# computing... すら
# computing... 7
# computing... ##ぶ
# computing... ほど
# computing... 高め
# computing... 使
# computing... 役立つ
# computing... 資料
# computing... 疾患
# computing... いき
# computing... 「
# computing... 決める
# computing... 自分
# computing... 解決
# computing... これ
# computing... さす
# computing... 効
# computing... 金
# computing... 物質
# computing... 環境
# computing... ローン
# computing... 付け
# computing... 思
# computing... つける
# computing... 会話
# computing... 機会
# computing... 負わ
# computing... ##乏
# computing... ##あ
# computing... 、
# computing... つい
# computing... 楽しく
# computing... 入っ
# computing... 法律
# computing... 水
# computing... 理解
# computing... ##まら
# computing... カフェ
# computing... 内
# computing... 日中
# computing... 変わり
# computing... 立っ
# computing... どの
# computing... 落ち
# computing... 脱出
# computing... 改めて
# computing... わかる
# computing... 大変
# computing... 難しい
# computing... ##がっ
# computing... 局
# computing... 関わら
# computing... 定時
# computing... 研
# computing... 持て
# computing... 小さく
# computing... 理由
# computing... 講
# computing... チャレンジ
# computing... 現状
# computing... 々
# computing... なる
# computing... こそ
# computing... 今日
# computing... また
# computing... ##治
# computing... 代
# computing... 昔
# computing... 優先
# computing... ん
# computing... 内容
# computing... カル
# computing... はじめ
# computing... 9
# computing... 量
# computing... 盛
# computing... 海外
# computing... 熱中
# computing... ##上げ
# computing... 200
# computing... 所
# computing... つもり
# computing... にくい
# computing... ごく
# computing... 得る
# computing... ##い
# computing... はい
# computing... 指導
# computing... 確保
# computing... 勝手
# computing... 分から
# computing... ぜ
# computing... 30
# computing... エア
# computing... 3
# computing... ##さり
# computing... へ
# computing... 特に
# computing... ##b
# computing... ##日
# computing... 先輩
# computing... やつ
# computing... 言わ
# computing... きれ
# computing... 症
# computing... 飲ん
# computing... ぉ
# computing... ##勤
# computing... 現職
# computing... レパートリー
# computing... 代用
# computing... ##膜
# computing... P
# computing... くらい
# computing... 一番
# computing... もっ
# computing... ##ツ
# computing... ちゃんと
# computing... エージェント
# computing... 小さな
# computing... 割
# computing... 満足
# computing... 点
# computing... 計画
# computing... 暑
# computing... ##盛
# computing... ,
# computing... ##しろ
# computing... あれ
# computing... 尽く
# computing... たま
# computing... グループ
# computing... ##た
# computing... 帰宅
# computing... 日常
# computing... 当面
# computing... たばこ
# computing... 上
# computing... なくなっ
# computing... 早
# computing... 弁当
# computing... 意義
# computing... !
# computing... 継続
# computing... 無し
# computing... 同じ
# computing... 買う
# computing... 初め
# computing... 心
# computing... 増やし
# computing... 払っ
# computing... 的
# computing... 覚え
# computing... いつ
# computing... スーツ
# computing... 開発
# computing... 車
# computing... ー
# computing... ほぼ
# computing... 法
# computing... ガッツ
# computing... スム
# computing... 傍
# computing... ##せる
# computing... .
# computing... 飲み
# computing... 通っ
# computing... ただ
# computing... 一
# computing... 貸し
# computing... 体験
# computing... 行け
# computing... 最近
# computing... 煙草
# computing... ##生
# computing... ブ
# computing... い
# computing... 付き合い
# computing... 真剣
# computing... 情報
# computing... 考え
# computing... つ
# computing... 薬物
# computing... 繰り返し
# computing... 無く
# computing... ##やす
# computing... ##れる
# computing... 技術
# computing... ?
# computing... ##わ
# computing... 問題
# computing... 見れ
# computing... 前
# computing... 木
# computing... だけ
# computing... 新た
# computing... たら
# computing... ##訳
# computing... 取ら
# computing... 目覚
# computing... 発揮
# computing... ##かく
# computing... 額
# computing... ##う
# computing... ##ヤン
# computing... 証拠
# computing... 生まれ
# computing... てる
# computing... 作っ
# computing... 被
# computing... 喫煙
# computing... 女性
# computing... ##ろ
# computing... 避け
# computing... だろう
# computing... 困
# computing... ちょっと
# computing... って
# computing... 心配
# computing... 聞い
# computing... 行う
# computing... 最初
# computing... う
# computing... 費
# computing... られ
# computing... 負担
# computing... 行く
# computing... 。
# computing... 2
# computing... ##入
# computing... 知り
# computing... 薬
# computing... 増える
# computing... あ
# computing... ##ご
# computing... こと
# computing... 特別
# computing... 本
# computing... しばらく
# computing... 活動
# computing... ワイン
# computing... 増え
# computing... テレビ
# computing... まだ
# computing... 親
# computing... ま
# computing... とき
# computing... 母
# computing... オプション
# computing... ##らせ
# computing... ##ほど
# computing... 感じる
# computing... 8
# computing... もらい
# computing... ##薬
# computing... 知っ
# computing... ずっと
# computing... 高
# computing... ##y
# computing... 食事
# computing... 与える
# computing... ら
# computing... 役
# computing... あげ
# computing... なかなか
# computing... はっきり
# computing... 解消
# computing... 31
# computing... 進め
# computing... 休
# computing... 我
# computing... 終え
# computing... 維持
# computing... 含ん
# computing... どこ
# computing... ##まり
# computing... ##昔
# computing... 破産
# computing... 策
# computing... 減らし
# computing... 成功
# computing... ず
# computing... する
# computing... ##産
# computing... 戻っ
# computing... そん
# computing... ##おう
# computing... 危険
# computing... ##く
# computing... %
# computing... 毎年
# computing... いま
# computing... 合わ
# computing... ##め
# computing... 挑戦
# computing... 起
# computing... 良
# computing... ##さ
# computing... たまに
# computing... 申
# computing... 分かっ
# computing... しっかり
# computing... 高い
# computing... 状況
# computing... 万
# computing... たり
# computing... 気
# computing... 淡
# computing... や
# computing... 火曜
# computing... なれる
# computing... 勇気
# computing... ##かっ
# computing... し
# computing... 子ども
# computing... 提案
# computing... 煙
# computing... 湯
# computing... 置い
# computing... 6
# computing... 日本
# computing... 炎
# computing... 赤ちゃん
# computing... 伺
# computing... 日
# computing... 利用
# computing... 前向き
# computing... 10
# computing... ##覚
# computing... ませ
# computing... ちょうど
# computing... 興味
# computing... ##ゃ
# computing... 金曜
# computing... 野菜
# computing... 少し
# computing... はず
# computing... 結
# computing... 大きい
# computing... 楽し
# computing... 勉強
# computing... ##寝
# computing... 過去
# computing... ##限
# computing... ##ぅ
# computing... 続ける
# computing... レストラン
# computing... くだ
# computing... ##デン
# computing... 整理
# computing... 挫折
# computing... 先
# computing... ありがとう
# computing... せっ
# computing... 帰る
# computing... 目指し
# computing... マイナス
# computing... チャンス
# computing... 一人
# computing... 活
# computing... 持っ
# computing... 部署
# computing... 就く
# computing... しまっ
# computing... 素晴らしい
# computing... 余
# computing... 迷
# computing... さら
# computing... その
# computing... 審査
# computing... ##合う
# computing... ##らっ
# computing... 客観
# computing... 明確
# computing... 書類
# computing... 簡単
# computing... そんな
# computing... ビタミン
# computing... 運動
# computing... え
# computing... まま
# computing... 0
# computing... 無理
# computing... 予約
# computing... テーマ
# computing... ど
# computing... しかし
# computing... 仕事
# computing... 方向
# computing... わか
# computing... どんどん
# computing... 全部
# computing... から
# computing... 体調
# computing... 夜
# computing... いい
# computing... たい
# computing... 次回
# computing... 保つ
# computing... 口腔
# computing... 必要
# computing... ##よ
# computing... 惣
# computing... スプレー
# computing... 様
# computing... やっ
# computing... 誘っ
# computing... 連絡
# computing... 嫌い
# computing... ##え
# computing... ご
# computing... いろいろ
# computing... 精神
# computing... 良い
# computing... ゆう
# computing... ##ぶん
# computing... ずつ
# computing... 13
# computing... 思い
# computing... 借り
# computing... 最
# computing... スイッチ
# computing... かけ
# computing... 一緒
# computing... 者
# computing... ひと
# computing... 過ごし
# computing... そ
# computing... 家電
# computing... 不安
# computing... ##速
# computing... (
# computing... ここ
# computing... ##分け
# computing... る
# computing... 外
# computing... ##ろう
# computing... 回
# computing... 行い
# computing... 称賛
# computing... 使い
# computing... リスク
# computing... 見つける
# computing... ため
# computing... 指
# computing... 意志
# computing... 上げる
# computing... 参加
# computing... 失敗
# computing... ##寄り
# computing... 抑え
# computing... あん
# computing... 吉野
# computing... しまう
# computing... なり
# computing... 色々
# computing... 鼓
# computing... 逆
# computing... すぎ
# computing... 定期
# computing... 作る
# computing... どんな
# computing... 感染
# computing... とっ
# computing... 効率
# computing... 比べ
# computing... ##そく
# computing... 家庭
# computing... ガー
# computing... ##月
# computing... 一応
# computing... ##こ
# computing... ほし
# computing... 就
# computing... 夏休み
# computing... 入れ
# computing... なに
# computing... 息
# computing... っ
# computing... 悪い
# computing... 望ま
# computing... そして
# computing... 風
# computing... ##っ
# computing... 辺
# computing... 度
# computing... ##ず
# computing... ##そ
# computing... を
# computing... ##送
# computing... 少ない
# computing... 悩
# computing... 疲れ
# computing... 経験
# computing... だ
# computing... 受ける
# computing... 対応
# computing... ライン
# computing... 確認
# computing... 対策
# computing... 起きる
# computing... ##ーチ
# computing... 責め
# computing... ください
# computing... いら
# computing... ##げ
# computing... 庫
# computing... さえ
# computing... 笑
# computing... 毎日
# computing... 段階
# computing... じゃ
# computing... 入社
# computing... 尽くし
# computing... 家族
# computing... 鍵
# computing... 方針
# computing... ##直し
# computing... )
# computing... 大
# computing... ##っち
# computing... 退
# computing... 値
# computing... ##んな
# computing... ゼロ
# computing... いろ
# computing... ##込み
# computing... 一時
# computing... ##せ
# computing... とれ
# computing... 嫌
# computing... 働き
# computing... チュ
# computing... 講習
# computing... 対する
# computing... ~
# computing... 支援
# computing... ##善
# computing... あと
# computing... 説明
# computing... 分
# computing... ちょ
# computing... もらう
# computing... 若い
# computing... ##直
# computing... 怖
# computing... 得
# computing... イメージ
# computing... 力
# computing... 大切
# computing... 普通
# computing... 確か

# %%
scores_df = pd.DataFrame.from_dict(scores, orient="index", columns=csvlist)

# %%
def extract_largest_values(lst, num_values):
    # 数値のみを含むリストを作成し、それぞれの値とインデックスを保持するタプルのリストを生成します
    numeric_list = [(val, idx) for idx, val in enumerate(lst) if isinstance(val, (int, float))]

    # 数値の大きい順にソートします
    sorted_numeric_list = sorted(numeric_list, key=lambda x: x[0], reverse=True)

    # 指定された数だけ大きい値とそのインデックスを抽出します
    largest_values = sorted_numeric_list[:num_values]

    return largest_values

# テスト用のリスト
numbers_list = [10, 5, 8, 20, 3, 12, 9]

# 例として、3つの最大値を取得します
result = extract_largest_values(numbers_list, 3)
print("取り出した最大の数値とそのインデックス:", result)
# Out:
# 取り出した最大の数値とそのインデックス: [(20, 3), (12, 5), (10, 0)]

# %%
def mask_func(text, scores, file_name, csvlist, mask_num):
    scorelist = []
    for i, f in enumerate(csvlist):
        if f == file_name:
            file_number = i
            break
        file_number = None
    #print(file_number)
    maskword_indices = []
    masked_indices = []
    tokenized_text = tokenizer.tokenize(text)
    if mask_num > len(tokenized_text):
        mask_num = len(tokenized_text)
    for i, token in enumerate(tokenized_text):
        #print(token, end="\t")
        if token not in scores.keys():
            #print("ないよ")
            scorelist.append(-1)
            continue
        else:
            scorelist.append(scores[token][file_number])
    maskids = [item[1] for item in extract_largest_values(scorelist, mask_num)]
    masktokens = [tokenized_text[i] for i in maskids]
    label = [-100]*len(tokenized_text)
    #print(mask_num)
    #print(masktokens)
    for i in range(mask_num):
        masktoken = masktokens[i]
        maskid = maskids[i]
        maskword_id = tokenizer.encode(masktoken, add_special_tokens=False)[0]
        maskword_indices.append(maskword_id)
        tokenized_text[maskid] = "[MASK]"
    masked_text = "".join(tokenized_text).replace("#", "")
    assert all([tokenized_text[idx]==4] for idx in maskids)
    print(text,"->",masked_text)
    return masked_text, maskword_indices


mask_func("勉強をもっとしたいという気持ちがある。",scores, "case2!.csv", csvlist, 4)
# Out:
# 勉強をもっとしたいという気持ちがある。 -> [MASK]を[MASK]し[MASK]という[MASK]がある。
# ('[MASK]を[MASK]し[MASK]という[MASK]がある。', [17372, 14924, 16716, 13030])

# %%
def mask_func_tfidf(text, tfidf, terms,  file_name, csvlist, mask_num):
    for i, f in enumerate(csvlist):
        if f == file_name:
            file_number = i
            break
        file_number = None
    tokenized_text = tokenizer.tokenize(text)
    scorelist = []
    for i, token in enumerate(tokenized_text):
        scorelist.append(-1)
        for j, term in enumerate(terms):
            if token == term:
                #print(term)
                #print(tfidf.toarray()[file_number, j])
                scorelist[i] = tfidf.toarray()[file_number, j]
    #print(scorelist)
    maskids = [item[1] for item in extract_largest_values(scorelist, mask_num) if item[0]!=-1]
    #print(maskids)
    maskedtokenids = [tokenizer.encode(tokenized_text[i], add_special_tokens=False)[0] for i in maskids]
    #print(maskedtokenids)
    for i in maskids:
        tokenized_text[i] = "[MASK]"
    if len(maskids) == 0:
        tokenized_text[0] = "[MASK]"
    masked_text = "".join(tokenized_text).replace("#", "")
    print(text,"->",masked_text)
    return masked_text, maskedtokenids

mask_func_tfidf("勉強をもっとしたいという気持ちがある。", tfidf, terms, "case2!.csv", csvlist, 2)
# Out:
# 勉強をもっとしたいという気持ちがある。 -> [MASK]をもっとしたいという[MASK]がある。
# ('[MASK]をもっとしたいという[MASK]がある。', [17372, 16716])

# %%
print(scores["、"])
# Out:
# [-0.12139338555484759, -0.24272193565421582, -0.07437044470704163, -0.013896433819254896, -0.6683960203887427, -0.1905626293003717, -0.18367859174538276, -0.17835239564872551, -0.3098566224025908]

# %%
print(mask_func_tfidf("やる気を高めて転職活動を行い、来年度からは新しい職場で働きたいわけですね。", tfidf, terms, "case1.csv", csvlist, 2))
# Out:
# やる気を高めて転職活動を行い、来年度からは新しい職場で働きたいわけですね。 -> やる気を高めて[MASK][MASK]を行い、来年度からは新しい職場で働きたいわけですね。
# ('やる気を高めて[MASK][MASK]を行い、来年度からは新しい職場で働きたいわけですね。', [27016, 12636])

# %%
def create_masked_dataset(train_list, mask_num, method, mask_client_dialogue, scores=scores, tfidf=tfidf, terms=terms):
    max_token_length = 300
    masked_train_list = {}

    for i, train in enumerate(train_list):
        key_name = "train" + str(i)
        masked_train_list[key_name] = []
        for series in train.iloc:
            source = series["source"]
            miti_code = series["miti_code"]
            if mask_client_dialogue:
                dialogue = series["sentence"]
            else:
                dialogue_cl1, dialogue = series["sentence"].split("[SEP]")

            if method == "tfidf":
                masked_dialogue, maskword_ids = mask_func_tfidf(dialogue, tfidf, terms, source, csvlist, mask_num=mask_num)
            elif method == "bm25":
                masked_dialogue, maskword_ids = mask_func(dialogue, scores, source, csvlist, mask_num=mask_num) 
            if mask_client_dialogue:
                masked_sentence = masked_dialogue
            else:             
                masked_sentence = dialogue_cl1 + "[SEP]" + masked_dialogue
            #print(masked_sentence)
            ids_for_assertion = tokenizer(masked_sentence)["input_ids"]
            masked_ids = [i for i in range(len(ids_for_assertion)) if ids_for_assertion[i] == 4]
            if len(masked_ids) >= 2:
                #assert all([label==-100 if idx!=masked_ids[0] or idx!=masked_ids[1] else label!=-100 for idx, label in enumerate(labels)])
                assert all([ids_for_assertion[idx] == 4 for idx in masked_ids])
            else:
                #assert all([label==-100 if idx!=masked_ids[0] else label!=-100 for idx, label in enumerate(labels)])
                assert ids_for_assertion[masked_ids[0]]==4

            masked_train_list[key_name].append({"sentence":series["sentence"],"masked_sentence":masked_sentence, "labels":[], "miti_code":miti_code,  "maskword_id":maskword_ids, "masked_ids":masked_ids, "source":source})
    return masked_train_list
    
masked_train_list = create_masked_dataset(train_list, n_masks, mask_method, mask_client_dialogue)
# Out:
# 思う。[SEP]こうやって今日もいらっしゃったんですけど、もっとやりたいというのがあって、これからも、こういう会に参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど
立たないかもしれないという思いもある一方で、やった方がいいと感じる気持ちが少し大きいということですね。楽しく勉強できる環境があれば、もっと前向きになれるかもしれません。[SEP] -> わからない。[SEP][MASK]を続けたいという思いはあるものの、[MASK]での使用[MASK]がないため、[MASK]なくてもいいのではという気持ちがあるということですね。[MASK]に立たないかもしれないという思いもある一方で、やった方がいいと感じる気持ちが少し大きいということですね。[MASK][MASK]できる[MASK]があれば、もっと前向きになれるかもしれません。[SEP]
# えぇ[SEP]やりたいという気持ちがあると最初におっしゃっていたのですが、やったらどんないいことがあると思いますか[SEP]出来てるかわからないけど、自分が成長してる気がするし。する。自分のことも知れる。かな。 -> え[MASK][SEP][MASK]たいという気持ちがあると[MASK]に[MASK][MASK]っていたのですが、やったらどんないいことがあると思いますか[SEP][MASK]てるかわからないけど、自分が[MASK]してる気がするし。する。自分のことも[MASK]る。かな。
# そうですね。あのー債務整理も勧められてるんですけどもまだそこはためらっていてそれでお金また借りれるとこないかなと思っています。[SEP]お金を借りる所を探してこれ以上使わない方が良いと思うけれども探してしまっている状況。[SEP]はい。 -> そうですね。あのー[MASK][MASK]も勧められてるんですけどもまだそこはため[MASK]ていてそれでお[MASK]また[MASK]れるとこないかなと思っています。[SEP]お[MASK]を[MASK]る所を[MASK]てこれ以上使わない方が良いと思うけれども探してしまっている状況。[SEP]はい。
# わかっています。わかっています。聞いたことがあるし，以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの？すごく難しい。[SEP]そうね，今までのような苦労をしなくてもあなたが利用できるものがあります｡ニコチン代用品、パッチや，トローチ，ガム，吸入器，スプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬）にトライするのであれば，薬物治療について話をすることができます。禁煙グループへの参加もできますし，電話相談窓口もありますし…。[SEP]とにかくそれをする時間がない… -> わかっています。わかっています。聞いたことがあるし[MASK]以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの?すごく難しい。[SEP]そうね[MASK]今までのような苦労をしなくてもあなたが利用できるものがあります。ニコチン代用品、パッチや[MASK]トローチ[MASK]ガム[MASK]吸入器[MASK]スプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬)にトライするのであれば[MASK]薬物治療について話をすることができます。禁煙グループへの参加もできますし[MASK]電話相談窓口もありますし...。[SEP]とにかくそれをする時間がない...
# そうですね。[SEP]やっぱり、寝るのが遅くなるっていうのは、色々やることがあったりするんだね。[SEP]そうですね。それだけのせいではないですが、仕事を持ち帰っていることも多いですかね。 -> そうですね。[SEP]やっ[MASK]り、[MASK]るのが[MASK]なるっていうのは、[MASK][MASK]ことがあったりするんだね。[SEP]そうですね。それだけの[MASK]ではないですが、仕事を[MASK]っていることも[MASK]ですかね。
# 重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。1日1時間転職活動のために時間を使うのは、今のAさんにとって、とても重要だということですね。[SEP]はい。 -> 重要度でいうと、[MASK]とか[MASK]とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。[MASK][MASK][MASK]時間[MASK][MASK]のために時間を[MASK]のは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# そう。ご飯を普通に200に抑えていたのに、おかわり！！って、言って。[SEP]じゃぁ、食べ過ぎている傾向にあって、それを経験しているがゆえに、やっぱこう、タバコをやめちゃうと体重増えちゃうかなって。　[SEP]そう。怖いっていう。 -> そう。ご[MASK]を普通に200に抑えていたのに、おかわり!!って、言って。[SEP]じゃぁ、[MASK][MASK]ている傾向にあって、それを経験しているがゆえに、やっぱこう、[MASK]を[MASK]ちゃうと[MASK][MASK]ちゃうかなって。[SEP]そう。[MASK]っていう。
# [SEP]お薬について少しお尋ねしてもよろしいですか？[SEP]あ、はい。 -> [SEP]お[MASK]に[MASK]て[MASK]お[MASK]しても[MASK][MASK]ですか?[SEP][MASK]、[MASK]。
# わかりません，今考えてみてもどのようにしたかすら覚えてないんです。でも，とにかくやったんです。私，想像できなかったの。タバコを吸う女性の赤ちゃんが死産になるとか，早産になるとか，また，障害児として生まれてくるなんてことを。だからもう飽き飽きするほど言われたでしよ。
# はい。[SEP]あなたは、仕事の日に発生する突発的な業務や、疲れて帰宅した日に作業時間が取れないという課題に直面しています。しかし、帰宅途中にカフェやレストランで時間を作るという具体的な対策を考えていて、このアプローチにより転職活動における自信度が高まると感じているようです。[SEP]はい。 -> はい。[SEP]あなたは、仕事の[MASK]に発生する突発的な業務や、疲れて[MASK]した[MASK]に[MASK]時間が取れないという課題に直面しています。しかし、[MASK][MASK]にカフェやレストランで時間を作るという具体的な対策を考えていて、このアプローチにより[MASK][MASK]における自信度が高まると感じているようです。[SEP]はい。
# そうですね。気をつけてはいるんですが、なかなか起きられなくて。[SEP]そっか。朝が起きられればってところか。[SEP]そうなんですよね。 -> そうですね。気を[MASK]てはいるんですが、[MASK][MASK]られなくて。[SEP][MASK]っか。[MASK]が[MASK]られ[MASK]ばって[MASK]か。[SEP]そうなんですよね。
# まぁ、そうですね。[SEP]あるんですね。別に責めるつもりはないんですよ。きちんと飲めた方が良いのかと思いまして。[SEP]そうですね。 -> [MASK]ぁ、そうですね。[SEP]あるんですね。[MASK]に[MASK]る[MASK]はないんですよ。[MASK][MASK]めた方が良いのかと[MASK][MASK]て。[SEP]そうですね。
# そうしたいと思います，いいですね。[SEP]よかった。[SEP]ありがとうございました。 -> そうし[MASK]と[MASK]ます[MASK][MASK]ですね。[SEP][MASK]た。[SEP][MASK][MASK][MASK]た。
# そうですね。目覚ましをたくさんかけたり、夜は早めに負担に入るようにしたり…[SEP]色々工夫してくれてるみたいだね。ありがとう。それが効果を発揮してくれればってところだね。[SEP]そうですね。ただ、難しいですよね。 -> そうですね。[MASK][MASK]を[MASK][MASK]たり、[MASK]は早めに[MASK]に[MASK]ようにしたり...[SEP]色々工夫して[MASK]てるみたいだね。ありがとう。それが効果を発揮してくれればってところだね。[SEP]そうですね。ただ、難しいですよね。
# はい。[SEP]今日はどんな悩みでいらっしゃったんでしょう。[SEP]勉強、カウンセリングの勉強をしようと思うけど、なかなかやる気が出ない。 -> はい。[SEP]今日はどんな[MASK]で[MASK]っ[MASK]ったんでしょう。[SEP][MASK]、[MASK][MASK]の[MASK]をしようと思うけど、なかなかやる[MASK]が出ない。
# はい。[SEP]それでは、1日1時間転職に向けた活動の時間を確保することに対する自信度は10点満点でいうとどれくらいでしょうか？0点が自信度ゼロ。10点は、「絶対できる」だとすると。[SEP]そうですね。1時間となると、なかなか難しそうですが…でも何とかなりますかね。まぁ、6点か7点ぐらいでしょうか。 -> はい。[SEP]それでは、[MASK][MASK][MASK]時間[MASK]に向けた[MASK]の時間を[MASK]することに対する[MASK]度は10点満点でいうとどれくらいでしょうか?0点が[MASK]度ゼロ。10点は、「絶対できる」だとすると。[SEP]そうですね。1時間となると、なかなか難しそうですが...でも何とかなりますかね。まぁ、6点か7点ぐらいでしょうか。
# そうですね。平日で1時間取れれば十分だと思います。むしろ、1時間取れるかどうか…[SEP]1時間とるのは難しいかもしれないと。[SEP]そうですね…毎日30分位が現実的かという思いと、1時間取れれば、だいぶ前進しそうだという思いがあります。 -> そうですね。平日で[MASK]時間[MASK]れば十分だと思います。むしろ、[MASK]時間取れるかどうか...[SEP][MASK]時間とるのは難しいかもしれないと。[SEP]そうですね...[MASK][MASK]分位が現実的かという思いと、[MASK]時間[MASK]れば、だいぶ前進しそうだという思いがあります。
うですね。[MASK][MASK]を[MASK][MASK]たり、[MASK]は早めに[MASK]に[MASK]ようにしたり...
# そりゃそうですね。[SEP]ですよね。医師はそのことについて何と言っているんですか？[SEP]何と言っているわけでもないですけど、薬が変わることもあれば、もう少し様子を見ようとなることもありますね。 -> [MASK][MASK][MASK]そうですね。[SEP]ですよね。[MASK]はそのことについて何と言っているんですか?[SEP]何と言っている[MASK]でもないですけど、[MASK]が[MASK]こともあれば、もう少し[MASK]を見ようとなることもありますね。
# はい。[SEP]それは、やっぱり、どっちかに決めておいた方がいいだろうということですよね。[SEP]そうですね。結局、どっちでもということだと、30分とか、場合によっては、やらなくてもいいかということになりがちだと思います。1時間なら1時間と決めた方が、その時間を確保するために、準備できると思います。また、30分と決めれば、それくらいは絶対確保しようとおもえるだろうし。 -> はい。[SEP]それは、やっぱり、どっちかに決めておいた方がいい[MASK]ということですよね。[SEP]そうですね。結局、どっちでもということだと、[MASK]分とか、場合によっては、やらなくてもいいかということになりがちだと思います。[MASK]時間なら[MASK]時間と決めた方が、その時間を[MASK]するために、[MASK]できると思います。また、[MASK]分と決めれば、それくらいは絶対[MASK]しようとおもえるだろうし。
# そうですね債務整理、過去にもやったことあるんですが、あまり役に立たなかったと言うか、父が一度自己破産をしてブラックなんですけどまた闇金に手を出してしまってそれをまたカバーするためにお金を借りたいと思ってるので、あまり法律家は相談したくないと思ってます。[SEP]法律家には相談したくない。[SEP]やっても無駄だなーと。 -> そうですね[MASK][MASK]、過去にもやったことあるんですが、あまり役に立たなかったと言うか、[MASK]が一度[MASK][MASK]をしてブラックなんですけどまた[MASK]金に手を出してしまってそれをまたカバーするためにお[MASK]を[MASK]たいと思ってるので、あまり法律家は相談したくないと思ってます。[SEP]法律家には相談したくない。[SEP]やっても無駄だなーと。
# はい。[SEP]あなたは、仕事の日に予期せぬ業務が発生したり、疲れた状態で帰宅したりする際の対処法として、帰宅途中にカフェやレストランで作業時間を確保することを考えています。この方法により、転職活動において必要な1日1時間の時間をほぼ確実に確保できると感じており、それが自信度を高める要因となっているようです。[SEP]はい。 -> はい。[SEP]あなたは、仕事の[MASK]に予期せぬ業務が発生したり、疲れた状態で[MASK]したりする際の対処法として、[MASK]途中にカフェやレストランで作業時間を[MASK]することを考えています。この方法により、[MASK][MASK]において必要な1[MASK]1時間の時間をほぼ確実に[MASK]できると感じており、それが自信度を高める要因となっているようです。[SEP]はい。
# あ、はい。[SEP]お薬は指示通り飲めていますか？[SEP]あ、まぁ… -> [MASK]、[MASK]。[SEP]お[MASK]は[MASK][MASK][MASK]めていますか?[SEP][MASK]、[MASK]ぁ...
# うぅん...たまたま起きるとか、そんなに意識していなくても起きられるんですよね。[SEP]意識していなくても起きられる日があるんですね。それは素晴らしいことです。寝る時間と起きる時間の関係に気づくのも、大切な一歩ですね。[SEP]そうなんですよ...逆に起きられない時は、寝るのが遅いのかもしれません。 -> うぅん...[MASK][MASK]とか、そんなに意識していなくても[MASK]られるんですよね。[SEP]意識していなくても[MASK]られる日があるんですね。それは素晴らしいことです。[MASK]る時間と[MASK]時間の関係に気づくのも、大切な一歩ですね。[SEP]そうなんですよ...逆に[MASK]られない時は、[MASK]るのが遅いのかもしれません。
# そうですね…[SEP]そうすると、今、テレビと、仕事の持ち帰りとあったわけだけど、今後、遅刻を減らすためにできそうなことがあるとしたら、どんなこと？[SEP]まずは、テレビですかね。きちんと時間を決めようと思います。録画してあるのをすべて見るとなると、遅くなってしまうので。 -> そうですね...[SEP]そうすると、今、[MASK]と、仕事の[MASK]りとあったわけだけど、今後、[MASK][MASK]を減らすためにできそうなことがあるとしたら、どんなこと?[SEP]まずは、[MASK]ですかね。きちんと時間を決めようと思います。[MASK]してあるのを[MASK]見るとなると、[MASK]なってしまうので。
# そうですね。お金も払ってるんで。[SEP]薬が効かなくても、症状としてはそれほど気にならないんですね。[SEP]そういうわけじゃにんですけど、あきらめてますよね。悪くならないだけいいかって。 -> そうですね。お[MASK]も[MASK]てるんで。[SEP][MASK]が[MASK]なくても、[MASK]としてはそれ[MASK]気にならないんですね。[SEP]そういうわけじゃにんですけど、[MASK]めてますよね。[MASK]ならないだけいいかって。
# ようは、いかに自分で自制するっていうことか～。[SEP]ちょっとトライしてみようかなという気持ちがある。　[SEP]いかにタバコをやめれるか、やめたいなっていう思いもある。美味しいんやったら、美味しい方がいいし。昔に比べたら、食欲も落ちていることは落ちているし。 -> ようは、いかに自分で自制するっていうことか[MASK]。[SEP]ちょっとトライしてみようかなという気持ちがある。[SEP]いかに[MASK]を[MASK]れるか、[MASK]たいなっていう思いもある。[MASK]しいんやったら、[MASK]しい方がいいし。[MASK]に比べたら、食欲も[MASK]ていることは落ちているし。
# ただ、時間的に厳しい中で、なかなかうまくいかず、落ち込んでいました。[SEP]忙しい中で、せっかく書いた書類がなかなか一次審査を通らないと、嫌になってしまうことはありますよね。ただ、実際は、今後も転職活動は続けていきたいということですね。[SEP]そうですね。一応会社の規定では、3か月前までに退職願を出さなくてはいけないことになっているのですが、当面はそれを目指して、それが難しくても、今後も転職活動を続けていく気ではいます。 -> ただ、時間的に厳しい中で、[MASK]うまくいかず、落ち込んでいました。[SEP]忙しい中で、せっかく[MASK]た[MASK]が[MASK]一次審査を通らないと、嫌になってしまうことはありますよね。ただ、実際は、今後も[MASK][MASK]は続けていきたいということですね。[SEP]そうですね。一応会社の規定では、3か月前までに退職願を出さなくてはいけないことになっているのですが、当面はそれを目指して、それが難しくても、今後も[MASK][MASK]を続けていく気ではいます。
# はい[SEP]このように本日は話をしてきましたが、いかがでしたか？[SEP]本当にやる気が無くて転職のことを考えるだけで憂うつでしたが、このままではいけないと改めて思えたし、じゃあ具体的に何をしていけばいいのかということも明確になったので、今はとても前向きで、気持ちも軽くなりました。まだ時間はあるので、まずはこの方向で継続してみたいと思います。 -> はい[SEP]このように[MASK][MASK]は話をしてきましたが、いかがでしたか?[SEP]本当にやる[MASK]が無くて[MASK]のことを考えるだけで憂うつでしたが、このままではいけないと[MASK]思えたし、じゃあ[MASK]的に何をしていけばいいのかということも明確になったので、今はとても前向きで、気持ちも軽くなりました。まだ時間はあるので、まずはこの[MASK]で[MASK]してみたいと思います。
# でも私にできるのかわからない。[SEP]タバコをやめたいというあなたの気持ち、特にお子さんの成長を思ってのことだということが伝わってきます。自分自身や大切な人のために、健康的な生活を目指すことは大変価値のあることです。そして、そのような変化に取り組むことに対する不安や疑問を感じることも、ごく自然なことです。[SEP]ええ。 -> でも私にできるのかわからない。[SEP][MASK]を[MASK]たいというあなたの気持ち、特にお[MASK]さんの[MASK]を思ってのことだということが[MASK]てきます。自分自身や大切な人のために、健康的な生活を[MASK]ことは[MASK][MASK]のあることです。そして、そのような変化に取り組むことに対する不安や疑問を感じることも、ごく自然なことです。[SEP]ええ。
# そうですね。結局、どっちでもということだと、30分とか、場合によっては、やらなくてもいいかということになりがちだと思います。1時間なら1時間と決めた方が、その時間を確保するために、準備できると思います。また、30分と決めれば、それくらいは絶対確保しようとおもえるだろうし。[SEP]30分にするにしろ、1時間にするにしろ、それをしっかり決めることが、今後転職活動をスムーズに進めて行くためには重要ということですね。[SEP]そうですね。とりあえずは、1時間やるということで、しばらくやってみようと思います。 -> そうですね。結局、どっちでもということだと、[MASK]分とか、場合によっては、やらなくてもいいかということになりがちだと思います。1時間なら1時間と決めた方が、その時間を[MASK]するために、[MASK]できると思います。また、[MASK]分と決めれば、それくらいは絶対[MASK]しようとおもえるだろうし。[SEP][MASK]分にするにしろ、1時間にするにしろ、それをしっかり決めることが、今後[MASK][MASK]をスムーズに進めて行くためには重要ということですね。[SEP]そうですね。とりあえずは、1時間やるということで、しばらくやってみようと思います。
# 出来てるかわからないけど、自分が成長してる気がするし。する。自分のことも知れる。かな。[SEP]自分のことを知りたい。[SEP]うん、知りたい。 -> [MASK][MASK]かわからないけど、自分が[MASK]し[MASK]気がするし。する。自分のことも[MASK]る。かな。[SEP]自分のことを[MASK]たい。[SEP][MASK]、[MASK]たい。
# そうなんです。今はいつもぎりぎりで、夜20時までに大きな郵便局まで書類を出しに行くこともあるので、それが無いだけでも、だいぶ効率的になると思います。[SEP]余裕をもって準備をして、早めに、近所の郵便局に出しに行けるといいということですね。[SEP]はい。あとは…どうしても、日々の業務に追われていると、転職活動を先送りにしがちなので、それを何とかする必要がありますかね。 -> そうなんです。今はいつもぎりぎりで、夜20時までに大きな郵便局まで[MASK]を出しに行くこともあるので、それが無いだけでも、[MASK][MASK]効率的になると思います。[SEP][MASK]をもって[MASK]をして、早めに、近所の郵便局に出しに行けるといいということですね。[SEP]はい。あとは...どうしても、日々の[MASK]に追われていると、[MASK][MASK]を先送りにしがちなので、それを何とかする必要がありますかね。
# [SEP]OK、エイデン(息子の名前）へ抗生物質の処方菱を書きました。中耳炎に効果があるでしょう。しかしカルテを見ると，彼はこの1年の問に6回から7回も繰り返しているようですね。とても大きな問題だと思います。[SEP]ええ，私たちにとってすごくストレスなんです。息子もすごく悩んでいて。 -> [SEP]OK、エイ[MASK]([MASK]の名前)へ抗生物質の処方菱を書きました。中[MASK][MASK]に効果があるでしょう。しかしカルテを見ると[MASK][MASK]はこの1年の問に6回から7回も繰り返しているようですね。とても大きな問題だと思います。[SEP]ええ[MASK]私たちにとってすごくストレスなんです。[MASK]もすごく悩んでいて。
# まずは、テレビですかね。きちんと時間を決めようと思います。録画してあるのをすべて見るとなると、遅くなってしまうので。[SEP]そっか。それはありがとうね。仕事の持ち帰りについては、どうかな？[SEP]持ち帰りは、減らした方が良いとは思うのですが、締め切りを遅らせることもできませんし… -> まずは、[MASK]ですかね。きちんと時間を決めようと思います。[MASK]してあるのをすべて見るとなると、[MASK]なってしまうので。[SEP][MASK]っか。それはありがとうね。仕事の[MASK]りについては、どうかな?[SEP][MASK]りは、[MASK]た方が良いとは思うのですが、締め切りを[MASK]らせることもできませんし...
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]時間管理に関して少し困っているようですね。特に大きな問題があったわけではないけれど、朝の時間に間に合わせることが難しかったということが理解できます。日常生活での小さな挑戦にも前向きに取り組んでいることは、とても良いことだと思います。[SEP]そうですね。すみません。 -> [MASK]、それが、[MASK]何があったというわけでは[MASK]んですが、[MASK]なくて。[SEP]時間管理に関して少し困っているようですね。特に大きな問題があったわけではないけれど、[MASK]の時間に[MASK][MASK]ことが難しかったということが理解できます。日常生活での小さな挑戦にも前向きに取り組んでいることは、とても良いことだと思います。[SEP]そうですね。[MASK]ません。
# 使い過ぎたり、出費が多くてマイナスですね。[SEP]毎月。[SEP]毎月。 -> [MASK][MASK]たり、[MASK][MASK]が[MASK]て[MASK]ですね。[SEP][MASK]。[SEP][MASK]。
# あーそうです、そうです。 [SEP]じゃあ今はまずはこのお金の事、この債務整理のコツとか専門家と話をしたいと思ってらっしゃる。[SEP]そうですね債務整理、過去にもやったことあるんですが、あまり役に立たなかったと言うか、父が一度自己破産をしてブラックなんですけどまた闇金に手を出してしまってそれをまたカバーするためにお金を借りたいと思ってるので、あまり法律家は相談したくないと思ってます。 -> あーそうです、そうです。[SEP]じゃあ今はまずはこのお[MASK]の事、この[MASK][MASK]のコツとか専門家と話をしたいと思って[MASK]しゃる。[SEP]そうですね[MASK]整理、過去にもやったことあるんですが、あまり役に立たなかったと言うか、[MASK]が一度自己破産をしてブラックなんですけどまた闇金に手を出してしまってそれをまたカバーするためにお[MASK]を[MASK]たいと思ってるので、あまり法律家は相談したくないと思ってます。
# わかりました。とにかくわかりました。[SEP]あなたが禁煙しようとしていること、そしてそれが非常に難しいことを理解しています。しかし、息子さんの健康のためにも、あなた自身のためにも、禁煙は避けられない道です。肺がんや心疾患など、喫煙によるリスクは非常に高く、今がやめる時です。[SEP] -> わかりました。[MASK]わかりました。[SEP]あなたが[MASK]しようとしていること、そしてそれが[MASK]に難しいことを理解しています。しかし、[MASK]さんの健康のためにも、あなた自身のためにも、[MASK]は避けられない道です。[MASK]がんや心疾患など、[MASK]による[MASK]は非常に高く、今がやめる時です。[SEP]
# 何と言っているわけでもないですけど、薬が変わることもあれば、もう少し様子を見ようとなることもありますね。[SEP]そうですか。きちんと医師とお話はできてるんですね。最善は尽くしているという感じですね。[SEP]そうですね。 -> 何と言っているわけでもないですけど、[MASK]が[MASK]こともあれば、もう少し[MASK]を見ようとなることもありますね。[SEP]そうですか。[MASK][MASK]とお話はできてるんですね。[MASK][MASK]は[MASK]ているという感じですね。[SEP]そうですね。
# んー、英語の勉強をしたいんだけど。[SEP]英語の勉強をしたい。[SEP]やっぱりなんか必要かなぁって思うんで。で、やっぱ実際忙しいから、挫折の繰り返しみたいな。 -> んー、[MASK]の[MASK]をしたいんだけど。[SEP][MASK]の[MASK]をしたい。[SEP]やっぱりなん[MASK]必要かなぁって思うんで。で、やっぱ実際[MASK]しいから、[MASK]の[MASK]みたいな。
# ええ，吸います。でも彼の周りで吸いません。彼の周りでは吸わないように気をつけています｡[SEP]いいですか，息子さんがこのように何度も中耳炎に躍っていることを見れば，私にはすぐタバコの煙のせいだと想像がつきます。そのことについてどう説明しますか？[SEP]わ，わかりません。私が言いたいのは，息子の周りでは吸わないように気をつけているということです。車の中では吸いませんし，息子が家にいるときは外に吸いに行きます。とにかく私にたばこが悪いということは分かっているし，息子にとっても悪いことだと分かっているからタバコの周りにいないでほしいと言っているし，本当に気をつけています。 -> ええ[MASK]吸います。でも彼の周りで吸いません。彼の周りでは吸わないように気をつけています。[SEP]いいですか[MASK]息子さんがこのように何度も中耳炎に躍っていることを見れば[MASK]私にはすぐタバコの煙のせいだと想像がつきます。そのことについてどう説明しますか?[SEP]わ[MASK]わかりません。私が言いたいのは[MASK]息子の周りでは吸わないように気をつけているということです。車の中では吸いませんし[MASK]息子が家にいるときは外に吸いに行きます。とにかく私にたばこが悪いということは分かっているし[MASK]息子にとっても悪いことだと分かっているからタバコの周りにいないでほしいと言っているし[MASK]本当に気をつけています。
# はい。[SEP]まず、持ち帰りは極力減らして、できれば無しにすること。その上で、締め切りに間に合わなそうなことがあったら、早めに言ってもらえる？担当を増やしたりしようと思うから。[SEP]わかりました。それならできそうです。 -> はい。[SEP]まず、[MASK]りは[MASK][MASK][MASK]て、できれば無しにすること。その上で、[MASK][MASK]に[MASK]なそうなことがあったら、[MASK]めに言ってもらえる?担当を増やしたりしようと思うから。[SEP]わかりました。それならできそうです。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]大丈夫ですよ。たまにはそういう日もありますからね。無理せず、自分のペースで行きましょう。[SEP]そうですね。すみません。 -> [MASK]、それが、[MASK]何があったというわけでは[MASK]んですが、[MASK]なくて。[SEP]大丈夫ですよ。[MASK]はそういう[MASK]もありますからね。無理せず、自分の[MASK]で行きましょう。[SEP]そうですね。[MASK]ません。
# それはよさそうですね，でも全てに参加する時間があるかどうか。[SEP]もちろん，時間もたくさん取られるかもしれませんし，あなたの生活に合わないかもしれません。あなたの生活に合うようないくつかの選択肢について話ができればと思うのですが。[SEP]とても嬉しいです -> それはよさそうですね[MASK]でも[MASK]に参加する時間があるかどうか。[SEP][MASK][MASK]時間も[MASK]取られるかもしれませんし[MASK]あなたの生活に合わないかもしれません。あなたの生活に合うようないくつかの[MASK][MASK]について話ができればと思うのですが。[SEP]とても嬉しいです
# もうないです。あのエアコンを買うために電化製品家電屋さんの審査通したんですけど通らなかったんです。なので困っています。[SEP]日々の生活にもうそろそろ困るかもしれないと思ってらっしゃって。。そうかー、Tさんとしてはお金を借りるところがなくて困っている一方で、何か例えば生活を少しこうしたらいいかなとか[SEP] -> もうないです。あの[MASK][MASK]を買うために電化製品家電屋さんの審査通したんですけど通らなかったんです。なので困っています。[SEP]日々の生活にもうそろそろ[MASK]るかもしれないと思って[MASK][MASK]って。。そうかー、[MASK]さんとしてはお[MASK]を[MASK]るところがなくて困っている一方で、何か例えば生活を少しこうしたらいいかなとか[SEP]
# 体重が80㎏とか、大分若い時にかなぁ？20代の時の太っていたとき！でも入社の時がちょうど72㎏だったはずで。[SEP]お～ぉ。じゃぁ、ちょうど入社の時の体重になった。　[SEP]そう。ちょうど入社の時の体重になった。 -> [MASK]が80[MASK]とか、大分若い時にかなぁ?20代の時の太っていたとき!でも[MASK]の時が[MASK]72[MASK]だったはずで。[SEP]お[MASK]ぉ。じゃぁ、ちょうど入社の時の[MASK]になった。[SEP]そう。ちょうど入社の時の[MASK]になった。
# そうですか。[SEP]いや、でも、前に話をさせてもらって、相談者君も気を付けてくれているみたいで良かったよ。遅刻しないようにすることについてはどんな感じ？[SEP]そうですね。気をつけてはいるんですが、なかなか起きられなくて。 -> そうですか。[SEP][MASK]、でも、前に話をさせて[MASK]て、相談者[MASK]も気を付けて[MASK]ているみたいで[MASK]たよ。[MASK][MASK]しないようにすることについてはどんな感じ?[SEP]そうですね。気をつけてはいるんですが、なかなか[MASK]られなくて。
# とても嬉しいです[SEP]OK，ではもしよければ，あなたが来られるときに一度予約を取り直して，そのことについて話をしましょう。[SEP]そうしたいと思います，いいですね。 -> とても[MASK]しいです[SEP][MASK][MASK]ではもしよければ[MASK]あなたが来られるときに一度[MASK]を[MASK]直して[MASK]そのことについて話をしましょう。[SEP]そうしたいと思います[MASK]いいですね。
# でも私にできるのかわからない[SEP]大切な人のために変わろうと思うその気持ち、とても素晴らしいですね。自分自身と向き合う勇気を持って、一歩ずつ進めていくことが大事です。[SEP]ええ -> でも私にできるのかわからない[SEP]大切な人のために[MASK][MASK][MASK]と思うその気持ち、とても素晴らしいですね。自分自身と[MASK][MASK][MASK]を持って、一歩[MASK]進めていくことが[MASK]です。[SEP]ええ
# はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。[SEP]その決断力、すごいですね。自分のキャリアに真剣に向き合って、積極的に時間を割く姿勢は、すばらしいです。[SEP]実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。 -> はい。せっかくなので、[MASK]に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。[SEP]その[MASK][MASK]、すごいですね。自分のキャリアに真剣に向き合って、[MASK]的に時間を割く[MASK]は、[MASK][MASK]です。[SEP]実際どうなるかはわからないですけどね。計画的に進め[MASK]といいとは思います。
# そうですね、あの、ないですね。なんか今年の学会ではあったりとか、そういう情報だけはあったので、勉強したいなってところはあるんですけど。[SEP]今日は何かお困りのことが。[SEP]お金を貯めたいと思うんですけどもたまらずに逆にマイナスばっかりです。 -> そうですね、[MASK]、ないですね。なんか今年の学会ではあったりとか、そういう情報だけはあったので、勉強したいなってところはあるんですけど。[SEP]今日は何かお[MASK]りのことが。[SEP]お[MASK]を[MASK]めたいと思うんですけども[MASK]らずに[MASK]に[MASK]ば[MASK]です。
# んー、そうね、悩んでる…まぁちょっとやって、オンライン英会話とかトライして。ただ忙しい時は難しい、そんなところを繰り返してる状況ですかね。[SEP]もし、英語の勉強をされて、少し英語のワークショップとか資料を読めたりすると、どんないいことがありますか？[SEP]そうですね、実際に、新しい、私だと、精神疾患に関するＭＩがどうかとか、国内ではまだ無かったりして、新しい情報みたいなのが聞きたいなぁとは思ってるけど、難しかったりとか、まあ教科書も英語だと豊富にあるんですけど、物すごい時間がかかってしまって、いまの技術では。まあそういうところもあるし、まあ勉強だけじゃなくても、子供と旅行とかいったら楽しいだろうなぁって。 -> んー、そうね、悩んでる...まぁちょっとやって、オンライン英会話とかトライして。ただ忙しい時は難しい、そんなところを繰り返してる状況ですかね。[SEP]もし、[MASK]の[MASK]をされて、少し[MASK]のワークショップとか資料を読めたりすると、どんないいことがありますか?[SEP]そうですね、実際に、新しい、私だと、[MASK]疾患に関するMIがどうかとか、国内ではまだ無かったりして、新しい情報みたいなのが聞きたいなぁとは思ってるけど、難しかったりとか、まあ[MASK][MASK]も[MASK]だと豊富にあるんですけど、物すごい時間がかかってしまって、いまの技術では。まあそういうところもあるし、まあ[MASK]だけじゃなくても、子供と旅行とかいったら楽しいだろうなぁって。
# 相談をしたいなと思ってるんですけど協力的ではないので 。[SEP]あー、そうかそうか。じゃあ今は相談もできなくて一人で悩んでて今日ちょっと話をしようかなと思ったと。[SEP]あーそうです、そうです。  -> [MASK]をしたいなと思ってるんですけど[MASK]的ではないので。[SEP]あ[MASK]、そうかそうか。じゃ[MASK]今は[MASK]もできなくて[MASK]で[MASK]でて今日ちょっと話をしようかなと思ったと。[SEP]あ[MASK]そうです、そうです。
# ありがとうございました。[SEP]はい。[SEP]でも私にできるのかわからない。 -> [MASK][MASK][MASK][MASK]。[SEP][MASK]。[SEP]でも[MASK]に[MASK]のか[MASK]ない。
# 自己破産すると思うんですけど、そうですね家族の協力も得られないので私一人だけ悩んでる感じ。[SEP]じゃあ、このことについてもしかしたら誰かと相談をしてなんかもうちょっと気持ちの整理をつけたいかなとかなんかそういう感じを思ってらっしゃる。[SEP]相談をしたいなと思ってるんですけど協力的ではないので 。 -> [MASK][MASK]すると思うんですけど、そうですね[MASK]の協力も得られないので私[MASK]だけ悩んでる感じ。[SEP]じゃあ、このことについてもしかしたら[MASK]かと相談をしてなんかもうちょっと気持ちの[MASK]をつけたいかなとかなんかそういう感じを思って[MASK][MASK]る。[SEP]相談をしたいなと思ってるんですけど協力的ではないので。
# うんある。[SEP]やった方がいいかなっていう気持ちが少し大きい。[SEP]どうだろ、半分半分かな。 -> [MASK]ある。[SEP]やった[MASK]がいいかなっていう気持ちが少し[MASK]。[SEP][MASK][MASK][MASK]、[MASK][MASK]かな。
# はい。[SEP]なんだかもったいないですね。せっかく飲んでるのに…[SEP]はぁ… -> [MASK]。[SEP][MASK]だか[MASK][MASK]ないですね。[MASK][MASK][MASK]でるのに...[SEP]は[MASK]...
# 実は、あんまり効果を感じてないんですよね。[SEP]そうなんですね。朝晩きちんと飲んでも、飛ばしてしまってもあまり変わらない。[SEP]はい。 -> [MASK]は、[MASK][MASK]効果を感じてないんですよね。[SEP]そうなんですね。朝[MASK][MASK][MASK]でも、[MASK]てしまってもあまり[MASK]ない。[SEP]はい。
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]ニコチンパッチを使用することについて、前向きに考えているようです。パッチを使用することで、禁煙に挑戦し、同時に体重管理にも気をつけることが重要になりそうです。体重の増加を恐れることなく、健康的な方法で禁煙に取り組むことができれば、長期的に見て健康に良い影響を与えることになるでしょう。[SEP] -> ですね。まずはあれ[MASK]禁煙サポートプログラム[MASK]に申込んで[MASK]をもらうところから始めてみようかな[MASK]と。[SEP]ニコチン[MASK]を使用することについて、前向きに考えているようです。[MASK]を使用することで、禁煙に挑戦し、同時に[MASK]管理にも気をつけることが重要になりそうです。[MASK]の増加を恐れることなく、健康的な方法で禁煙に取り組むことができれば、長期的に見て健康に良い影響を与えることになるでしょう。[SEP]
# タバコはやめたいけど、体重が増えたりするのが心配。[SEP]そうですね～。今までのお話の中で、味覚が、美味しくて食べ過ぎちゃったというお話もあったと思いますが、やっぱりご飯が美味しくなることこそが、タバコのせいなんです。　[SEP]そう、それが分かっているもんだから、余計怖いというか、、、スイッチが入った瞬間怖いというか、また食べ過ぎてしまうんやろな～みないな。 -> タバコはやめたいけど、[MASK]が増えたりするのが心配。[SEP]そうですね[MASK]。今までのお話の中で、味覚が、[MASK]しくて食べ過ぎちゃったというお話もあったと思いますが、やっぱりご[MASK]が[MASK]しくなることこそが、タバコのせいなんです。[SEP]そう、それが分かっているもんだから、余計[MASK]というか、、、スイッチが入った瞬間[MASK]というか、また食べ過ぎてしまうんやろな[MASK]みないな。
# そういうわけじゃにんですけど、あきらめてますよね。悪くならないだけいいかって。[SEP]確かにそうですね。悪くなっていないのは良いことですね。もっと効く方法があったら、なお良いという感じですかね。[SEP]そりゃそうですね。 -> そういうわけじゃにんですけど、[MASK]めてますよね。[MASK]ならないだけいいかって。[SEP][MASK]にそうですね。[MASK]なっていないのは良いことですね。もっと[MASK]く方法があったら、[MASK]良いという感じですかね。[SEP][MASK]り[MASK]そうですね。
# 難しい。わかんない。[SEP]勝手に想像してしまいました。[SEP]えぇ -> 難しい。[MASK][MASK]ない。[SEP][MASK]に[MASK]して[MASK][MASK]た。[SEP][MASK][MASK]
# そうですね、でもやっぱりこの債務整理のこの返済を、もう少し額を抑えられたらなと思います。[SEP]じゃあ債務整理の専門の方と色々もう一回お話をちょっとしてみようかなとか。[SEP]そうですね、ま、できる、話ししてどうなるかわからないんですけど、うまく行くんだったらしても良いかなー。 -> そうですね、でもやっぱりこの[MASK][MASK]のこの[MASK]を、もう少し額を[MASK]られたらなと思います。[SEP]じゃあ[MASK][MASK]の[MASK]の方と色々もう一回お話をちょっとしてみようかなとか。[SEP]そうですね、ま、できる、話ししてどうなるかわからないんですけど、うまく[MASK]んだったらしても良いかなー。
# そうですね。目覚ましをたくさんかけたり、夜は早めに負担に入るようにしたり...[SEP]そうですね、夜早く寝る努力や目覚ましをかける工夫、いいですね。ちょっとずつでも、そういう努力が結果につながると思いますよ。[SEP]そうですね。ただ、難しいですよね。 -> そうですね。[MASK][MASK]をたくさん[MASK]たり、[MASK]は早めに[MASK]に入るようにしたり...[SEP]そうですね、夜早く[MASK]る努力や[MASK][MASK]をかける工夫、いいですね。ちょっとずつでも、そういう努力が結果につながると思いますよ。[SEP]そうですね。ただ、難しいですよね。
# そうです。どうせこんな書類書いたって無駄だろうと思ってしまいます。[SEP]ただ、ご自身としては、そうも言っていられない状況だと。[SEP]そうですね。何とかして、脱出しなくてはいけないと思います。 -> そうです。どう[MASK]こんな[MASK][MASK][MASK][MASK]無駄[MASK]と思ってしまいます。[SEP]ただ、ご自身としては、そうも言っていられない状況だと。[SEP]そうですね。何とかして、[MASK]しなくては[MASK]ないと思います。
# はい。[SEP]このままだったらどんな風になると考えていらっしゃいますか？[SEP]自己破産すると思うんですけど、そうですね家族の協力も得られないので私一人だけ悩んでる感じ。 -> はい。[SEP]この[MASK]だったらどんな風になると考えていらっ[MASK]いますか?[SEP][MASK][MASK]すると思うんですけど、そうですね[MASK]の[MASK]も得られないので私[MASK]だけ[MASK]でる感じ。
# 8，9割出来るのではないでしょうか。100％というのは難しいと思ので、これくらいなら十分かと思います。[SEP]1日1時間時間を使うと意識して、過ごし、場合によっては、帰宅途中にカフェやレストランによることで、8，9割はこの目標を達成できそうだということですね。[SEP]はい。 -> 8,9割出来るのではないでしょうか。100%というのは難しいと思ので、これくらいなら十分かと思います。[SEP][MASK][MASK][MASK]時間時間を使うと意識して、過ごし、場合によっては、[MASK][MASK]に[MASK]や[MASK]によることで、8,9割はこの目標を[MASK]できそうだということですね。[SEP]はい。
# わかりました。とにかくわかりました。[SEP]O K[SEP]わかりました。とにかくわかりました。 -> [MASK]ました。[MASK][MASK]ました。[SEP][MASK][MASK][SEP][MASK]ました。[MASK][MASK]ました。
# とりあえず、次の年金が 来月13日に入るのでそれまで繋げれば生活を、後父の給料が8日なので、その日まで乗り切れば。[SEP]後数日まずは乗り切れればと。[SEP]エアコン買ったり支払いにまた考えたいなと思ってるんですけど。 -> とりあえず、次の年金が来月13日に入るのでそれまで繋げれば生活を、[MASK][MASK]の給料が8日なので、その日まで[MASK][MASK]ば。[SEP][MASK]数日まずは乗り切れればと。[SEP][MASK][MASK][MASK]たり支払いにまた考えたいなと思ってるんですけど。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]今朝は時間に間に合わせるのが難しかったと聞きましたが、そういった時にどのように対応するかも大切ですね。自分自身を律する力が身についているようで、それはとても大切なことです。[SEP]そうですね。すみません。 -> [MASK]、それが、特に何があったというわけでは[MASK]んですが、[MASK]なくて。[SEP]今[MASK]は時間に[MASK][MASK]のが難しかったと聞きましたが、そういった時にどのように対応するかも大切ですね。自分自身を律する[MASK]が身についているようで、それはとても大切なことです。[SEP]そうですね。[MASK]ません。
# いやぁ…[SEP]せっかくなら、ちゃんと効いてくれた方が良いのかと思って…[SEP]そうですね。お金も払ってるんで。 -> [MASK]ぁ...[SEP][MASK][MASK]なら、[MASK][MASK]いて[MASK]た方が良いのかと思って...[SEP]そうですね。お[MASK]も[MASK]てるんで。
# はい。[SEP]他にも何かありそうですか？[SEP]そうですね。やっぱり、自分のために時間は使うべきだという思いがあります。今の仕事は、それが嫌いなわけではないですが、自分が今やるべきことはそれではないと思います。自分の人生やキャリアの優先順位を上げるべきだと思います。 -> はい。[SEP]他にも何かありそうですか?[SEP]そうですね。やっぱり、自分のために時間は[MASK][MASK]だという思いがあります。今の仕事は、それが[MASK]なわけではないですが、自分が今[MASK][MASK]ことはそれではないと思います。自分の人生やキャリアの[MASK]順位を[MASK][MASK]だと思います。
# タバコをやめたら、メシがうまくなったっていう話を聞いて、「これ！」って思って。[SEP]自覚できてうれしい気持ち。　[SEP]うれしい。そうなんや～。これや～！っという。おいんしんや～！！って思ったけど、飲む・食うしちゃうと、大昔のあの時代に戻るのかな？なんて。 -> [MASK]を[MASK]たら、[MASK]シがうまくなったっていう話を聞いて、「これ!」って思って。[SEP]自覚できてうれしい気持ち。[SEP]うれしい。そうなんや[MASK]。これや[MASK]![MASK][MASK]いう。おいんしんや[MASK]!!って思ったけど、飲む・食うしちゃうと、大昔のあの時代に戻るのかな?なんて。
# うぅん．．．たまたま起きるとか、そんなに意識していなくても起きられるんですよね。[SEP]来られるときは、意識せずにも起きられるのか！それはいいね！[SEP]そうなんですよ…逆に起きられない時は、寝るのが遅いのかもしれません。 -> うぅん...[MASK][MASK]とか、そんなに[MASK]していなくても[MASK]られるんですよね。[SEP]来られるときは、[MASK]せずにも[MASK]られるのか!それはいいね![SEP]そうなんですよ...逆に[MASK]られない時は、[MASK]るのが遅いのかもしれません。
# はい。[SEP]月曜日と火曜日に日中作業ができなかった場合や、水曜日と金曜日に疲れて帰宅した際の対処法について、あなたは帰宅途中にカフェやレストランで作業するという具体的な方法を考えています。これにより、転職活動に必要な1日1時間の時間を確保し、目標達成に対する自信度を8、9割まで高めることができると考えているようです。[SEP]はい。 -> はい。[SEP]月曜[MASK]と火曜[MASK]に日中作業ができなかった場合や、水曜[MASK]と金曜日に疲れて[MASK]した際の対処法について、あなたは[MASK]途中にカフェやレストランで作業するという具体的な方法を考えています。これにより、[MASK][MASK]に必要な1日1時間の時間を[MASK]し、目標達成に対する自信度を8、9割まで高めることができると考えているようです。[SEP]はい。
# そうなんですよ...逆に起きられない時は、寝るのが遅いのかもしれません。[SEP]今年度も保健指導にご参加くださりありがとうございます。では早速ですが、健診結果の振返り、食事・運動・その他で主にタバコについて確認させてください。どうでしょうか？[SEP]5年前に比べると、良くなっている。特に体重が80㎏だったから～。 -> そうなんですよ...逆に起きられない時は、寝るのが遅いのかもしれません。[SEP]今年度も保健指導にご参加くださりありがとうございます。では早速ですが、健診結果の振返り、[MASK][MASK]運動[MASK]その他で主に[MASK]について確認させてください。どうでしょうか?[SEP]5年前に比べると、良くなっている。特に[MASK]が[MASK][MASK]だったから[MASK]。
# はい。[SEP]そうすると、改めて、今日も面談が終わった後には、どんな風になっていると良さそうですか？[SEP]そうですね。やる気というよりも、淡々と、計画的に、応募書類を出し続けるということですかね。気分的なことよりも、現職との両立がキーになりそうです。 -> はい。[SEP]そうすると、改めて、今日も面談が終わった後には、どんな風になっていると[MASK]さそうですか?[SEP]そうですね。やる[MASK]という[MASK]も、淡々と、[MASK]的に、[MASK][MASK]を出し続けるということですかね。気分的なこと[MASK]も、現職との[MASK]がキーになりそうです。
# ええ。[SEP]じゃあ３分くらいで。どんなテーマで？[SEP]んー、英語の勉強をしたいんだけど。 -> ええ。[SEP]じゃ[MASK][MASK][MASK][MASK]で。どんな[MASK]で?[SEP]ん[MASK]、[MASK]の[MASK]をしたいんだけど。
# 持ち帰りは、減らした方が良いとは思うのですが、締め切りを遅らせることもできませんし…[SEP]そうしたら、私から提案させてもらいたいことがあるんだけどいい？[SEP]はい。 -> [MASK]りは、[MASK]た方が良いとは思うのですが、[MASK][MASK]を[MASK][MASK]ることもできませんし...[SEP]そうしたら、私から[MASK]さ[MASK]てもらいたいことがあるんだけどいい?[SEP]はい。
# あ、まぁ…[SEP]飲めないめないこともありますかね?[SEP]まぁ、そうですね。 -> [MASK]、[MASK][MASK]...[SEP][MASK][MASK]ない[MASK]ないこともありますかね?[SEP][MASK][MASK]、そうですね。
# そうですね…まぁ、テレビ見すぎなのかな。[SEP]テレビ、好きなんだね。[SEP]そうなんですよ。録画してあるのがあるんで… -> そうですね...[MASK][MASK]、[MASK][MASK][MASK]なのかな。[SEP][MASK]、[MASK]なんだね。[SEP]そうなんですよ。[MASK]してあるのがあるんで...
# パッチはそう、でも飲み薬よりはパッチ！[SEP]パッチやってみようかな？って、飲み薬は、、、　[SEP]飲み薬は怖いかなって！飲み薬は確か産業医の先生のあれがいるんですよね？ -> [MASK]はそう、でも[MASK][MASK]よりは[MASK]![SEP][MASK]やってみようかな?って、[MASK][MASK]は、、、[SEP]飲み薬は[MASK]かなって!飲み薬は確か産業医の先生のあれがいるんですよね?
# はい。[SEP]あなたは、仕事の日に発生する突発的な業務や、疲れて帰宅した日に作業時間が取れないという課題に直面しています。しかし、帰宅途中にカフェやレストランで時間を作るという具体的な対策を考えていて、このアプローチにより転職活動における自信度が高まると感じているようです。[SEP]はい。 -> はい。[SEP]あなたは、仕事の[MASK]に発生する突発的な業務や、疲れて[MASK]した[MASK]に[MASK]時間が取れないという課題に直面しています。しかし、[MASK][MASK]にカフェやレストランで時間を作るという具体的な対策を考えていて、このアプローチにより[MASK][MASK]における自信度が高まると感じているようです。[SEP]はい。
# そうですね。気をつけてはいるんですが、なかなか起きられなくて。[SEP]そっか。朝が起きられればってところか。[SEP]そうなんですよね。 -> そうですね。気を[MASK]てはいるんですが、[MASK][MASK]られなくて。[SEP][MASK]っか。[MASK]が[MASK]られ[MASK]ばって[MASK]か。[SEP]そうなんですよね。
# まぁ、そうですね。[SEP]あるんですね。別に責めるつもりはないんですよ。きちんと飲めた方が良いのかと思いまして。[SEP]そうですね。 -> [MASK]ぁ、そうですね。[SEP]あるんですね。[MASK]に[MASK]る[MASK]はないんですよ。[MASK][MASK]めた方が良いのかと[MASK][MASK]て。[SEP]そうですね。
# そうしたいと思います，いいですね。[SEP]よかった。[SEP]ありがとうございました。 -> そうし[MASK]と[MASK]ます[MASK][MASK]ですね。[SEP][MASK]た。[SEP][MASK][MASK][MASK]た。
# そうですね。目覚ましをたくさんかけたり、夜は早めに負担に入るようにしたり…[SEP]色々工夫してくれてるみたいだね。ありがとう。それが効果を発揮してくれればってところだね。[SEP]そうですね。ただ、難しいですよね。 -> そうですね。[MASK][MASK]を[MASK][MASK]たり、[MASK]は早めに[MASK]
# ええ[SEP]では，もし禁煙の決心をするとして，全く自信がない「できないと思う」場合を1，できると確信している場合を10として9から10段階で今のあなたはどの辺りですか？[SEP]たぶん5くらいだと，迷っているところ。以前やったことがあるからできると思うけれど，同時にすごく難しいとも感じている，同じ状況じゃないし。 -> ええ[SEP]では[MASK]もし禁煙の決心をするとして[MASK]全く自信がない「できないと思う」[MASK]を1[MASK]できると確信している[MASK]を10として9から10段階で今のあなたはどの辺りですか?[SEP]たぶん5くらいだと[MASK]迷っているところ。以前やったことがあるからできると思うけれど[MASK]同時にすごく難しいとも感じている[MASK]同じ状況じゃないし。
# そうですね…月、火の仕事中に突発的な業務が発生した時や、水、金に疲れて帰宅したときなんかが難しいと思います。この辺りの対処法を見つけることができれば、自信度は高まると思います。[SEP]月、火に日中に出来なかった場合にどうするかということと、水、金に疲れて帰宅したときにどうするかということですね。[SEP]はい。いずれも帰宅してしまうと、なかなか作業の時間が取れないことが多いので、帰宅前にやれるといいですかね。例えば、水、金や月、火で日中に1時間取れなかったときには、帰宅途中でカフェやレストランによって1時間作業をして帰るとか。 -> そうですね...月、火の仕事中に突発的な業務が発生した時や、水、金に疲れて[MASK]したときなんかが難しいと思います。この辺りの対処法を見つけることができれば、自信度は高まると思います。[SEP]月、火に日中に出来なかった場合にどうするかということと、水、金に疲れて[MASK]したときにどうするかということですね。[SEP]はい。いずれも[MASK]してしまうと、なかなか[MASK]の時間が取れないことが多いので、[MASK]前にやれるといいですかね。例えば、水、金や月、火で日中に1時間取れなかったときには、[MASK][MASK]で[MASK]やレストランによって1時間作業をして帰るとか。
# はい。気をつけてはいるんですが…[SEP]どんなことをしてくれているの？[SEP]そうですね。目覚ましをたくさんかけたり、夜は早めに負担に入るようにしたり… -> はい。気をつけてはいるんですが...[SEP]どんなことをして[MASK]ているの?[SEP]そうですね。[MASK][MASK]を[MASK][MASK]たり、[MASK]は早めに[MASK]に[MASK]ようにしたり...
# そりゃそうですね。[SEP]ですよね。医師はそのことについて何と言っているんですか？[SEP]何と言っているわけでもないですけど、薬が変わることもあれば、もう少し様子を見ようとなることもありますね。 -> [MASK][MASK][MASK]そうですね。[SEP]ですよね。[MASK]はそのことについて何と言っているんですか?[SEP]何と言っている[MASK]でもないですけど、[MASK]が[MASK]こともあれば、もう少し[MASK]を見ようとなることもありますね。
# はい。[SEP]それは、やっぱり、どっちかに決めておいた方がいいだろうということですよね。[SEP]そうですね。結局、どっちでもということだと、30分とか、場合によっては、やらなくてもいいかということになりがちだと思います。1時間なら1時間と決めた方が、その時間を確保するために、準備できると思います。また、30分と決めれば、それくらいは絶対確保しようとおもえるだろうし。 -> はい。[SEP]それは、やっぱり、どっちかに決めておいた方がいい[MASK]ということですよね。[SEP]そうですね。結局、どっちでもということだと、[MASK]分とか、場合によっては、やらなくてもいいかということになりがちだと思います。[MASK]時間なら[MASK]時間と決めた方が、その時間を[MASK]するために、[MASK]できると思います。また、[MASK]分と決めれば、それくらいは絶対[MASK]しようとおもえるだろうし。
# そうですね債務整理、過去にもやったことあるんですが、あまり役に立たなかったと言うか、父が一度自己破産をしてブラックなんですけどまた闇金に手を出してしまってそれをまたカバーするためにお金を借りたいと思ってるので、あまり法律家は相談したくないと思ってます。[SEP]法律家には相談したくない。[SEP]やっても無駄だなーと。 -> そうですね[MASK][MASK]、過去にもやったことあるんですが、あまり役に立たなかったと言うか、[MASK]が一度[MASK][MASK]をしてブラックなんですけどまた[MASK]金に手を出してしまってそれをまたカバーするためにお[MASK]を[MASK]たいと思ってるので、あまり法律家は相談したくないと思ってます。[SEP]法律家には相談したくない。[SEP]やっても無駄だなーと。
# はい。[SEP]あなたは、仕事の日に予期せぬ業務が発生したり、疲れた状態で帰宅したりする際の対処法として、帰宅途中にカフェやレストランで作業時間を確保することを考えています。この方法により、転職活動において必要な1日1時間の時間をほぼ確実に確保できると感じており、それが自信度を高める要因となっているようです。[SEP]はい。 -> はい。[SEP]あなたは、仕事の[MASK]に予期せぬ業務が発生したり、疲れた状態で[MASK]したりする際の対処法として、[MASK]途中にカフェやレストランで作業時間を[MASK]することを考えています。この方法により、[MASK][MASK]において必要な1[MASK]1時間の時間をほぼ確実に[MASK]できると感じており、それが自信度を高める要因となっているようです。[SEP]はい。
# あ、はい。[SEP]お薬は指示通り飲めていますか？[SEP]あ、まぁ… -> [MASK]、[MASK]。[SEP]お[MASK]は[MASK][MASK][MASK]めていますか?[SEP][MASK]、[MASK]ぁ...
# うぅん...たまたま起きるとか、そんなに意識していなくても起きられるんですよね。[SEP]意識していなくても起きられる日があるんですね。それは素晴らしいことです。寝る時間と起きる時間の関係に気づくのも、大切な一歩ですね。[SEP]そうなんですよ...逆に起きられない時は、寝るのが遅いのかもしれません。 -> うぅん...[MASK][MASK]とか、そんなに意識していなくても[MASK]られるんですよね。[SEP]意識していなくても[MASK]られる日があるんですね。それは素晴らしいことです。[MASK]る時間と[MASK]時間の関係に気づくのも、大切な一歩ですね。[SEP]そうなんですよ...逆に[MASK]られない時は、[MASK]るのが遅いのかもしれません。
# そうですね…[SEP]そうすると、今、テレビと、仕事の持ち帰りとあったわけだけど、今後、遅刻を減らすためにできそうなことがあるとしたら、どんなこと？[SEP]まずは、テレビですかね。きちんと時間を決めようと思います。録画してあるのをすべて見るとなると、遅くなってしまうので。 -> そうですね...[SEP]そうすると、今、[MASK]と、仕事の[MASK]りとあったわけだけど、今後、[MASK][MASK]を減らすためにできそうなことがあるとしたら、どんなこと?[SEP]まずは、[MASK]ですかね。きちんと時間を決めようと思います。[MASK]してあるのを[MASK]見るとなると、[MASK]なってしまうので。
# そうですね。お金も払ってるんで。[SEP]薬が効かなくても、症状としてはそれほど気にならないんですね。[SEP]そういうわけじゃにんですけど、あきらめてますよね。悪くならないだけいいかって。 -> そうですね。お[MASK]も[MASK]てるんで。[SEP][MASK]が[MASK]なくても、[MASK]としてはそれ[MASK]気にならないんですね。[SEP]そういうわけじゃにんですけど、[MASK]めてますよね。[MASK]ならないだけいいかって。
# ようは、いかに自分で自制するっていうことか～。[SEP]ちょっとトライしてみようかなという気持ちがある。　[SEP]いかにタバコをやめれるか、やめたいなっていう思いもある。美味しいんやったら、美味しい方がいいし。昔に比べたら、食欲も落ちていることは落ちているし。 -> ようは、いかに自分で自制するっていうことか[MASK]。[SEP]ちょっとトライしてみようかなという気持ちがある。[SEP]いかに[MASK]を[MASK]れるか、[MASK]たいなっていう思いもある。[MASK]しいんやったら、[MASK]しい方がいいし。[MASK]に比べたら、食欲も[MASK]ていることは落ちているし。
# ...
# はい。[SEP]まず、持ち帰りは極力減らして、できれば無しにすること。その上で、締め切りに間に合わなそうなことがあったら、早めに言ってもらえる？担当を増やしたりしようと思うから。[SEP]わかりました。それならできそうです。 -> はい。[SEP]まず、[MASK]りは[MASK][MASK][MASK]て、できれば無しにすること。その上で、[MASK][MASK]に[MASK]なそうなことがあったら、[MASK]めに言ってもらえる?担当を増やしたりしようと思うから。[SEP]わかりました。それならできそうです。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]大丈夫ですよ。たまにはそういう日もありますからね。無理せず、自分のペースで行きましょう。[SEP]そうですね。すみません。 -> [MASK]、それが、[MASK]何があったというわけでは[MASK]んですが、[MASK]なくて。[SEP]大丈夫ですよ。[MASK]はそういう[MASK]もありますからね。無理せず、自分の[MASK]で行きましょう。[SEP]そうですね。[MASK]ません。
# それはよさそうですね，でも全てに参加する時間があるかどうか。[SEP]もちろん，時間もたくさん取られるかもしれませんし，あなたの生活に合わないかもしれません。あなたの生活に合うようないくつかの選択肢について話ができればと思うのですが。[SEP]とても嬉しいです -> それはよさそうですね[MASK]でも[MASK]に参加する時間があるかどうか。[SEP][MASK][MASK]時間も[MASK]取られるかもしれませんし[MASK]あなたの生活に合わないかもしれません。あなたの生活に合うようないくつかの[MASK][MASK]について話ができればと思うのですが。[SEP]とても嬉しいです
# もうないです。あのエアコンを買うために電化製品家電屋さんの審査通したんですけど通らなかったんです。なので困っています。[SEP]日々の生活にもうそろそろ困るかもしれないと思ってらっしゃって。。そうかー、Tさんとしてはお金を借りるところがなくて困っている一方で、何か例えば生活を少しこうしたらいいかなとか[SEP] -> もうないです。あの[MASK][MASK]を買うために電化製品家電屋さんの審査通したんですけど通らなかったんです。なので困っています。[SEP]日々の生活にもうそろそろ[MASK]るかもしれないと思って[MASK][MASK]って。。そうかー、[MASK]さんとしてはお[MASK]を[MASK]るところがなくて困っている一方で、何か例えば生活を少しこうしたらいいかなとか[SEP]
# 体重が80㎏とか、大分若い時にかなぁ？20代の時の太っていたとき！でも入社の時がちょうど72㎏だったはずで。[SEP]お～ぉ。じゃぁ、ちょうど入社の時の体重になった。　[SEP]そう。ちょうど入社の時の体重になった。 -> [MASK]が80[MASK]とか、大分若い時にかなぁ?20代の時の太っていたとき!でも[MASK]の時が[MASK]72[MASK]だったはずで。[SEP]お[MASK]ぉ。じゃぁ、ちょうど入社の時の[MASK]になった。[SEP]そう。ちょうど入社の時の[MASK]になった。
# そうですか。[SEP]いや、でも、前に話をさせてもらって、相談者君も気を付けてくれているみたいで良かったよ。遅刻しないようにすることについてはどんな感じ？[SEP]そうですね。気をつけてはいるんですが、なかなか起きられなくて。 -> そうですか。[SEP][MASK]、でも、前に話をさせて[MASK]て、相談者[MASK]も気を付けて[MASK]ているみたいで[MASK]たよ。[MASK][MASK]しないようにすることについてはどんな感じ?[SEP]そうですね。気をつけてはいるんですが、なかなか[MASK]られなくて。
# 本当にやる気が無くて転職のことを考えるだけで憂うつでしたが、このままではいけないと改めて思えたし、じゃあ具体的に何をしていけばいいのかということも明確になったので、今はとても前向きで、気持ちも軽くなりました。まだ時間はあるので、まずはこの方向で継続してみたいと思います。[SEP]そうですね。もう少しやってみて、またうまくいかないようであれば方針を修正するということでいいのではないかと思います。他に何か今日話し合っておいた方がいいことはありますか？[SEP]いいえ。大丈夫です。 -> 本当にやる[MASK]が無くて[MASK]のことを考えるだけで憂うつでしたが、このままでは[MASK]ないと[MASK]思えたし、じゃあ[MASK]的に何をしていけばいいのかということも明確になったので、今はとても前向きで、気持ちも軽くなりました。まだ時間はあるので、まずはこの[MASK]で[MASK]してみたいと思います。[SEP]そうですね。もう少しやってみて、またうまくいかないようであれば方針を修正するということでいいのではないかと思います。他に何か今日話し合って[MASK]た方がいいことはありますか?[SEP]いいえ。大丈夫です。
# 曜日によって業務内容は変わってくるのですが、月、火、木は1日開発の仕事をしていて、木曜日は英会話に通っているので、その前の時間ですかね。月、火は、簡単な書類作成なら、休憩時間などに出来ると思います。水と金は、ミーティングが多くなるので、なかなか日中行うのは難しいですね。この日は退勤後かなと思います。[SEP]だいぶ具体的に考えられていますね！それでは、先ほどは1日1時間とることの自信度は6点か7点ということでしたが、これを、もう少し上げるとすると、何があると上がってきそうですか？[SEP]そうですね…月、火の仕事中に突発的な業務が発生した時や、水、金に疲れて帰宅したときなんかが難しいと思います。この辺りの対処法を見つけることができれば、自信度は高まると思います。 -> 曜日によって業務内容は変わってくるのですが、月、火、木は1[MASK]開発の仕事をしていて、木曜[MASK]は英会話に通っているので、その前の時間ですかね。月、火は、簡単な書類作成なら、休憩時間などに出来ると思います。水と金は、ミーティングが多くなるので、なかなか[MASK]中行うのは難しいですね。この[MASK]は退勤後かなと思います。[SEP]だいぶ具体的に考えられていますね!それでは、先ほどは1[MASK]1時間とることの[MASK]度は6点か7点ということでしたが、これを、もう少し上げるとすると、何があると上がってきそうですか?[SEP]そうですね...月、火の仕事中に突発的な業務が発生した時や、水、金に疲れて[MASK]したときなんかが難しいと思います。この辺りの対処法を見つけることができれば、[MASK]度は高まると思います。
# そうなんですよね。[SEP]でもそれがなかなか難しいと。[SEP]はい。気をつけてはいるんですが… -> そうなんです[MASK]ね。[SEP]でも[MASK]が[MASK][MASK]と。[SEP][MASK]。[MASK]を[MASK]ては[MASK]んですが...
# そうですね、ま、できる、話ししてどうなるかわからないんですけど、うまく行くんだったらしても良いかなー。[SEP]じゃあーその辺の、少し専門家の方とのいろんな面談の調整とか少し進めていくというの、それいかがですか？[SEP]そうですね、お願いしてもいいですか。 -> そうですね、ま、できる、話ししてどうなるかわからないんですけど、うまく[MASK]んだったらしても良いかな[MASK]。[SEP]じゃあ[MASK]その[MASK]の、少し[MASK][MASK]の方とのいろんな面談の[MASK]とか少し進めていくというの、それいかがですか?[SEP]そうですね、お[MASK]してもいいですか。
# そうですね。やる気というよりも、淡々と、計画的に、応募書類を出し続けるということですかね。気分的なことよりも、現職との両立がキーになりそうです。[SEP]やる気というよりも、いかに現在のお仕事と両立させながら、応募を継続していくかが重要だろうということですね。[SEP]はい -> そうですね。やる[MASK]という[MASK]も、淡々と、[MASK]的に、応募[MASK]を出し続けるということですかね。気分的なこと[MASK]も、現職との両立がキーになりそうです。[SEP]やる[MASK]という[MASK]も、いかに現在のお仕事と両立させながら、応募を継続していくかが重要[MASK]ということですね。[SEP]はい
# はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。[SEP]時間管理に関して少し困っているようですね。特に大きな問題があったわけではないけれど、朝の時間に間に合わせることが難しかったということが理解できます。日常生活での小さな挑戦にも前向きに取り組んでいることは、とても良いことだと思います。[SEP]実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。 -> はい。せっかくなので、[MASK]に時間を[MASK]てみようと思います。本当に、来[MASK]も今の[MASK]で[MASK][MASK]というのは、自分にとって良いことではないと思うので。[SEP]時間管理に関して少し困っているようですね。特に大きな問題があったわけではないけれど、朝の時間に間に合わ[MASK]ことが難しかったということが理解できます。日常生活での小さな挑戦にも前向きに取り組んでいることは、とても良いことだと思います。[SEP]実際どうなるかはわからないですけどね。[MASK]的に進められるといいとは思います。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]そっか、大事がなかったなら良かったよ。時間通りに来ようとはしてくれたんだね。[SEP]そうですね。すみません。 -> [MASK]、それが、[MASK]何があったというわけでは[MASK]んですが、[MASK]なくて。[SEP][MASK]っか、大事がなかったなら[MASK]たよ。時間通りに来ようとはして[MASK]たんだね。[SEP]そうですね。[MASK]ません。
# そうよ，もう息子はお腹の中にいないんだから。だから吸っていないと言ったのは，彼のそばでは吸わないようにすごく気をつけているからなの。結構できてると思っている。他の人にも彼の傍では吸わせないようにしているし…。[SEP]あなたはできる限りのことをしていると。[SEP]はい。 -> そうよ[MASK]もう息子はお腹の中にいないんだから。だから[MASK]っていないと言ったのは[MASK][MASK]の[MASK]では[MASK]わないようにすごく気をつけているからなの。結構できてると思っている。他の人にも[MASK]の傍では[MASK]わせないようにしているし...。[SEP]あなたはできる限りのことをしていると。[SEP]はい。
# そうですね。あとは、時間ですかね。どうしても、なかなかうまく時間が使えていない感じがするので、その辺りについてご相談させていただければと思います。[SEP]時間の使い方について相談できると、今後、今のお仕事をしながら少なくとも今以上には、転職活動を効率的に進めることができるだろうということですね。[SEP]はい。 -> そうですね。あとは、時間ですかね。どうしても、[MASK]うまく時間が使えていない感じがするので、その辺りについてご相談させて[MASK]ければと思います。[SEP]時間の使い方について相談できると、[MASK]、今のお仕事をしながら少なくとも今以上には、[MASK][MASK]を[MASK]的に[MASK]ことができる[MASK]ということですね。[SEP]はい。
# そう。怖さ。ここからマックス90㎏までいったから。[SEP]そういう経験をしながら、今、体重を減らしてきているから、タバコをやめるのが怖い。　[SEP]タバコはやめたいけど、体重が増えたりするのが心配。 -> そう。怖さ。ここからマックス90kgまでいったから。[SEP]そういう経験をしながら、今、[MASK]を減らしてきているから、[MASK]を[MASK]るのが[MASK]。[SEP][MASK]は[MASK]たいけど、[MASK]が[MASK]たりするのが心配。
# はい。[SEP]OK，でも本当はどこかでたばこをやめたいと思っているように聞こえます。[SEP]ええ，そうすべきだと分かっています，毎年新年に“今年は禁煙する”といいますが，何かあるとできない，やめられないんです。何もなければやめられるのに・・・。 -> はい。[SEP]OK[MASK]でも本当はどこかでたばこを[MASK]たいと思っているように聞こえます。[SEP]ええ[MASK]そうすべきだと分かっています[MASK]毎年新年に“今年は禁煙する”といいますが[MASK]何かあるとできない[MASK][MASK]られないんです。何もなければ[MASK]られるのに・・・。
# わかりました。とにかくわかりました。[SEP]息子さんが何度も中耳炎を繰り返していることは、あなたにとっても息子さんにとっても大きなストレスですね。タバコの煙が子どもの耳感染のリスクファクターの一つであることを考慮すると、あなたが喫煙していることが関連している可能性があります。息子さんの周りで吸わないように気をつけているというあなたの努力は理解していますが、それでもタバコの影響は考慮に入れなければならないかもしれません。[SEP] -> わかりました。[MASK]わかりました。[SEP][MASK]さんが何度も中[MASK][MASK]を繰り返していることは、あなたにとっても[MASK]さんにとっても大きなストレスですね。タバコの煙が子どもの耳感染のリスクファクターの一つであることを考慮すると、あなたが[MASK]していることが関連している可能性があります。[MASK]さんの[MASK]で吸わないように気をつけているというあなたの努力は理解していますが、それでもタバコの影響は考慮に入れなければならないかもしれません。[SEP]
# ええ，その通りです。[SEP]以前やめたときはどうやってできたのですか？[SEP]わかりません，今考えてみてもどのようにしたかすら覚えてないんです。でも，とにかくやったんです。私，想像できなかったの。タバコを吸う女性の赤ちゃんが死産になるとか，早産になるとか，また，障害児として生まれてくるなんてことを。だからもう飽き飽きするほど言われたでしよ。ね，もう今は危険な状態じゃないんです。 -> ええ[MASK]その通りです。[SEP]以前やめたときはどうやってできたのですか?[SEP]わかりません[MASK]今考えてみてもどのようにしたかすら覚えてないんです。でも[MASK]とにかくやったんです。私[MASK]想像できなかったの。タバコを吸う女性の赤ちゃんが死産になるとか[MASK]早産になるとか[MASK]また[MASK]障害児として生まれてくるなんてことを。だからもう飽き飽きするほど言われたでしよ。ね[MASK]もう今は危険な状態じゃないんです。
# 薬は好きではありません。[SEP]OK，他の方と一緒に体験することができるサポートグループや勉強会もあります。時々，ただそのサポートを受けるだけで大きな恩恵を被る。特に喫煙がストレス緩和になるような人にとってはそんな場所が役立つかもしれません。[SEP]それはよさそうですね，でも全てに参加する時間があるかどうか。 -> 薬は好きではありません。[SEP][MASK][MASK]他の方と一緒に[MASK]することができるサポートグループや勉強会もあります。時[MASK][MASK]ただそのサポートを受けるだけで大きな恩恵を被る。特に[MASK]が[MASK]緩和になるような人にとってはそんな場所が役立つかもしれません。[SEP]それはよさそうですね[MASK]でも全てに参加する時間があるかどうか。
# はい。[SEP]あなたは、月曜日と火曜日に予期せぬ業務が発生したり、水曜日と金曜日に疲れて帰宅することが、転職活動における時間確保の障壁となっていると感じていますね。このような状況に対処する方法を見つけることが、あなたの自信度を向上させる鍵になりそうです。[SEP]はい。 -> はい。[SEP]あなたは、月曜[MASK]と火曜[MASK]に予期せぬ業務が発生したり、水曜[MASK]と金曜[MASK]に疲れて[MASK]することが、[MASK][MASK]における時間[MASK]の障壁となっていると感じていますね。このような状況に対処する方法を見つけることが、あなたの自信度を向上させる鍵になりそうです。[SEP]はい。
# そうですね。何とかして、脱出しなくてはいけないと思います。[SEP]来年度から別の職場で働くために出来る限りのことをしたいという思いはあるわけですね。[SEP]そうですね。現実的に、時間が無いということが大きいかもしれませんね。 -> そうですね。何とかして、[MASK]しなくては[MASK]ないと思います。[SEP]来[MASK]から[MASK]の[MASK]で[MASK]ために[MASK]限りのことをしたいという思いはあるわけですね。[SEP]そうですね。[MASK]的に、時間が無いということが大きいかもしれませんね。
# そうなんですよね…[SEP]毎日30分か、1時間かというのが、良いところですかね。[SEP]はい。 -> そうなんです[MASK]ね...[SEP][MASK][MASK][MASK]か、[MASK]時間かというのが、[MASK][MASK]ですかね。[SEP][MASK]。
# うん。[SEP]今の気持ちとして続けられそうだなという気持ちは１０点満点としたら何点ぐらい？[SEP]3 -> [MASK]。[SEP]今の気持ちとして[MASK]られそうだなという気持ちは[MASK][MASK][MASK]としたら何[MASK][MASK]?[SEP][MASK]
# いいえ。大丈夫です。[SEP]わかりました。それでは、今日はこれで面談を終えたいと思います。またいつでもご連絡ください。本日はありがとうございました。[SEP]ありがとうございました。 -> いいえ。大[MASK]夫です。[SEP]わかりました。それでは、今日はこれで[MASK][MASK]を[MASK]たいと思います。また[MASK]でもご[MASK]ください。[MASK][MASK]はありがとうございました。[SEP]ありがとうございました。
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]禁煙に向けての第一歩として、禁煙サポートプログラムに申し込み、ニコチンパッチを試すことを決めたのは素晴らしいことです。食事量の管理にも注意しながら、禁煙に成功するための支援を得ることが重要です。この取り組みは、あなたの健康改善に大きく貢献することになるでしょう。[SEP] -> ですね。まずはあれ[MASK]禁煙サポート[MASK][MASK]に申込んで[MASK]を[MASK]ところから始めてみようかな[MASK]と。[SEP]禁煙に向けての第一歩として、禁煙サポートプログラムに申し込み、ニコチン[MASK]を試すことを決めたのは素晴らしいことです。[MASK]量の管理にも注意しながら、禁煙に成功するための支援を得ることが重要です。この取り組みは、あなたの健康改善に大きく貢献することになるでしょう。[SEP]
# 毎月。[SEP]じゃあ今、お金を貯めて何かやりたい事があるとそんな感じですか？[SEP]お金を貯めて何かやりたいというわけではないんですけど、日々の生活が厳しくて、追われてお付き合いのお金とか -> [MASK]。[SEP]じゃあ今、お[MASK]を[MASK]めて何かやりたい事があるとそんな感じですか?[SEP]お[MASK]を[MASK]めて何かやりたいというわけではないんですけど、日々の生活が[MASK]て、追われてお[MASK]のお[MASK]とか
# はい。[SEP]あなたは、1日1時間の時間を転職活動に費やすことを意識しており、帰宅途中にカフェやレストランを利用することで、この目標を8、9割達成できると考えています。このような具体的な計画は、あなたの転職活動への自信を高めるのに役立つでしょう。[SEP]はい。 -> はい。[SEP]あなたは、1[MASK]1時間の時間を[MASK][MASK]に費やすことを意識しており、[MASK][MASK]に[MASK]やレストランを利用することで、この目標を8、9割達成できると考えています。このような具体的な計画は、あなたの[MASK][MASK]への自信を高めるのに役立つでしょう。[SEP]はい。
# うん、知りたい。[SEP]自分が成長している気持ちで勉強できたらいいなと。[SEP]うん。 -> [MASK]、[MASK]たい。[SEP][MASK]が[MASK]している[MASK]で[MASK][MASK]たらいいなと。[SEP][MASK]。
# やめていた間に、仕出し弁当が、ガッツンときてもうて。メシうめーっていうのがあったから。[SEP]タバコをやめている時にご飯が美味しかった。　[SEP]そう！やめている間に、そこの仕出し弁当は元々不味かったのに、その弁当でさえ、ご飯が何でもうめって思った。 -> [MASK]ていた[MASK]に、仕出し弁当が、ガッツンときてもうて。メシうめーっていうのがあったから。[SEP][MASK]を[MASK]ている時にご[MASK]が[MASK]しかった。[SEP]そう![MASK]ている間に、そこの仕出し弁当は元々不味かったのに、その弁当でさえ、ご[MASK]が何でもうめって思った。
# そうですね。[SEP]今はちょと環境も変わって、勉強する環境にないけど、その時のことを思い出すともう一度やってみようかなって思う。[SEP]思う。 -> そうですね。[SEP]今は[MASK]と[MASK]も[MASK]て、[MASK]する[MASK]にないけど、その時のことを[MASK][MASK]ともう一[MASK]やってみようかなって思う。[SEP]思う。
# そうですね。とりあえずは、1時間やるということで、しばらくやってみようと思います。[SEP]30分よりは1時間に決めた方が良さそうな感じだったんですね。[SEP]はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来年度も今の職場で働き続けるというのは、自分にとって良いことではないと思うので。 -> そうですね。とりあえずは、[MASK]時間やるということで、しばらくやってみようと思います。[SEP][MASK][MASK][MASK]は[MASK]時間に決めた方が[MASK]さそうな感じだったんですね。[SEP]はい。せっかくなので、大胆に時間を取ってみようと思います。本当に、来[MASK]も今の職場で[MASK]続けるというのは、自分にとって良いことではないと思うので。
# うぅん...たまたま起きるとか、そんなに意識していなくても起きられるんですよね。[SEP]あなたがたまたま早起きできたり、意識せずに起きられる日があるということは、その日の体調や心の状態が良好であることを示しているかもしれませんね。それは、健康的な生活リズムを維持している良い兆しです。[SEP]そうなんですよ...逆に起きられない時は、寝るのが遅いのかもしれません。 -> うぅん...[MASK][MASK]とか、そんなに[MASK]していなくても[MASK]られるんですよね。[SEP]あなたが[MASK]早起きできたり、意識せずに[MASK]られる日があるということは、その日の体調や心の状態が良好であることを示しているかもしれませんね。それは、健康的な生活リズムを維持している良い兆しです。[SEP]そうなんですよ...逆に[MASK]られない時は、[MASK]るのが遅いのかもしれません。
# そうですね。やっぱり、自分のために時間は使うべきだという思いがあります。今の仕事は、それが嫌いなわけではないですが、自分が今やるべきことはそれではないと思います。自分の人生やキャリアの優先順位を上げるべきだと思います。[SEP]仕事は仕事で大事だけれど、今自分のために何が必要かということを考えると、それは、転職に向けた活動を優先することだということですね。[SEP]はい。 -> そうですね。やっぱり、自分のために時間は[MASK][MASK]だという思いがあります。今の仕事は、それが嫌いなわけではないですが、自分が今やる[MASK]ことはそれではないと思います。自分の人生やキャリアの優先順位を[MASK][MASK]だと思います。[SEP]仕事は仕事で大事だけれど、今自分のために何が必要かということを考えると、それは、[MASK]に[MASK]た[MASK]を優先することだということですね。[SEP]はい。
# はい。[SEP]あなたは、帰宅途中にカフェやレストランで作業時間を確保することを考えているようですね。このような工夫をすることで、転職活動に必要な1日1時間の時間を実質的に確保し、目標達成に向けた自信が高まると感じているのですね。[SEP]はい。 -> はい。[SEP]あなたは、[MASK][MASK]に[MASK]やレストランで作業時間を[MASK]することを考えているようですね。このような工夫をすることで、[MASK][MASK]に必要な1[MASK]1時間の時間を実質的に[MASK]し、目標達成に向けた自信が高まると感じているのですね。[SEP]はい。
# そう。ちょうど入社の時の体重になった。[SEP]この体重がタバコをやめることで維持できないじゃないかという怖さがある。　[SEP]そう。怖さ。ここからマックス90㎏までいったから。 -> そう。[MASK][MASK]の時の[MASK]になった。[SEP]この[MASK]が[MASK]を[MASK]ることで維持できないじゃないかという[MASK]さがある。[SEP]そう。怖さ。ここからマックス90[MASK]までいったから。
# ええ。[SEP]ここからどうするべきだと思いますか？[SEP]わかりません，私…助けがほしい，どういった助けを必要としているかわからない。 -> ええ。[SEP][MASK]からどうする[MASK]だと思いますか?[SEP][MASK]ません[MASK]私...[MASK]が[MASK][MASK]どういった[MASK]を必要としているかわからない。
# そうすると、やっぱパッチか。（少し間を置いて）一番怖いのは禁煙して太るのが怖いかなっと。[SEP]体重が増えちゃうこと。　[SEP]やめていた間に、仕出し弁当が、ガッツンときてもうて。メシうめーっていうのがあったから。 -> そうすると、やっぱ[MASK]か。[MASK]少し間を置いて[MASK]一番[MASK]のは禁煙して太るのが[MASK]かな[MASK]と。[SEP][MASK]が増えちゃうこと。[SEP][MASK]ていた間に、仕出し弁当が、ガッツンときてもうて。メシうめーっていうのがあったから。
# はい[SEP]それが、今と違ってどのようになっていると、良さそうですか？[SEP]そうですね。今は、応募書類の締め切りに追われている感じなので、もう少し余裕をもって準備をしたいです。 -> はい[SEP]それが、今と[MASK]てどのようになっていると、[MASK][MASK]そうですか?[SEP]そうですね。今は、[MASK][MASK]の締め切りに追われている感じなので、もう少し[MASK]を[MASK]て[MASK]をしたいです。
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]タバコをやめたいという意志があることが伺えます。しかし、タバコをやめることで体重が増加することに対する不安が大きいようですね。過去に禁煙に成功した経験から、食事の量が増えることを経験しているため、それが再び起こるかもしれないという心配があるようです。[SEP] -> ですね。まずはあれ[MASK]禁煙サポートプログラム[MASK]に申込んで[MASK]をもらうところから始めてみようかな[MASK]と。[SEP]タバコを[MASK]たいという意志があることが伺えます。しかし、タバコを[MASK]ることで[MASK]が増加することに対する不安が大きいようですね。過去に禁煙に成功した経験から、[MASK]の量が増えることを経験しているため、それが再び起こるかもしれないという心配があるようです。[SEP]
# そうです，ええ。彼は端息はないし，彼の友達が抱えているようないろいろな問題もないし。それに，ずっと前，やめようと思ったのですが，今はどうやったらできるのかわかりません，わからないのです。[SEP]妊娠した時はどうしてやめようと思ったのですか？[SEP]ええと，彼がお腹にいるときは，なんでも分け合っているわけだから，胎児に影響があるかもと分かっていたし，息子に何かがあったら生きていけないと思っていました。 -> そうです[MASK]ええ。彼は端息はないし[MASK]彼の友達が抱えているようないろいろな問題もないし。それに[MASK]ずっと前[MASK]やめようと思ったのですが[MASK]今はどうやったらできるのかわかりません[MASK]わからないのです。[SEP]妊娠した時はどうしてやめようと思ったのですか?[SEP]ええと[MASK]彼がお腹にいるときは[MASK]なんでも分け合っているわけだから,胎児に影響があるかもと分かっていたし,息子に何かがあったら生きていけないと思っていました。
# そうですね。今は、応募書類の締め切りに追われている感じなので、もう少し余裕をもって準備をしたいです。[SEP]いいじゃないですか！早めに準備すると気分的にも余裕が持てそうですね。[SEP]そうなんです。今はいつもぎりぎりで、夜20時までに大きな郵便局まで書類を出しに行くこともあるので、それが無いだけでも、だいぶ効率的になると思います。 -> そうですね。今は、応募[MASK]の締め切りに追われている感じなので、もう少し[MASK]をもって[MASK]をしたいです。[SEP]いいじゃないですか!早めに[MASK]すると気分的にも[MASK]が持てそうですね。[SEP]そうなんです。今はいつもぎりぎりで、夜20時までに大きな郵便局まで[MASK]を出しに行くこともあるので、それが無いだけでも、[MASK][MASK]効率的になると思います。
# ですね。まずはあれ(禁煙サポートプログラム)に申込んでパッチをもらうところから始めてみようかなっと。[SEP]タバコをやめた時の食事の美味しさを感じることについては、一つの課題となっています。食事がより美味しく感じられるために、過食傾向になる可能性があるということですね。しかし、現在の食事量が減っていることは、タバコをやめた際の体重増加のリスクを減らすことにつながりそうです。[SEP] -> ですね。まずはあれ(禁煙サポートプログラム)に申込んで[MASK]をもらうところから始めてみようかな[MASK]と。[SEP]タバコをやめた時の[MASK]の[MASK]しさを感じることについては、一つの課題となっています。[MASK]がより[MASK]しく感じられるために、過食傾向になる可能性があるということですね。しかし、現在の[MASK]量が減っていることは、タバコをやめた際の[MASK]増加のリスクを減らすことにつながりそうです。[SEP]
# そうですね。1時間となると、なかなか難しそうですが…でも何とかなりますかね。まぁ、6点か7点ぐらいでしょうか。[SEP]だいぶ自信度も高そうですね。[SEP]そうですね。無理ではないと思います。 -> そうですね。[MASK]時間となると、[MASK]難しそうですが...でも何とかなりますかね。まぁ、[MASK][MASK]か7[MASK]ぐらいでしょうか。[SEP][MASK][MASK][MASK]度も高そうですね。[SEP]そうですね。無理ではないと思います。
# そうですね。すみません。[SEP]いや、別に責めてるつもりはないんだよ。もし何か時間通りに来るために手伝えることがあれば協力したいと思って。[SEP]そうですか。 -> そうですね。[MASK]ません。[SEP][MASK]、別に[MASK]てる[MASK]はないんだよ。もし何か時間[MASK]に[MASK]ために[MASK][MASK]ことがあれば協力したいと思って。[SEP]そうですか。
# そうですね。一応会社の規定では、3か月前までに退職願を出さなくてはいけないことになっているのですが、当面はそれを目指して、それが難しくても、今後も転職活動を続けていく気ではいます。[SEP]そのために今日できることとしては、今後の見通しについてお伺いしていくことですかね。他に何か、やる気を高めるために出来そうなことはありますか？[SEP]そうですね。あとは、時間ですかね。どうしても、なかなかうまく時間が使えていない感じがするので、その辺りについてご相談させていただければと思います。 -> そうですね。一応会社の規定では、3か月前までに退職願を出さなくては[MASK]ないことになっているのですが、当面はそれを目指して、それが難しくても、[MASK]も[MASK][MASK]を続けていく気ではいます。[SEP]そのために今日できることとしては、今後の見通しについてお伺いしていくことですかね。他に何か、やる[MASK]を[MASK]ために出来そうなことはありますか?[SEP]そうですね。あとは、時間ですかね。どうしても、[MASK]うまく時間が使えていない感じがするので、その辺りについてご相談させて[MASK]ければと思います。
# いや、それが、特に何があったというわけでは無いんですが、間に合わなくて。[SEP]朝の時間に間に合わせようとする努力をされていたのですね。何か特別なことがあったわけではなく、ただ時間に追われていたということで、そのような状況にも関わらず、最善を尽くそうとされたことは称賛に値します。[SEP]そうですね。すみません。 -> [MASK]、それが、特に何があったというわけでは[MASK]んですが、[MASK]なくて。[SEP][MASK]の時間に[MASK][MASK]とする[MASK]をされていたのですね。何か特別なことがあったわけではなく、ただ時間に追われていたということで、そのような状況にも関わらず、最善を尽くそうとされたことは称賛に値します。[SEP]そうですね。[MASK]ません。
# 付き合いの方が多くて厳しくてやっぱりついつい簡単にカードローンとかしてます。[SEP]お金が貯まらない原因は今はカードローンかなーって思ってらっしゃるんですね。[SEP]そうですね。出て行くお金を抑えきれなくて、どんどんどんどん借りてばっかりいます 。 -> [MASK]の方が多くて[MASK]てやっぱりついつい簡単にカードローンとかしてます。[SEP]お[MASK]が[MASK]まらない原因は今はカードローンかなーって思って[MASK]しゃるんですね。[SEP]そうですね。出て行くお[MASK]を[MASK]きれなくて、どんどんどんどん[MASK]てばっかりいます。
# そう、それが分かっているもんだから、余計怖いというか、、、スイッチが入った瞬間怖いというか、また食べ過ぎてしまうんやろな～みないな。[SEP]食べ過ぎなければやめられるのに！っと思う。　[SEP]タバコをやめたら、メシがうまくなったっていう話を聞いて、「これ！」って思って。 -> そう、それが分かっているもんだから、余計[MASK]というか、、、スイッチが入った瞬間[MASK]というか、また[MASK]過ぎてしまうんやろな[MASK]みないな。[SEP]食べ過ぎなければ[MASK]られるのに![MASK]と思う。[SEP][MASK]を[MASK]たら、メシがうまくなったっていう話を聞いて、「これ!」って思って。
# いえいえ。たまたま期限のある仕事だったので。[SEP]一つはそれで、他には？[SEP]そうですね…まぁ、テレビ見すぎなのかな。 -> [MASK][MASK]。[MASK][MASK]のある仕事だったので。[SEP]一[MASK]はそれで、[MASK]には?[SEP]そうですね...まぁ、[MASK]見[MASK]なのかな。

# %% [markdown]
# 入力用のデータができた。
#
# 後はmask推定をしてもらい、上位2件のデータを水増しデータセットの中に入れる
#
# 今回は5種類の水増しデータセットを作成するため、元データと水増しデータの対応をしっかり行う

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
print(device)
# Out:
# cuda

# %%
model = transformers.BertForMaskedLM.from_pretrained(model_name)

# %% [markdown]
# MASKが二つある場合も出力はおそらく同じ。
#
# BertのOutput.logitsには全トークン分の行列が含まれているため、そこからMASKした2つののインデックスを取り出せばいいと思われる
#
# でもテストしておく

# %%
print(masked_train_list)
# Out:
# {'train0': [{'sentence': '思う。[SEP]こうやって今日もいらっしゃったんですけど、もっとやりたいというのがあって、これからも、こういう会に参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、会社でも使う機会がないからやらなくてもいいのかなとも思っちゃう。', 'masked_sentence': '思う。[SEP][MASK]やって今日もいらっしゃったんですけど、もっと[MASK]たいというのがあって、これからも、[MASK]いう[MASK]に参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、[MASK]でも[MASK][MASK]がないから[MASK]なくてもいいのかなとも思っちゃう。', 'labels': [], 'miti_code': 2, 'maskword_id': [12587, 15054, 722, 15243, 14092, 20425, 13041, 13041], 'masked_ids': [4, 19, 32, 34, 56, 59, 60, 64], 'source': 'case2!.csv'}, {'sentence': 'はい。[SEP]今日は初めは転職に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事と転職活動を両立させるかが大事ということから、1日1時間と時間を決めて、転職活動に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を取れば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の転職の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい', 'masked_sentence': 'はい。[SEP]今日は初めは[MASK]に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事と[MASK][MASK]を両立させるかが大事ということから、1[MASK]1時間と時間を決めて、[MASK][MASK]に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を[MASK]ば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の[MASK]の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい', 'labels': [], 'miti_code': 6, 'maskword_id': [27016, 27016, 27016, 27016, 12636, 12636, 2698, 20972], 'masked_ids': [8, 40, 41, 55, 64, 65, 100, 146], 'source': 'case1.csv'}, {'sentence': 'わからない。[SEP]カウンセリングの勉強に取り組む気が起きないと感じているのですね。以前は同じ会社の人と一緒に学んでいたり、講習会に参加したりしていたが、最近は部署が変わり、勉強する機会が減ってしまったということですね。以前は勉強が役立って楽しかったが、現在はそのような環境がなくなってしまったため、やる気が出なくなっているということですね。[SEP]', 'masked_sentence': 'わからない。[SEP]カウンセリングの[MASK]に取り組む気が起きないと感じているのですね。以前は同じ[MASK]の人と一緒に学んでいたり、講習[MASK]に参加したりしていたが、最近は部署が変わり、[MASK]する[MASK]が減ってしまったということですね。以前は[MASK]が役立って[MASK]かったが、現在はそのような[MASK]がなくなってしまったため、やる気が出なくなっているということですね。[SEP]', 'labels': [], 'miti_code': 6, 'maskword_id': [12587, 17372, 17372, 17372, 15054, 13348, 722, 15248], 'masked_ids': [8, 26, 38, 55, 57, 71, 76, 87], 'source': 'case2!.csv'}, {'sentence': 'そうですねぇ、そういった目標は持ってますけどねぇ。[SEP]あんまり精神疾患の治療へのカウンセリングの応用とか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の学会ではあったりとか、そういう情報だけはあったので、勉強したいなってところはあるんですけど。', 'masked_sentence': 'そうですね[MASK]、そういった目標は持ってますけどね[MASK]。[SEP]あんまり[MASK][MASK]の治療へのカウンセリングの[MASK]とか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の[MASK]ではあったりとか、そういう[MASK]だけはあったので、[MASK]したいなってところはあるんですけど。', 'labels': [], 'miti_code': 0, 'maskword_id': [14586, 17372, 13830, 12823, 18, 18, 17434, 17337], 'masked_ids': [4, 16, 21, 22, 30, 58, 68, 76], 'source': 'case5!.csv'}, {'sentence': '実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]1日1時間、転職活動のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10点として、あまり重要でないというのを0点とすると、Aさんにとっては、何点くらいになりそうですか？[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。', 'masked_sentence': '実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP][MASK][MASK][MASK]時間、[MASK][MASK]のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10[MASK]として、あまり重要でないというのを0[MASK]とすると、Aさんにとっては、何[MASK]くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。', 'labels': [], 'miti_code': 4, 'maskword_id': [27016, 12636, 2698, 32, 32, 3601, 3601, 3601], 'masked_ids': [25, 26, 27, 30, 31, 65, 79, 92], 'source': 'case1.csv'}, {'sentence': '一時的に業研で禁煙やってたもんだから、一応協力するわ～、っていうけどもぉ～。なんや、なんでこんなイライラするんやろなーって。だからパッチ、パッチがいるかな。でもパッチをやっていたKさんがパッチしながら普通に吸っていて、それはいかんやろーって（笑）。[SEP]パッチは効果なさそう。\u3000[SEP]パッチはそう、でも飲み薬よりはパッチ！', 'masked_sentence': '一時的に業研で禁煙やってたもんだから、一応協力するわ[MASK]、っていうけどもぉ[MASK]。なんや、なんでこんなイライラするんやろなーって。だから[MASK]、[MASK]がいるかな。でも[MASK]をやっていたKさんが[MASK]しながら普通に吸っていて、それはいかんやろーって(笑)。[SEP][MASK]は効果なさそう。[SEP][MASK]はそう、でも飲み薬よりはパッチ!', 'labels': [], 'miti_code': 2, 'maskword_id': [109, 109, 28613, 28613, 28613, 28613, 28613, 28613], 'masked_ids': [19, 26, 46, 48, 56, 65, 89, 96], 'source': 'case8!.csv'}, {'sentence': '彼によくないとわかっているからです。耳の感染症や端息に関していろいろなものを読みました…でも耳の感染症を患っている子の中には親が吸ってない人もいるからそれだけじゃないと思って[SEP]そうですか。あなたがタバコをすっていることが彼に影響しているのではと心配する一方で，タバコを吸うことがこのような問題の原因になっているかどうかわからないと思っているのですね。[SEP]そうです，ええ。彼は端息はないし，彼の友達が抱えているようないろいろな問題もないし。それに，ずっと前，やめようと思ったのですが，今はどうやったらできるのかわかりません，わからないのです ...

# %%
model.to(device)
data_augmented = {}
model.eval()
sp_ids_list = [tokenizer.cls_token_id, tokenizer.pad_token_id]
for key in masked_train_list.keys():
    train_data = masked_train_list[key]
    data_augmented[key] = []
    for data in train_data:
        count = 0
        sentence = data["sentence"]
        masked_sentence = data["masked_sentence"]
        miti_code = data["miti_code"]
        source = data["source"]
        maskword = data["maskword_id"]
        masked_ids = data["masked_ids"]
        inputs = tokenizer(masked_sentence)
        with torch.no_grad():
            outputs = model(torch.tensor([inputs["input_ids"]]).to(device))
        predictions = [outputs.logits[0, mid].topk(multiplier_augmentation+1).indices for mid in masked_ids]
        #print(predictions)
        #すべてのMASKを埋めることができる1組の予測を取り出す
        for i in range(len(predictions[0])):
            if count >= multiplier_augmentation:
                break
            prediction_list = []
            new_sentence_ids = inputs["input_ids"]
            preds = [predictions[j][i] for j in range(len(predictions))]
            #print(preds)
            #各予測をMASK位置に埋め込んでいく
            for k in range(len(preds)):
                mid = masked_ids[k]
                p = preds[k]
                prediction_list.append(p.item())
                decodeword = tokenizer.decode(p)
                new_sentence_ids[mid] = p
            new_sentence_ids = [index for index in new_sentence_ids if index not in sp_ids_list][:-1]
            decoded_sentence = tokenizer.decode(new_sentence_ids)
            new_sentence = "".join(decoded_sentence.split(" "))
            print(new_sentence)
            if maskword != prediction_list:
                count += 1
                data_augmented[key].append({"sentence":new_sentence, "miti_code":data["miti_code"], "augmented":True, "source":data["source"]})
        data_augmented[key].append({"sentence":sentence,"miti_code":data["miti_code"], "augmented":False, "source":data["source"]})
# Out:
# 思う。[SEP]そうやって今日もいらっしゃったんですけど、もっとやりたいというのがあって、これからも、そういうことに参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、それでもやるまりがないから続けなくてもいいのかなとも思っちゃう。
# 思う。[SEP]こうやって今日もいらっしゃったんですけど、もっと続けたいというのがあって、これからも、こういうものに参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、今でも、ところがないからやらなくてもいいのかなとも思っちゃう。
# 思う。[SEP]いろいろやって今日もいらっしゃったんですけど、もっと行きたいというのがあって、これからも、ちゃんという活動に参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、自分でも前意味がないから辞めなくてもいいのかなとも思っちゃう。
# 思う。[SEP]色々やって今日もいらっしゃったんですけど、もっと会いたいというのがあって、これからも、いろいろいうイベントに参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、これでも勝ちことがないからやめなくてもいいのかなとも思っちゃう。
# 思う。[SEP]ずっとやって今日もいらっしゃったんですけど、もっと楽しみたいというのがあって、これからも、もっというプロジェクトに参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、いまでもやり時間がないから行かなくてもいいのかなとも思っちゃう。
# 思う。[SEP]それやって今日もいらっしゃったんですけど、もっと歌いたいというのがあって、これからも、というフェスに参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、何でもいい気がないからしなくてもいいのかなとも思っちゃう。
# 思う。[SEP]とやって今日もいらっしゃったんですけど、もっと進みたいというのがあって、これからも、色々いうところに参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、そうでもそのがいがないから始めなくてもいいのかなとも思っちゃう。
# 思う。[SEP]正直やって今日もいらっしゃったんですけど、もっと関わりたいというのがあって、これからも、どういう運動に参加して続けていきたいと。[SEP]思う。続けていきたいって思うけど、なんでも決め切りがないから止めなくてもいいのかなとも思っちゃう。
# はい。[SEP]今日は初めは明日に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事とやる気を両立させるかが大事ということから、1日1時間と時間を決めて、その的に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を使えば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の仕事の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めはオリンピックに向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事とモチベーションを両立させるかが大事ということから、1人1時間と時間を決めて、それように時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を持てば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の活躍の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めは将来に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事とやり活動を両立させるかが大事ということから、1時間1時間と時間を決めて、余ために時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を取れば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の成功の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めは目標に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事とその生活を両立させるかが大事ということから、1分1時間と時間を決めて、もっと計に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間をとれば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の飛躍の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めは受験に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事と本とを両立させるかが大事ということから、1週間1時間と時間を決めて、気めに時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を切れば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の活動の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めは仕事に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事とのづくりを両立させるかが大事ということから、1週1時間と時間を決めて、とにかく時間に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間をもらえば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の成長の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めは次に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事と勉作りを両立させるかが大事ということから、1、1時間と時間を決めて、どのことに時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間を思えば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の復帰の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# はい。[SEP]今日は初めは復帰に向けたやる気をどのように高めるかという話でしたが、気持ちの問題というよりも、いかに現在の仕事と勉強仕事を両立させるかが大事ということから、1~1時間と時間を決めて、じ時に時間を使うといいのではないかという方向で話を進めてきましたね。Aさんは、今日のように時間をもてば、冷静に、客観的に、問題を分析して対処法を考える力がある方だと感じました。今日話し合ったような方向で進めていけると、来年度の改革の可能性は確実に高まるだろうと思います。実際エージェントからもこのまま続けてみてはと言われているということなので、今進まれている方向性は間違いではないのではないかと思います。[SEP]はい
# わからない。[SEP]カウンセリングの仕事に取り組む気が起きないと感じているのですね。以前は同じ部署の人と一緒に学んでいたり、講習会に参加したりしていたが、最近は部署が変わり、参加する機会が減ってしまったということですね。以前はそれが役立っているかったが、現在はそのようなことがなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングの勉強に取り組む気が起きないと感じているのですね。以前は同じ職場の人と一緒に学んでいたり、講習などに参加したりしていたが、最近は部署が変わり、勉強することが減ってしまったということですね。以前は勉強が役立っていかったが、現在はそのような仕事がなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングの業務に取り組む気が起きないと感じているのですね。以前は同じ会社の人と一緒に学んでいたり、講習等に参加したりしていたが、最近は部署が変わり、相談する時間が減ってしまったということですね。以前は経験が役立ってたかったが、現在はそのような機会がなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングの授業に取り組む気が起きないと感じているのですね。以前は同じ分野の人と一緒に学んでいたり、講習室に参加したりしていたが、最近は部署が変わり、受講する人が減ってしまったということですね。以前は研修が役立っておかったが、現在はそのようなものがなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングの問題に取り組む気が起きないと感じているのですね。以前は同じ大学の人と一緒に学んでいたり、講習セミナーに参加したりしていたが、最近は部署が変わり、担当する頻度が減ってしまったということですね。以前は仕事が役立ってもかったが、現在はそのような必要がなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングの研究に取り組む気が起きないと感じているのですね。以前は同じ立場の人と一緒に学んでいたり、講習所に参加したりしていたが、最近は部署が変わり、所属する人数が減ってしまったということですね。以前はコミュニケーションが役立ってはかったが、現在はそのような活動がなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングのことに取り組む気が起きないと感じているのですね。以前は同じ学科の人と一緒に学んでいたり、講習セッションに参加したりしていたが、最近は部署が変わり、指導する仕事が減ってしまったということですね。以前はこれが役立っておらかったが、現在はそのような意識がなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# わからない。[SEP]カウンセリングの課題に取り組む気が起きないと感じているのですね。以前は同じ業界の人と一緒に学んでいたり、講習クラスに参加したりしていたが、最近は部署が変わり、活動する回数が減ってしまったということですね。以前は自分が役立ってまかったが、現在はそのような習慣がなくなってしまったため、やる気が出なくなっているということですね。[SEP]
# そうですねね、そういった目標は持ってますけどねね。[SEP]あんまりうつ病の治療へのカウンセリングのガイドラインとか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の時点ではあったりとか、そういうことだけはあったので、勉強したいなってところはあるんですけど。
# そうですねって、そういった目標は持ってますけどね」。[SEP]あんまり、がんの治療へのカウンセリングの方法とか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の段階ではあったりとか、そういうものだけはあったので、そうしたいなってところはあるんですけど。
# そうですねあ、そういった目標は持ってますけどねぇ。[SEP]あんまり難病の治療へのカウンセリングの指針とか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年のインタビューではあったりとか、そういうのだけはあったので、実践したいなってところはあるんですけど。
# そうですねよ、そういった目標は持ってますけどねって。[SEP]あんまり不ズの治療へのカウンセリングの知識とか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年のガイドラインではあったりとか、そういう目標だけはあったので、実現したいなってところはあるんですけど。
# そうですねと、そういった目標は持ってますけどね。。[SEP]あんまりエイ人の治療へのカウンセリングの本とか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の論文ではあったりとか、そういう話だけはあったので、研究したいなってところはあるんですけど。
# そうですねで、そういった目標は持ってますけどね?。[SEP]あんまり精神病気の治療へのカウンセリングのアドバイスとか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の日本ではあったりとか、そういう考えだけはあったので、どうしたいなってところはあるんですけど。
# そうですねぇ、そういった目標は持ってますけどねと。[SEP]あんまり喘症の治療へのカウンセリングのマニュアルとか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の文献ではあったりとか、そういう意識だけはあったので、証明したいなってところはあるんですけど。
# そうですね、、そういった目標は持ってますけどねー。[SEP]あんまり乳かんの治療へのカウンセリングのノウハウとか、日本の文献で無いですもんね。[SEP]そうですね、あの、ないですね。なんか今年の学会ではあったりとか、そういうところだけはあったので、改善したいなってところはあるんですけど。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]そのをの時間、あるいは勉強のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10%として、あまり重要でないというのを0%とすると、Aさんにとっては、何%くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]これ、1時間、そして自分のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10だとして、あまり重要でないというのを0点とすると、Aさんにとっては、何点くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]こののな時間、特に仕事のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10までとして、あまり重要でないというのを0だとすると、Aさんにとっては、何パーセントくらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]それ時間を時間、つまり習のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10以上として、あまり重要でないというのを0位とすると、Aさんにとっては、何位くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]まずに一時間、レク事のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10点として、あまり重要でないというのを0までとすると、Aさんにとっては、何倍くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]自分は2時間、また作業のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10位として、あまり重要でないというのを0ですとすると、Aさんにとっては、何割くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]時間べ、時間、そのリエーションのための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10くらいとして、あまり重要でないというのを0以上とすると、Aさんにとっては、何度くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 実際どうなるかはわからないですけどね。計画的に進められるといいとは思います。[SEP]例えばで3時間、ミー研究のための時間に使うということの重要度について点数を付けてもらいたいのですが、とても重要だというのを10パーセントとして、あまり重要でないというのを0からとすると、Aさんにとっては、何分くらいになりそうですか?[SEP]重要度でいうと、8とか9とか。10までいかないにしても、かなり高いと思います。
# 一時的に業研で禁煙やってたもんだから、一応協力するわよ、っていうけどもぉー。なんや、なんでこんなイライラするんやろなーって。だからね、医者がいるかな。でも禁煙をやっていたKさんが禁煙しながら普通に吸っていて、それはいかんやろーって(笑)。[SEP]それは効果なさそう。[SEP]それはそう、でも飲み薬よりはパッチ!
# 一時的に業研で禁煙やってたもんだから、一応協力するわね、っていうけどもぉ〜。なんや、なんでこんなイライラするんやろなーって。だからちょっと、友達がいるかな。でもタバコをやっていたKさんが緊張しながら普通に吸っていて、それはいかんやろーって(笑)。[SEP]これは効果なさそう。[SEP]ではそう、でも飲み薬よりはパッチ!
# 一時的に業研で禁煙やってたもんだから、一応協力する
までのような苦労をしなくてもあなたが利用できるものがあります。ニコチン代用品、パッチやマウストローチ(ガム状吸入器とスプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬)にトライするのであればその薬物治療について話をすることができます。禁煙グループへの参加もできますしもちろん電話相談窓口もありますし...。[SEP]とにかくそれをする時間がない...
# わかっています。わかっています。聞いたことがあるし!以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの?すごく難しい。[SEP]そうね」今までのような苦労をしなくてもあなたが利用できるものがあります。ニコチン代用品、パッチやエアトローチ用ガムや吸入器などスプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬)にトライするのであればもっと薬物治療について話をすることができます。禁煙グループへの参加もできますし「電話相談窓口もありますし...。[SEP]とにかくそれをする時間がない...
# わかっています。わかっています。聞いたことがあるしか以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの?すごく難しい。[SEP]そうね,今までのような苦労をしなくてもあなたが利用できるものがあります。ニコチン代用品、パッチやガストローチ。ガムの吸入器およびスプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬)にトライするのであればあらゆる薬物治療について話をすることができます。禁煙グループへの参加もできますしお電話相談窓口もありますし...。[SEP]とにかくそれをする時間がない...
# わかっています。わかっています。聞いたことがあるしね以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの?すごく難しい。[SEP]そうね.今までのような苦労をしなくてもあなたが利用できるものがあります。ニコチン代用品、パッチやゴムトローチ/ガム・吸入器付きスプレー式点鼻薬など。チヤンテイックスやZyban(経口禁煙薬)にトライするのであれば初めて薬物治療について話をすることができます。禁煙グループへの参加もできますし?電話相談窓口もありますし...。[SEP]とにかくそれをする時間がない...
# そうですね。[SEP]やってり、イジるのが楽しくなるっていうのは、いろなことがあったりするんだね。[SEP]そうですね。それだけのことではないですが、仕事をするっていることもないですかね。
# そうですね。[SEP]やっちゃり、バズるのが難しくなるっていうのは、そうんなことがあったりするんだね。[SEP]そうですね。それだけのものではないですが、仕事をしようっていることもあるですかね。
# そうですね。[SEP]やっけり、解かるのが遅くなるっていうのは、やりることがあったりするんだね。[SEP]そうですね。それだけの意味ではないですが、仕事をやるっていることも多いですかね。
# そうですね。[SEP]やったり、ボケるのが速くなるっていうのは、ありがいうことがあったりするんだね。[SEP]そうですね。それだけの話ではないですが、仕事をやろうっていることもいいですかね。
# そうですね。[SEP]やっぱり、アゲるのが早くなるっていうのは、凄しいことがあったりするんだね。[SEP]そうですね。それだけのわけではないですが、仕事を続けるっていることもそうですかね。
# そうですね。[SEP]やったらり、やるるのがうまくなるっていうのは、嬉ないことがあったりするんだね。[SEP]そうですね。それだけの事ではないですが、仕事を楽しむっていることもありですかね。
# そうですね。[SEP]やってれり、やらるのが上手くなるっていうのは、いろいろいことがあったりするんだね。[SEP]そうですね。それだけの人間ではないですが、仕事をこなすっていることも大事ですかね。
# そうですね。[SEP]やっおけり、おけるのが長くなるっていうのは、大変ってことがあったりするんだね。[SEP]そうですね。それだけの問題ではないですが、仕事をできるっていることも重要ですかね。
# 重要度でいうと、10とか10とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。やっぱ、時間の自分のために時間を使うのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、1とか20とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。そのあの時間節けのために時間をかけるのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、5とか3とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。それ、な時間と約のために時間を作るのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、9とか5とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。そうべ。時間、とりのために時間を稼ぐのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、8とか8とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。でのと時間やりのために時間を掛けるのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、3とか9とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。このでり時間。びのために時間を回すのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、7とか30とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。まだとい時間考管理のために時間を考えるのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# 重要度でいうと、100とか7とか。10までいかないにしても、かなり高いと思います。[SEP]そうですか。わいういう時間あることのために時間を過ごすのは、今のAさんにとって、とても重要だということですね。[SEP]はい。
# そう。ご注文を普通に200に抑えていたのに、おかわり!!って、言って。[SEP]じゃぁ、太っている傾向にあって、それを経験しているがゆえに、やっぱこう、それをしちゃうと、っちゃうかなって。[SEP]そう。」っていう。
# そう。ご飯を普通に200に抑えていたのに、おかわり!!って、言って。[SEP]じゃぁ、痩している傾向にあって、それを経験しているがゆえに、やっぱこう、これを言っちゃうとかなっちゃうかなって。[SEP]そう。』っていう。
# そう。ご予算を普通に200に抑えていたのに、おかわり!!って、言って。[SEP]じゃぁ
前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの?すごく難しい。
# もう、私は吸っていないって・・・いえは私・私。私やめようとしてきたけれど自分でもすごく難しくてどうやっていいか分からないんです。[SEP]今がやめるときです。吸い続けることはできません。僕のためだけでなくあなたのためにも言います。肺がんや肺気腫/口腔がんと心疾患などのりスクも増えるんですよ。[SEP]わかっています。わかっています。聞いたことがあるし「以前人に言われたこともあります。全部聞きました。ただどうやっていいかわからないんです。どうやって禁煙したらいいの?すごく難しい。
# そう。せっかくズボンも小さく、これもまたスーツを指さして小っちゃくしたのに。うん。[SEP]ああ。スーツのサイズ下げたのに、またあーるとサイズあげなきゃ!みたいな。[SEP]それが一番いいかな!」と。
# そう。せっかくズボンも小さく、これもちゃんとスーツを指さしながら小っちゃくしたのに。うん。[SEP]あー。スーツのサイズ下げたのに、また着めるとサイズあげなきゃ!みたいな。[SEP]それが一番簡単かな!ああ。
# そう。せっかくズボンも小さく、これも白いスーツを指さし、小っちゃくしたのに。うん。[SEP]あうん。スーツのサイズ下げたのに、またちょけるとサイズあげなきゃ!みたいな。[SEP]それが一番難しいかな!とって。
# そう。せっかくズボンも小さく、これもパンツスーツを指さしたら小っちゃくしたのに。うん。[SEP]あっ。スーツのサイズ下げたのに、また脱れるとサイズあげなきゃ!みたいな。[SEP]それが一番大事かな!って」。
# そう。せっかくズボンも小さく、これも、スーツを指さしたり小っちゃくしたのに。うん。[SEP]あぁ。スーツのサイズ下げたのに、またゆかるとサイズあげなきゃ!みたいな。[SEP]それが一番楽かな!!いう。
# そう。せっかくズボンも小さく、これもいいスーツを指さしつつ小っちゃくしたのに。うん。[SEP]あう。スーツのサイズ下げたのに、またパせるとサイズあげなきゃ!みたいな。[SEP]それが一番良いかな!』な。
# そう。せっかくズボンも小さく、これも同じスーツを指さしに小っちゃくしたのに。うん。[SEP]あ~。スーツのサイズ下げたのに、またとえるとサイズあげなきゃ!みたいな。[SEP]それが一番ですかな!そうの。
# そう。せっかくズボンも小さく、これも初めてスーツを指さしで小っちゃくしたのに。うん。[SEP]ああ。スーツのサイズ下げたのに、またひジるとサイズあげなきゃ!みたいな。[SEP]それが一番ましかな!えも。

# %%
print(data_augmented.keys())
for i in range(10):
    print(data_augmented["train0"][i])

# %%
p_list = ["p1/", "p2/", "p3/", "p4/", "p5/"]
dir_list = [base_path + "ex{}/ex{}-{}/".format(ex_n[0], ex_n[0], ex_n[1]) + d for d in p_list]
filename_list = ["{}-{}train.csv".format(ex_n[0], ex_n[1]), "{}-{}valid.csv".format(ex_n[0], ex_n[1]), "{}-{}test.csv".format(ex_n[0], ex_n[1])]
val_list = [valid_df1, valid_df2, valid_df3, valid_df4, valid_df5]
tes_list = [test_df1, test_df2, test_df3, test_df4, test_df5]
print(dir_list)
for p in p_list:
    if not os.path.exists(p):
        os.mkdir(p)

# %%
for i, key in enumerate(data_augmented.keys()):
    d = dir_list[i]
    if not os.path.exists(d + "/datasets/"):
        os.mkdir(d + "datasets/")
    else:
        shutil.rmtree(d + "datasets/")
        os.mkdir(d + "datasets/")
    train = pd.DataFrame.from_dict(data_augmented[key])
    valid = val_list[i]
    test = tes_list[i]
    train.to_csv(d+"/datasets/"+filename_list[0], index=False)
    valid.to_csv(d+"/datasets/"+filename_list[1], index=False)
    test.to_csv(d+"/datasets/"+filename_list[2], index=False)
